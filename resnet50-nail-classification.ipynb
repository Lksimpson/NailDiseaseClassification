# %%
import matplotlib.pyplot as plt
from collections import OrderedDict

from copy import deepcopy
import torch
from torchvision import models  
from torch import nn
from torch import optim
from torchvision import datasets, transforms, models

# download the data
data_dir = '/kaggle/input/clean-datasetsplit8515/data'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# Process with some data transformation, do not change
data_transforms = {
    'training': transforms.Compose([transforms.RandomResizedCrop(224),
                                    transforms.RandomHorizontalFlip(),
                                    transforms.RandomRotation(30),
                                    transforms.ToTensor(),
                                    transforms.Normalize([0.485, 0.456, 0.406],
                                                         [0.229, 0.224,
                                                          0.225])]),

    'validation': transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize(
                                          [0.485, 0.456, 0.406],
                                          [0.229, 0.224, 0.225])]),

    'testing': transforms.Compose([transforms.Resize(256),
                                   transforms.CenterCrop(224),
                                   transforms.ToTensor(),
                                   transforms.Normalize([0.485, 0.456, 0.406],
                                                        [0.229, 0.224,
                                                         0.225])])
}
# This specifies how many images to process per training/validation
batch_size = 32

image_datasets = {
    'training': datasets.ImageFolder(train_dir,
                                     transform=data_transforms['training']),
    'testing': datasets.ImageFolder(test_dir,
                                    transform=data_transforms['testing']),
    'validation': datasets.ImageFolder(valid_dir,
                                       transform=data_transforms['validation'])
}

dataloaders = {
    'training': torch.utils.data.DataLoader(image_datasets['training'],
                                            batch_size=batch_size,
                                            shuffle=True),
    'testing': torch.utils.data.DataLoader(image_datasets['testing'],
                                           batch_size=batch_size,
                                           shuffle=False),
    'validation': torch.utils.data.DataLoader(image_datasets['validation'],
                                              batch_size=batch_size,
                                              shuffle=True)
}

# get the length of each dataloaders; with batch size=256, you should have 26 batches of training samples, each with 256 images 
training_len = len(dataloaders['training'])
test_len = len(dataloaders['testing'])
validation_len = len(dataloaders['validation'])
class_to_idx = image_datasets['training'].class_to_idx

print('We have ', training_len, 'batches of training images;', 'each with',
      batch_size, 'images')
print('We have ', validation_len, 'batches of validation images;', 'each with',
      batch_size, 'images')
print('We have ', test_len, 'batches of testing images;', 'each with',
      batch_size, 'images')

# Let us preview size of each batch
print('Single batch', next(iter(dataloaders['training']))[0].shape)
# Transfer learning with ResNet50
model = models.resnet50(weights='DEFAULT')
for param in model.parameters():
    param.requires_grad = False

print(model)

# This is the original classifier with resnet50
print()
print('Original classifier of ResNet50')
print(model.fc)

# Defining number of hidden units in our fully connected layer
number_of_classes = len(class_to_idx) 
model.fc = nn.Linear(2048, number_of_classes)
print(model)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)

epochs = 10
optimizer = optim.Adam(model.fc.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()  # Changed from NLLLoss - this works with raw logits
print_every = 5

validation_accuracies, training_accuracies = [], []
validation_losses, training_losses = [], []

best_validation_accuracy = 0
best_model_weights = None

for e in range(epochs):

    training_loss = training_accuracy = 0
    validation_loss = validation_accuracy = 0

    model.train()
    for batch_idx, (images, labels) in enumerate(dataloaders['training']):

        # Moving images & labels to the GPU if there is one
        images, labels = images.to(device), labels.to(device)

        # Zero gradients first
        optimizer.zero_grad()

        # Forward pass
        logits = model.forward(images)  # Changed variable name for clarity
        loss = criterion(logits, labels)
        
        # Backward pass to compute gradients
        loss.backward()
        
        # Update weights after backward
        optimizer.step()

        # Calculating metrics
        ps = torch.softmax(logits, dim=1)  # Changed from exp since we have raw logits now
        top_ps, top_class = ps.topk(1, dim=1)
        matches = (top_class == labels.view(*top_class.shape)).type(
            torch.FloatTensor)
        train_batch_accuracy = matches.mean()

        # Tracking metrics
        training_loss += loss.item()
        train_batch_loss = loss.item()
        training_accuracy += train_batch_accuracy.item()

        if batch_idx % print_every == 0:
            print('epoch', e, 'batch', batch_idx)
            print('training loss per batch', train_batch_loss)
            print('training accuracy per batch', train_batch_accuracy.item())

    # Validation
    model.eval()
    with torch.no_grad():
        for batch_idx, (images, labels) in enumerate(
                dataloaders['validation']):
            images, labels = images.to(device), labels.to(device)
            logits = model(images)  # Changed variable name
            loss = criterion(logits, labels)
            ps = torch.softmax(logits, dim=1)  # Changed from exp
            top_ps, top_class = ps.topk(1, dim=1)
            matches = (top_class == labels.view(*top_class.shape)).type(
                torch.FloatTensor)
            validation_batch_accuracy = matches.mean()

            validation_loss += loss.item()
            validation_batch_loss = loss.item()
            validation_accuracy += validation_batch_accuracy

    # Save best model
    if validation_accuracy >= best_validation_accuracy:
        best_validation_accuracy = validation_accuracy
        best_model_weights = model.state_dict()

    # Summary per epoch
    print('epoch', e, 'summary')
    print('avg training loss per epoch', training_loss / training_len)
    print('avg training accuracy per epoch', training_accuracy / training_len)
    training_losses.append(training_loss / training_len)
    training_accuracies.append(training_accuracy / training_len)

    print('avg validation loss per epoch', validation_loss / validation_len)
    print('avg validation accuracy per epoch',
          validation_accuracy / validation_len)
    validation_losses.append(validation_loss / validation_len)
    validation_accuracies.append(validation_accuracy / validation_len)

    print()
plt.figure()
plt.title("Training Summary of Loss")
plt.plot(training_losses, label='Training Loss')
plt.plot(validation_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure()
plt.title("Training Summary of Accuracy")
plt.plot(training_accuracies, label='Training Accuracy')
plt.plot(validation_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Load the best model so far
model.load_state_dict(best_model_weights)
model.eval()  # Set to evaluation mode

total_correct = 0
total_samples = 0
predictions = []
label_data = []

with torch.no_grad():  # Disable gradient computation for testing
    for images, labels in dataloaders['testing']:
        images, labels = images.to(device), labels.to(device)
        
        logits = model(images)
        ps = torch.softmax(logits, dim=1)
        
        top_ps, top_class = ps.topk(1, dim=1)
        
        total_correct += (top_class == labels.view(*top_class.shape)).sum().item()
        total_samples += labels.size(0)
        
        predictions.append(top_class)
        label_data.append(labels)

test_accuracy = total_correct / total_samples
print(f'Test Accuracy: {test_accuracy:.4f}')

predictions = torch.cat(predictions).cpu()
label_data = torch.cat(label_data).cpu()

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix as conf_mat
import numpy as np

# Your class labels - replace these with your actual class names
class_names = ['Acral Lentiginous Melanoma', 'Blue Finger', 'Clubbing', 'Healthy Nail', 'Onychogryphosis', 'Pitting']

cf = conf_mat(label_data, predictions)

# Plot raw confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cf, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.tight_layout()
plt.show()

# Plot normalized confusion matrix
plt.figure(figsize=(10, 8))
ncf = cf.astype('float') / cf.sum(axis=1, keepdims=True)  # Normalize by row (true labels)
sns.heatmap(ncf, annot=True, fmt='.2%', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('Normalized Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.tight_layout()
plt.show()

import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix as conf_mat

# Your class labels - replace with actual names
class_names = ['Acral Lentiginous Melanoma', 'Blue Finger', 'Clubbing', 'Healthy Nail', 'Onychogryphosis', 'Pitting']

cf = conf_mat(label_data, predictions)

# Calculate Overall Accuracy
overall_accuracy = np.trace(cf) / cf.sum()

# Calculate TP, FP, FN, TN for each class
metrics = []
for i, class_name in enumerate(class_names):
    TP = cf[i, i]
    FP = cf[:, i].sum() - TP
    FN = cf[i, :].sum() - TP
    TN = cf.sum() - TP - FP - FN
    
    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    support = cf[i, :].sum()
    
    metrics.append({
        'Class': class_name,
        'TP': TP,
        'FP': FP,
        'FN': FN,
        'TN': TN,
        'Precision': round(precision, 4),
        'Recall': round(recall, 4),
        'F1-Score': round(f1, 4),
        'Support': support
    })

metrics_df = pd.DataFrame(metrics)

# Calculate Macro Average
macro_avg = {
    'Class': 'Macro Avg',
    'TP': ' ',
    'FP': ' ',
    'FN': ' ',
    'TN': ' ',
    'Precision': round(metrics_df['Precision'].mean(), 4),
    'Recall': round(metrics_df['Recall'].mean(), 4),
    'F1-Score': round(metrics_df['F1-Score'].mean(), 4),
    'Support': metrics_df['Support'].sum()
}

# Calculate Weighted Average
total_support = metrics_df['Support'].sum()
weighted_avg = {
    'Class': 'Weighted Avg',
    'TP': ' ',
    'FP': ' ',
    'FN': ' ',
    'TN': ' ',
    'Precision': round((metrics_df['Precision'] * metrics_df['Support']).sum() / total_support, 4),
    'Recall': round((metrics_df['Recall'] * metrics_df['Support']).sum() / total_support, 4),
    'F1-Score': round((metrics_df['F1-Score'] * metrics_df['Support']).sum() / total_support, 4),
    'Support': total_support
}

# Add averages to dataframe
metrics_df = pd.concat([metrics_df, pd.DataFrame([macro_avg, weighted_avg])], ignore_index=True)

# Print results
print(f"{'='*60}")
print(f"OVERALL ACCURACY: {round(overall_accuracy, 4)} ({round(overall_accuracy*100, 2)}%)")
print(f"{'='*60}\n")
print(metrics_df.to_string(index=False))
# Out:
# We have  100 batches of training images; each with 32 images
# We have  18 batches of validation images; each with 32 images
# We have  3 batches of testing images; each with 32 images
# Single batch torch.Size([32, 3, 224, 224])
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )
#
# Original classifier of ResNet50
# Linear(in_features=2048, out_features=1000, bias=True)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=6, bias=True)
# )
# epoch 0 batch 0
# training loss per batch 1.7815117835998535
# training accuracy per batch 0.1875
# epoch 0 batch 5
# training loss per batch 1.7076307535171509
# training accuracy per batch 0.3125
# epoch 0 batch 10
# training loss per batch 1.6748270988464355
# training accuracy per batch 0.34375
# epoch 0 batch 15
# training loss per batch 1.5869137048721313
# training accuracy per batch 0.34375
# epoch 0 batch 20
# training loss per batch 1.4595372676849365
# training accuracy per batch 0.5
# epoch 0 batch 25
# training loss per batch 1.4831475019454956
# training accuracy per batch 0.40625
# epoch 0 batch 30
# training loss per batch 1.3980940580368042
# training accuracy per batch 0.5
# epoch 0 batch 35
# training loss per batch 1.3576431274414062
# training accuracy per batch 0.59375
# epoch 0 batch 40
# training loss per batch 1.262359857559204
# training accuracy per batch 0.59375
# epoch 0 batch 45
# training loss per batch 1.2780499458312988
# training accuracy per batch 0.53125
# epoch 0 batch 50
# training loss per batch 1.1776511669158936
# training accuracy per batch 0.65625
# epoch 0 batch 55
# training loss per batch 1.0859849452972412
# training accuracy per batch 0.71875
# epoch 0 batch 60
# training loss per batch 1.324988603591919
# training accuracy per batch 0.53125
# epoch 0 batch 65
# training loss per batch 1.2921233177185059
# training accuracy per batch 0.5625
# epoch 0 batch 70
# training loss per batch 1.1540733575820923
# training accuracy per batch 0.59375
# epoch 0 batch 75
# training loss per batch 1.2735003232955933
# training accuracy per batch 0.59375
# epoch 0 batch 80
# training loss per batch 1.0577411651611328
# training accuracy per batch 0.59375
# epoch 0 batch 85
# training loss per batch 1.0189037322998047
# training accuracy per batch 0.78125
# epoch 0 batch 90
# training loss per batch 1.0517250299453735
# training accuracy per batch 0.6875
# epoch 0 batch 95
# training loss per batch 1.3360679149627686
# training accuracy per batch 0.4375
# epoch 0 summary
# avg training loss per epoch 1.3258382737636567
# avg training accuracy per epoch 0.5223863637447357
# avg validation loss per epoch 1.0339699122640822
# avg validation accuracy per epoch tensor(0.6811)
#
# epoch 1 batch 0
# training loss per batch 1.0707002878189087
# training accuracy per batch 0.59375
# epoch 1 batch 5
# training loss per batch 1.1792396306991577
# training accuracy per batch 0.5
# epoch 1 batch 10
# training loss per batch 1.1279494762420654
# training accuracy per batch 0.625
# epoch 1 batch 15
# training loss per batch 1.0825531482696533
# training accuracy per batch 0.625
# epoch 1 batch 20
# training loss per batch 1.1381880044937134
# training accuracy per batch 0.59375
# epoch 1 batch 25
# training loss per batch 1.0453590154647827
# training accuracy per batch 0.5625
# epoch 1 batch 30
# training loss per batch 1.0183289051055908
# training accuracy per batch 0.59375
# epoch 1 batch 35
# training loss per batch 1.13663649559021
# training accuracy per batch 0.59375
# epoch 1 batch 40
# training loss per batch 1.0495877265930176
# training accuracy per batch 0.6875
# epoch 1 batch 45
# training loss per batch 0.9411808252334595
# training accuracy per batch 0.71875
# epoch 1 batch 50
# training loss per batch 0.9880321025848389
# training accuracy per batch 0.71875
# epoch 1 batch 55
# training loss per batch 1.1016210317611694
# training accuracy per batch 0.625
# epoch 1 batch 60
# training loss per batch 1.239182472229004
# training accuracy per batch 0.5625
# epoch 1 batch 65
# training loss per batch 0.8841972947120667
# training accuracy per batch 0.78125
# epoch 1 batch 70
# training loss per batch 0.8461461663246155
# training accuracy per batch 0.71875
# epoch 1 batch 75
# training loss per batch 0.9934661984443665
# training accuracy per batch 0.65625
# epoch 1 batch 80
# training loss per batch 1.1393296718597412
# training accuracy per batch 0.53125
# epoch 1 batch 85
# training loss per batch 0.8493399024009705
# training accuracy per batch 0.65625
# epoch 1 batch 90
# training loss per batch 1.2108265161514282
# training accuracy per batch 0.5625
# epoch 1 batch 95
# training loss per batch 0.9360373020172119
# training accuracy per batch 0.625
# epoch 1 summary
# avg training loss per epoch 1.004094125032425
# avg training accuracy per epoch 0.6448295456171036
# avg validation loss per epoch 0.865053567621443
# avg validation accuracy per epoch tensor(0.7160)
#
# epoch 2 batch 0
# training loss per batch 0.7995151281356812
# training accuracy per batch 0.78125
# epoch 2 batch 5
# training loss per batch 0.9466953277587891
# training accuracy per batch 0.65625
# epoch 2 batch 10
# training loss per batch 0.8851020336151123
# training accuracy per batch 0.65625
# epoch 2 batch 15
# training loss per batch 0.9590883255004883
# training accuracy per batch 0.625
# epoch 2 batch 20
# training loss per batch 0.7821342349052429
# training accuracy per batch 0.78125
# epoch 2 batch 25
# training loss per batch 0.9967404007911682
# training accuracy per batch 0.59375
# epoch 2 batch 30
# training loss per batch 1.115797519683838
# training accuracy per batch 0.5625
# epoch 2 batch 35
# training loss per batch 0.9337208867073059
# training accuracy per batch 0.65625
# epoch 2 batch 40
# training loss per batch 0.7530929446220398
# training accuracy per batch 0.78125
# epoch 2 batch 45
# training loss per batch 0.7837018966674805
# training accuracy per batch 0.71875
# epoch 2 batch 50
# training loss per batch 0.9790083765983582
# training accuracy per batch 0.65625
# epoch 2 batch 55
# training loss per batch 0.973141074180603
# training accuracy per batch 0.71875
# epoch 2 batch 60
# training loss per batch 0.9175456762313843
# training accuracy per batch 0.71875
# epoch 2 batch 65
# training loss per batch 0.842695415019989
# training accuracy per batch 0.71875
# epoch 2 batch 70
# training loss per batch 1.075430989265442
# training accuracy per batch 0.59375
# epoch 2 batch 75
# training loss per batch 0.6447612643241882
# training accuracy per batch 0.875
# epoch 2 batch 80
# training loss per batch 0.8206695914268494
# training accuracy per batch 0.65625
# epoch 2 batch 85
# training loss per batch 0.8579869866371155
# training accuracy per batch 0.71875
# epoch 2 batch 90
# training loss per batch 0.7207695245742798
# training accuracy per batch 0.78125
# epoch 2 batch 95
# training loss per batch 0.8413709998130798
# training accuracy per batch 0.71875
# epoch 2 summary
# avg training loss per epoch 0.905115555524826
# avg training accuracy per epoch 0.6773011362552643
# avg validation loss per epoch 0.7730844484435188
# avg validation accuracy per epoch tensor(0.7434)
#
# epoch 3 batch 0
# training loss per batch 0.7834444642066956
# training accuracy per batch 0.6875
# epoch 3 batch 5
# training loss per batch 0.9176826477050781
# training accuracy per batch 0.59375
# epoch 3 batch 10
# training loss per batch 0.8499892354011536
# training accuracy per batch 0.71875
# epoch 3 batch 15
# training loss per batch 0.7318440675735474
# training accuracy per batch 0.75
# epoch 3 batch 20
# training loss per batch 0.9074752330780029
# training accuracy per batch 0.75
# epoch 3 batch 25
# training loss per batch 0.956346869468689
# training accuracy per batch 0.71875
# epoch 3 batch 30
# training loss per batch 0.7080556154251099
# training accuracy per batch 0.71875
# epoch 3 batch 35
# training loss per batch 0.9724615812301636
# training accuracy per batch 0.59375
# epoch 3 batch 40
# training loss per batch 0.8727071285247803
# training accuracy per batch 0.8125
# epoch 3 batch 45
# training loss per batch 0.8546695113182068
# training accuracy per batch 0.65625
# epoch 3 batch 50
# training loss per batch 0.8227113485336304
# training accuracy per batch 0.65625
# epoch 3 batch 55
# training loss per batch 0.7678632140159607
# training accuracy per batch 0.8125
# epoch 3 batch 60
# training loss per batch 0.7326006293296814
# training accuracy per batch 0.75
# epoch 3 batch 65
# training loss per batch 0.8160505890846252
# training accuracy per batch 0.75
# epoch 3 batch 70
# training loss per batch 0.5622838139533997
# training accuracy per batch 0.75
# epoch 3 batch 75
# training loss per batch 0.8071565628051758
# training accuracy per batch 0.8125
# epoch 3 batch 80
# training loss per batch 0.9195502996444702
# training accuracy per batch 0.5625
# epoch 3 batch 85
# training loss per batch 0.755612313747406
# training accuracy per batch 0.875
# epoch 3 batch 90
# training loss per batch 0.821104109287262
# training accuracy per batch 0.625
# epoch 3 batch 95
# training loss per batch 0.8065633773803711
# training accuracy per batch 0.71875
# epoch 3 summary
# avg training loss per epoch 0.8452043390274048
# avg training accuracy per epoch 0.6923579546809197
# avg validation loss per epoch 0.7356178164482117
# avg validation accuracy per epoch tensor(0.7689)
#
# epoch 4 batch 0
# training loss per batch 1.0857948064804077
# training accuracy per batch 0.5625
# epoch 4 batch 5
# training loss per batch 0.8278095126152039
# training accuracy per batch 0.65625
# epoch 4 batch 10
# training loss per batch 0.9585610032081604
# training accuracy per batch 0.65625
# epoch 4 batch 15
# training loss per batch 0.6877710819244385
# training accuracy per batch 0.8125
# epoch 4 batch 20
# training loss per batch 0.818368136882782
# training accuracy per batch 0.71875
# epoch 4 batch 25
# training loss per batch 1.0599898099899292
# training accuracy per batch 0.5
# epoch 4 batch 30
# training loss per batch 0.7276127338409424
# training accuracy per batch 0.71875
# epoch 4 batch 35
# training loss per batch 0.594752311706543
# training accuracy per batch 0.8125
# epoch 4 batch 40
# training loss per batch 0.5762031078338623
# training accuracy per batch 0.875
# epoch 4 batch 45
# training loss per batch 0.8187054395675659
# training accuracy per batch 0.78125
# epoch 4 batch 50
# training loss per batch 0.7708548307418823
# training accuracy per batch 0.75
# epoch 4 batch 55
# training loss per batch 0.6754037141799927
# training accuracy per batch 0.78125
# epoch 4 batch 60
# training loss per batch 1.0574029684066772
# training accuracy per batch 0.59375
# epoch 4 batch 65
# training loss per batch 0.829890251159668
# training accuracy per batch 0.65625
# epoch 4 batch 70
# training loss per batch 0.8873206377029419
# training accuracy per batch 0.71875
# epoch 4 batch 75
# training loss per batch 0.8335155844688416
# training accuracy per batch 0.59375
# epoch 4 batch 80
# training loss per batch 0.9069237112998962
# training accuracy per batch 0.625
# epoch 4 batch 85
# training loss per batch 0.8280757069587708
# training accuracy per batch 0.71875
# epoch 4 batch 90
# training loss per batch 0.8696350455284119
# training accuracy per batch 0.625
# epoch 4 batch 95
# training loss per batch 0.738295316696167
# training accuracy per batch 0.78125
# epoch 4 summary
# avg training loss per epoch 0.8329849404096603
# avg training accuracy per epoch 0.6873295456171036
# avg validation loss per epoch 0.7027807616525226
# avg validation accuracy per epoch tensor(0.7807)
#
# epoch 5 batch 0
# training loss per batch 0.8560975193977356
# training accuracy per batch 0.71875
# epoch 5 batch 5
# training loss per batch 0.7500609159469604
# training accuracy per batch 0.75
# epoch 5 batch 10
# training loss per batch 0.7251692414283752
# training accuracy per batch 0.75
# epoch 5 batch 15
# training loss per batch 0.9628176689147949
# training accuracy per batch 0.65625
# epoch 5 batch 20
# training loss per batch 0.988025426864624
# training accuracy per batch 0.5625
# epoch 5 batch 25
# training loss per batch 1.0503332614898682
# training accuracy per batch 0.5625
# epoch 5 batch 30
# training loss per batch 0.7352092862129211
# training accuracy per batch 0.75
# epoch 5 batch 35
# training loss per batch 0.8003178834915161
# training accuracy per batch 0.71875
# epoch 5 batch 40
# training loss per batch 0.7329762578010559
# training accuracy per batch 0.71875
# epoch 5 batch 45
# training loss per batch 1.0381336212158203
# training accuracy per batch 0.65625
# epoch 5 batch 50
# training loss per batch 0.6081094741821289
# training accuracy per batch 0.78125
# epoch 5 batch 55
# training loss per batch 0.8635311722755432
# training accuracy per batch 0.75
# epoch 5 batch 60
# training loss per batch 0.6513177156448364
# training accuracy per batch 0.78125
# epoch 5 batch 65
# training loss per batch 0.9459037780761719
# training accuracy per batch 0.5625
# epoch 5 batch 70
# training loss per batch 0.9817264676094055
# training accuracy per batch 0.5625
# epoch 5 batch 75
# training loss per batch 1.0250617265701294
# training accuracy per batch 0.625
# epoch 5 batch 80
# training loss per batch 0.8185055255889893
# training accuracy per batch 0.75
# epoch 5 batch 85
# training loss per batch 0.8348540663719177
# training accuracy per batch 0.78125
# epoch 5 batch 90
# training loss per batch 0.8007470965385437
# training accuracy per batch 0.65625
# epoch 5 batch 95
# training loss per batch 0.7791492938995361
# training accuracy per batch 0.75
# epoch 5 summary
# avg training loss per epoch 0.7910479840636253
# avg training accuracy per epoch 0.7151420456171036
# avg validation loss per epoch 0.6724066767427657
# avg validation accuracy per epoch tensor(0.7820)
#
# epoch 6 batch 0
# training loss per batch 0.8393225073814392
# training accuracy per batch 0.6875
# epoch 6 batch 5
# training loss per batch 0.8487119674682617
# training accuracy per batch 0.71875
# epoch 6 batch 10
# training loss per batch 0.6114007830619812
# training accuracy per batch 0.84375
# epoch 6 batch 15
# training loss per batch 0.6705493927001953
# training accuracy per batch 0.8125
# epoch 6 batch 20
# training loss per batch 0.9052402973175049
# training accuracy per batch 0.59375
# epoch 6 batch 25
# training loss per batch 0.755389928817749
# training accuracy per batch 0.65625
# epoch 6 batch 30
# training loss per batch 0.5004667043685913
# training accuracy per batch 0.84375
# epoch 6 batch 35
# training loss per batch 1.0310779809951782
# training accuracy per batch 0.65625
# epoch 6 batch 40
# training loss per batch 0.6479406356811523
# training accuracy per batch 0.78125
# epoch 6 batch 45
# training loss per batch 0.854247510433197
# training accuracy per batch 0.78125
# epoch 6 batch 50
# training loss per batch 0.8254616856575012
# training accuracy per batch 0.65625
# epoch 6 batch 55
# training loss per batch 0.8338718414306641
# training accuracy per batch 0.625
# epoch 6 batch 60
# training loss per batch 0.8028871417045593
# training accuracy per batch 0.65625
# epoch 6 batch 65
# training loss per batch 0.5919775366783142
# training accuracy per batch 0.875
# epoch 6 batch 70
# training loss per batch 0.8165133595466614
# training accuracy per batch 0.6875
# epoch 6 batch 75
# training loss per batch 0.773248016834259
# training accuracy per batch 0.75
# epoch 6 batch 80
# training loss per batch 0.8242855668067932
# training accuracy per batch 0.71875
# epoch 6 batch 85
# training loss per batch 0.8869808912277222
# training accuracy per batch 0.6875
# epoch 6 batch 90
# training loss per batch 0.7729913592338562
# training accuracy per batch 0.75
# epoch 6 batch 95
# training loss per batch 0.929184079170227
# training accuracy per batch 0.65625
# epoch 6 summary
# avg training loss per epoch 0.7346891343593598
# avg training accuracy per epoch 0.7357386362552643
# avg validation loss per epoch 0.6523226714796491
# avg validation accuracy per epoch tensor(0.7776)
#
# epoch 7 batch 0
# training loss per batch 0.722707211971283
# training accuracy per batch 0.71875
# epoch 7 batch 5
# training loss per batch 1.0331348180770874
# training accuracy per batch 0.625
# epoch 7 batch 10
# training loss per batch 0.6258648037910461
# training accuracy per batch 0.71875
# epoch 7 batch 15
# training loss per batch 0.6540570259094238
# training accuracy per batch 0.75
# epoch 7 batch 20
# training loss per batch 0.7107042074203491
# training accuracy per batch 0.78125
# epoch 7 batch 25
# training loss per batch 0.9150548577308655
# training accuracy per batch 0.59375
# epoch 7 batch 30
# training loss per batch 0.7943801283836365
# training accuracy per batch 0.8125
# epoch 7 batch 35
# training loss per batch 0.7415741086006165
# training accuracy per batch 0.6875
# epoch 7 batch 40
# training loss per batch 0.6252436637878418
# training accuracy per batch 0.78125
# epoch 7 batch 45
# training loss per batch 1.1561022996902466
# training accuracy per batch 0.59375
# epoch 7 batch 50
# training loss per batch 0.6341184973716736
# training accuracy per batch 0.8125
# epoch 7 batch 55
# training loss per batch 0.6793528199195862
# training accuracy per batch 0.71875
# epoch 7 batch 60
# training loss per batch 0.6818005442619324
# training accuracy per batch 0.78125
# epoch 7 batch 65
# training loss per batch 0.6091787219047546
# training accuracy per batch 0.75
# epoch 7 batch 70
# training loss per batch 0.5370955467224121
# training accuracy per batch 0.8125
# epoch 7 batch 75
# training loss per batch 0.8120177388191223
# training accuracy per batch 0.75
# epoch 7 batch 80
# training loss per batch 0.809237539768219
# training accuracy per batch 0.75
# epoch 7 batch 85
# training loss per batch 0.5672088265419006
# training accuracy per batch 0.84375
# epoch 7 batch 90
# training loss per batch 0.5939313769340515
# training accuracy per batch 0.75
# epoch 7 batch 95
# training loss per batch 0.6447589993476868
# training accuracy per batch 0.75
# epoch 7 summary
# avg training loss per epoch 0.7452678027749061
# avg training accuracy per epoch 0.7341477274894714
# avg validation loss per epoch 0.6337761845853593
# avg validation accuracy per epoch tensor(0.7915)
#
# epoch 8 batch 0
# training loss per batch 0.9955798387527466
# training accuracy per batch 0.625
# epoch 8 batch 5
# training loss per batch 0.5504554510116577
# training accuracy per batch 0.6875
# epoch 8 batch 10
# training loss per batch 0.7351056933403015
# training accuracy per batch 0.6875
# epoch 8 batch 15
# training loss per batch 0.9119786024093628
# training accuracy per batch 0.75
# epoch 8 batch 20
# training loss per batch 0.7743638157844543
# training accuracy per batch 0.71875
# epoch 8 batch 25
# training loss per batch 0.7094035744667053
# training accuracy per batch 0.75
# epoch 8 batch 30
# training loss per batch 0.5106843709945679
# training accuracy per batch 0.84375
# epoch 8 batch 35
# training loss per batch 0.7639597058296204
# training accuracy per batch 0.71875
# epoch 8 batch 40
# training loss per batch 0.694300651550293
# training accuracy per batch 0.78125
# epoch 8 batch 45
# training loss per batch 0.7591593265533447
# training accuracy per batch 0.75
# epoch 8 batch 50
# training loss per batch 0.6631298661231995
# training accuracy per batch 0.71875
# epoch 8 batch 55
# training loss per batch 0.7983249425888062
# training accuracy per batch 0.71875
# epoch 8 batch 60
# training loss per batch 0.9732195138931274
# training accuracy per batch 0.71875
# epoch 8 batch 65
# training loss per batch 0.7849717736244202
# training accuracy per batch 0.65625
# epoch 8 batch 70
# training loss per batch 0.6222963929176331
# training accuracy per batch 0.8125
# epoch 8 batch 75
# training loss per batch 0.6977220773696899
# training accuracy per batch 0.75
# epoch 8 batch 80
# training loss per batch 0.49749279022216797
# training accuracy per batch 0.84375
# epoch 8 batch 85
# training loss per batch 0.7750166058540344
# training accuracy per batch 0.6875
# epoch 8 batch 90
# training loss per batch 0.5484508872032166
# training accuracy per batch 0.71875
# epoch 8 batch 95
# training loss per batch 1.0898133516311646
# training accuracy per batch 0.625
# epoch 8 summary
# avg training loss per epoch 0.7363839396834373
# avg training accuracy per epoch 0.7350568181276321
# avg validation loss per epoch 0.6049496448702283
# avg validation accuracy per epoch tensor(0.8106)
#
# epoch 9 batch 0
# training loss per batch 0.7660670280456543
# training accuracy per batch 0.71875
# epoch 9 batch 5
# training loss per batch 0.8684810996055603
# training accuracy per batch 0.84375
# epoch 9 batch 10
# training loss per batch 0.6975440382957458
# training accuracy per batch 0.75
# epoch 9 batch 15
# training loss per batch 0.8204986453056335
# training accuracy per batch 0.71875
# epoch 9 batch 20
# training loss per batch 0.7898951172828674
# training accuracy per batch 0.75
# epoch 9 batch 25
# training loss per batch 0.5406779050827026
# training accuracy per batch 0.84375
# epoch 9 batch 30
# training loss per batch 0.6480460166931152
# training accuracy per batch 0.84375
# epoch 9 batch 35
# training loss per batch 0.7176229953765869
# training accuracy per batch 0.84375
# epoch 9 batch 40
# training loss per batch 0.6418324112892151
# training accuracy per batch 0.75
# epoch 9 batch 45
# training loss per batch 0.5980497002601624
# training accuracy per batch 0.8125
# epoch 9 batch 50
# training loss per batch 0.6075232028961182
# training accuracy per batch 0.78125
# epoch 9 batch 55
# training loss per batch 0.7283138632774353
# training accuracy per batch 0.8125
# epoch 9 batch 60
# training loss per batch 0.6090673804283142
# training accuracy per batch 0.71875
# epoch 9 batch 65
# training loss per batch 0.8725533485412598
# training accuracy per batch 0.71875
# epoch 9 batch 70
# training loss per batch 0.6482115387916565
# training accuracy per batch 0.78125
# epoch 9 batch 75
# training loss per batch 0.8693464994430542
# training accuracy per batch 0.59375
# epoch 9 batch 80
# training loss per batch 0.7624207735061646
# training accuracy per batch 0.71875
# epoch 9 batch 85
# training loss per batch 0.6270636916160583
# training accuracy per batch 0.875
# epoch 9 batch 90
# training loss per batch 0.733191192150116
# training accuracy per batch 0.78125
# epoch 9 batch 95
# training loss per batch 0.5324389338493347
# training accuracy per batch 0.8125
# epoch 9 summary
# avg training loss per epoch 0.7168738824129105
# avg training accuracy per epoch 0.7350568181276321
# avg validation loss per epoch 0.6084657361110052
# avg validation accuracy per epoch tensor(0.7963)
# Test Accuracy: 0.8864
# ============================================================
# OVERALL ACCURACY: 0.8864 (88.64%)
# ============================================================
#
#                      Class TP FP FN TN  Precision  Recall  F1-Score  Support
# Acral Lentiginous Melanoma 14  3  1 70     0.8235  0.9333    0.8750       15
#                Blue Finger 20  0  0 68     1.0000  1.0000    1.0000       20
#                   Clubbing 11  4  1 72     0.7333  0.9167    0.8148       12
#               Healthy Nail  7  2  2 77     0.7778  0.7778    0.7778        9
#            Onychogryphosis 14  1  2 71     0.9333  0.8750    0.9032       16
#                    Pitting 12  0  4 72     1.0000  0.7500    0.8571       16
#                  Macro Avg                 0.8780  0.8755    0.8713       88
#               Weighted Avg                 0.8987  0.8864    0.8871       88
