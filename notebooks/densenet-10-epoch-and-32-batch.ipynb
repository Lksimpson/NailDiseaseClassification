# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/nail-disease-detection-dataset/data/validation/blue_finger/Screen-Shot-2021-10-15-at-10-44-09-AM_png.rf.fa5059ea7a03fc7853fa574ce5b05a59.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/blue_finger/Screen-Shot-2021-10-15-at-10-40-07-AM_png.rf.ce1377336d3cfe8a5956c7822d0f3536.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/blue_finger/Screen-Shot-2021-10-15-at-10-43-24-AM_png.rf.d7cfd2a2eb508c0cf55d67a6e482e83f.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/blue_finger/Screen-Shot-2021-10-15-at-10-44-24-AM_png.rf.0fc15e7d1ca7e1dd1009010d21c4b025.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/blue_finger/Screen-Shot-2021-10-15-at-10-44-09-AM_png.rf.9196975a777207fee17ee744f60d81b3.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/blue_finger/Screen-Shot-2021-10-15-at-10-41-24-AM_png.rf.79aabe37924d244e8c96e49f030e57bf.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/blue_finger/Screen-Shot-2021-10-15-at-10-43-24-AM_png.rf.97c573e8bf4dfa915df53fa99e3b33fb.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/blue_finger/Screen-Shot-2021-10-15-at-10-40-07-AM_png.rf.ac1bd481a7768d536d4b898885ff708f.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/blue_finger/Screen-Shot-2021-10-15-at-10-43-29-AM_png.rf.5ad468e58cd936dc0d5306b02e2c5be6.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Acral_Lentiginous_Melanoma/nail-melanoma-2-300x180_jpg.rf.15e478ceef3c930f98f08d67d4527183.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Acral_Lentiginous_Melanoma/p-1-womans-story-shows-why-you-should-never-ignore-black-line-on-your-nail-1506429403_jpg.rf.88ee9943b08313dde0aa6071626e751b.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Acral_Lentiginous_Melanoma/hutchinsons-nail-melanoma-Nameer-Al-Sudany_png.rf.6e0ffcf4ec169817436e1047a6992284.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Acral_Lentiginous_Melanoma/nail-melanoma-2-300x180_jpg.rf.4237689a19295abc7320a279a4b298ce.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Acral_Lentiginous_Melanoma/images-2_jpeg.rf.910b53e8e95fd8ea08e1434c93b1c5b2.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Acral_Lentiginous_Melanoma/RB-Tiny-Red-Lines_jpg.rf.8bf867d594a337fadb6dfef4a9b9bf0d.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Acral_Lentiginous_Melanoma/Screen-Shot-2021-11-16-at-6-57-22-PM_png.rf.c6ddbb3ca1ef3a9137645c8c21712bb9.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Acral_Lentiginous_Melanoma/p-1-womans-story-shows-why-you-should-never-ignore-black-line-on-your-nail-1506429403_jpg.rf.5132c5b76fc63ee817884973ddd0d005.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Acral_Lentiginous_Melanoma/images-2_jpeg.rf.0b82ab05e3199fc2d90c01a77d9aace9.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Acral_Lentiginous_Melanoma/p-1-womans-story-shows-why-you-should-never-ignore-black-line-on-your-nail-1506429403_jpg.rf.7183adb8f5934f917fab4e14667c4bb0.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Acral_Lentiginous_Melanoma/hutchinsons-nail-melanoma-Nameer-Al-Sudany_png.rf.0ac0ae87f994c75ff150cba6897a5e72.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Acral_Lentiginous_Melanoma/RB-Tiny-Red-Lines_jpg.rf.2b83f979a518747791c04cb591535176.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Acral_Lentiginous_Melanoma/Screen-Shot-2021-11-16-at-6-57-22-PM_png.rf.5d2de4abeddea0fd6d4eb47c0b67e0a8.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Acral_Lentiginous_Melanoma/hutchinsons-nail-melanoma-Nameer-Al-Sudany_png.rf.bd1235ab3ab9ed9109c4ef4abc5732a1.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Acral_Lentiginous_Melanoma/images-2_jpeg.rf.3a816d1c560c64d563ecef354b17bc50.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Acral_Lentiginous_Melanoma/RB-Tiny-Red-Lines_jpg.rf.680472f52d5adf5a1d4193be5b7e4b30.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Acral_Lentiginous_Melanoma/Screen-Shot-2021-11-16-at-6-57-22-PM_png.rf.ec6e992690d1addee83ca314a263ed66.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Acral_Lentiginous_Melanoma/nail-melanoma-2-300x180_jpg.rf.a96c7a57e883bf173a9119a2b7895a49.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/pitting/120_JPG.rf.eb7386574801d4346d6095d61decbba6.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/pitting/108_JPG.rf.40d1720769393f88f2f33a1551a3e2f1.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/pitting/113_JPG.rf.e9450e0dbf3a0e3b588abe6cbbf9bd09.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/pitting/126_JPG.rf.372fbad28457b8da7cbe482df957c190.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/pitting/108_JPG.rf.8dab79a581652b65c98389790e2f67e5.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/pitting/120_JPG.rf.7e92fa0a785de7b96cfdfd951ddc558e.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/pitting/115_JPG.rf.25da2042a343b93974bce8a64d98a236.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/pitting/124_JPG.rf.50d57fdbe05ba48917dd86dbd38e35e2.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/pitting/126_JPG.rf.4556e9cf4e9ceaf8c811e994d363df47.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/pitting/119_jpg.rf.9f1597f0ea6e5b3700cd38b147f8d8e9.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/pitting/115_JPG.rf.1093c0f6850fd6e600ee619e45f86d0f.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/pitting/105_JPG.rf.d6b40c812af4617716bf95eeb085b269.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/pitting/115_JPG.rf.83aa064b00b75267b31fc93cc40b6285.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/pitting/108_JPG.rf.2ec505974a0d5d9aa69deb3579f03cfd.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/pitting/120_JPG.rf.4b7a830667dbb013fbbbd20f1b1f4bce.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/pitting/126_JPG.rf.8e3c38017672c29a316b3884721fa786.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Onychogryphosis/images--MR0O0A_jpeg.rf.4fd2f4644605791d9e9456a757be5de0.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Onychogryphosis/Screen-Shot-2021-11-16-at-10-24-09-PM_png.rf.15c05ee3965fe8fabcc8622211aba223.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Onychogryphosis/Screen-Shot-2021-11-16-at-10-24-09-PM_png.rf.3cf9ffe19e72c75e212a20c3214147e6.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Onychogryphosis/Screen-Shot-2021-11-16-at-10-39-52-PM_png.rf.516df24e53038f9f31e2bca0af74ff48.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Onychogryphosis/images--kZUSGO_jpeg.rf.d5f5667447c95de60ec7666d03dd2c9c.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Onychogryphosis/Screen-Shot-2021-11-16-at-10-39-52-PM_png.rf.0fb64414a31216bbf28bbe3ac612ecee.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Onychogryphosis/Screen-Shot-2021-11-16-at-10-23-59-PM_png.rf.ba787af7af07499d7f481c020332ac2a.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Onychogryphosis/Screen-Shot-2021-11-16-at-10-39-52-PM_png.rf.7b51706dfce11ca4bc62a6b79ef1d3e5.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Onychogryphosis/Screen-Shot-2021-11-16-at-10-24-09-PM_png.rf.864ca33e07c8aca34ad661182541cce1.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Onychogryphosis/images--MR0O0A_jpeg.rf.087a40051aaf227ed846457e98a916de.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Onychogryphosis/images--MR0O0A_jpeg.rf.bba5a691e7d60e48e0001f20a1864809.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Onychogryphosis/Screen-Shot-2021-11-16-at-10-37-25-PM_png.rf.d4a08a5b6c448abedef2857ace6474a4.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/clubbing/Screen-Shot-2021-10-26-at-11-11-50-AM_png.rf.4114ba76118d49941b7bb51d98eafcb8.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/clubbing/Screen-Shot-2021-10-26-at-12-10-57-PM_png.rf.13d80dc781bd7e9b4d1c2c67ecbacb55.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/clubbing/Screen-Shot-2021-10-26-at-12-10-57-PM_png.rf.0873270d15ef63fa42d0840d1b0e585f.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/clubbing/Screen-Shot-2021-10-26-at-12-10-57-PM_png.rf.b54d6f7d9360ad44ad10b4b719f5ff22.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/clubbing/Screen-Shot-2021-10-26-at-11-18-39-AM_png.rf.117075115306121d1a9cc3cb2e79b8c5.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/clubbing/Screen-Shot-2021-10-26-at-12-11-28-PM_png.rf.4f993b88f526fd3ce51dc24eeae5b4d2.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/clubbing/Screen-Shot-2021-10-26-at-11-12-59-AM_png.rf.3225bdddc077d3d57fc649823dbd53fc.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/clubbing/Screen-Shot-2021-10-26-at-12-07-03-PM_png.rf.3704ea52b01c388a10d017d4eba90738.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/clubbing/Screen-Shot-2021-10-26-at-11-18-39-AM_png.rf.178001a8e5d2dff5552d35b093b7f47b.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/clubbing/Screen-Shot-2021-10-26-at-11-11-50-AM_png.rf.b2d73c991f1ccea144f06be455b8a88e.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/clubbing/Screen-Shot-2021-10-26-at-12-07-03-PM_png.rf.2a2d2f13976b58b491b4eda7ae861da6.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/clubbing/Screen-Shot-2021-10-26-at-12-09-28-PM_png.rf.1b2bfb63b6e848f2cb0257c23a2a356b.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/clubbing/Screen-Shot-2021-10-26-at-12-07-03-PM_png.rf.3514795dcb0a1e7bbbd78fd0acc2ac7b.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/clubbing/Screen-Shot-2021-10-26-at-11-18-39-AM_png.rf.28dd555e879ae0cbd28ffafe036d29a7.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/clubbing/Screen-Shot-2021-10-26-at-11-11-50-AM_png.rf.fcad66ef67b557cca35f7e088cc4934a.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/clubbing/Screen-Shot-2021-10-26-at-11-18-43-AM_png.rf.6fa0f7e99b108258c846126dd57821b3.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h16_png.rf.544a7f60be3a66bac16b65327a54a313.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h28_png.rf.703767728e747d391e99c44cf7f8eb55.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h40_png.rf.fadb0d18801992e95a4be37f7b0f19b7.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h28_png.rf.6da7a98cf8f462565e2ca7c506c1d6ae.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h27_png.rf.a132936cf5a62b232230cb627aca10e6.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h14_png.rf.9e48f154edf68fa4094ba876c23615f1.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h42_png.rf.16c0757e4e7efb45784ff84d76fbc941.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h27_png.rf.9b007d56afacd71d36f9bde6bc96de28.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h16_png.rf.ca2c70dc94af5e37bca2fa6e716f2436.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h41_png.rf.48945eda8b3b22a8f1accd95df84d4a7.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h32_png.rf.b85221a5be1d5dcbd6ed6f8f2036df6f.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h33_png.rf.b300a39e8d6896a2544016da61d5bfe0.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h34_png.rf.7d264f62efdf1b4431a119912742cdc6.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h33_png.rf.c731aa01b059058e8fa6c0b62238c493.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h41_png.rf.e4128998582761f8a7ce0571c70bec8e.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h34_png.rf.01d5a5820b29d21fdfbf29e9d3ff4718.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h15_png.rf.1cc449363f93785079ef9d41f25ff57c.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h23_png.rf.c7c509ee51e926570eef01670971a12d.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h42_png.rf.70cfa6398ae4af341c1c2b70625034fd.jpg
# /kaggle/input/nail-disease-detection-dataset/data/validation/Healthy_Nail/h15_png.rf.dc966fe377b6ddcba1d8cfb34e157f3b.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-10-09-51-PM_png.rf.b35fb792d1ff4d32d52ab7baeee617fc.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-10-09-28-PM_png.rf.fc6645ce881f95b6682f6958e5acf20a.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-05-43-PM_png.rf.d2a0a8780d0baba489dd43395501bd74.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-21-29-PM_png.rf.e589731e8ddd65cbda152ddb37d73f85.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-10-09-58-PM_png.rf.f357adca933ff843d33f651fea90a597.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-49-53-PM_png.rf.29025ab2b34a5f4653f7d1baa9c69968.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-15-47-PM_png.rf.453b26aadd417920db9cf3e70c292827.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-07-19-PM_png.rf.373e52099ee52b0ae8fe61391cdfbd6f.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-42-05-AM_png.rf.048c08823c937895f93937607c38339d.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-21-20-PM_png.rf.4b082b27c403e8a932b856951650803d.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-00-19-PM_png.rf.12f586458fd2f0f448d41fc8f26eb8dd.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-11-05-07-AM_png.rf.34b8542606bc0dd84e9167e389c403f7.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-55-27-PM_png.rf.9a004ad0550f5324df7f420a51f290c6.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-11-11-25-AM_png.rf.e71f3c9923a9c0976479cf7a61c1e3bf.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-46-00-AM_png.rf.2e4c70496b85936f560d23039a4c7448.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-21-08-PM_png.rf.8d1d70d5f6f782b1b2e3208d83c4a028.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-11-11-16-AM_png.rf.abb7e53099b9167c9c3665332cd601ca.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-51-05-PM_png.rf.9cfdc69d9472cf594da6d913eb3a1c4c.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-51-21-AM_png.rf.c17223659c288b600fce028b001f004a.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-50-45-PM_png.rf.09f6901091920ba4e757969e9a61a283.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-01-41-PM_png.rf.b9405f7d08247ad59b160c9fa9fc9b1a.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-10-10-41-PM_png.rf.7bcae8bde7efffb4b54a144c2aedc458.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-21-43-PM_png.rf.e3b8328443edaebff648fcf6fa74d370.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-36-15-AM_png.rf.630e34a3991ea4e3cbe7687696b545e0.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-42-05-AM_png.rf.4b2f1c256e5f561d5d27d136d413d761.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-11-05-02-AM_png.rf.24fb0d62bda522b7d13f6621cbddfc1c.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-19-49-PM_png.rf.6f4171ec0431ad53a109b6e8cd705aaa.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-07-12-PM_png.rf.bc8c531c45d15848e8c6ee6afc9ec7fe.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-44-09-AM_png.rf.566ededfd4f7c5eba89b0fb37afbb544.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-53-45-PM_png.rf.11a09014fba4bbcaafd38ad76da196b7.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-11-05-16-AM_png.rf.aa6fee8dbd60331ab76537a394bbdf43.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-07-23-PM_png.rf.b7e97f377b232a17ed2321aef4f03dd1.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-47-18-PM_png.rf.069f1667c292d234d46966e21d22f3d7.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-52-25-PM_png.rf.fd524079b504bd4e40b2269140882b48.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-53-45-PM_png.rf.b4b0b36d101ec924989ee8e34f81702a.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-30-06-PM_png.rf.01c80da6122271d76cfa18af1e1535d8.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-45-42-AM_png.rf.326d4f81e4fec4f8bf52c5c762b9451b.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-25-04-PM_png.rf.25d6e55cc5866bc4932c0790d5faeb07.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-50-49-PM_png.rf.064f6a290bd872243874470984ac6f94.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-49-11-PM_png.rf.a2e7c3e114e96a80471bf0f7a58cf989.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-9-40-58-AM_png.rf.6ad3f46677a65d13fe1a7f9a0d4104c8.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-03-08-PM_png.rf.ea0cc3e6158ec384aed9407e557a1533.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-05-44-PM_png.rf.a8b205d721eae0446918863d0bf422cd.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-16-04-PM_png.rf.241b8d4678c7b43c94509c0cb83781fc.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-10-07-05-PM_png.rf.16029e355eba3a789cadc8c50a2b07b4.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-51-58-PM_png.rf.ae553ccaea075888db7092efd4ec347b.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-45-38-AM_png.rf.2d03589b251827c76e25a183e87873e1.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-53-39-PM_png.rf.1eb11664c930e495470bc688109e2708.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-10-19-PM_png.rf.5d4de7ded1e3613e6827276b87e5d5b3.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-16-04-PM_png.rf.30f19cbcefc372afd61695ade7157636.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-9-40-14-AM_png.rf.2609ebb74c1ae5140c956be069097d9d.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-51-13-AM_png.rf.c8b53ab79fdafea8067f3bf55557b23c.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-00-08-PM_png.rf.c1d808cb3972ce7daae8632fbfb13a61.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-47-28-PM_png.rf.39445ca31785c1ece174a56fc010c839.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-57-57-PM_png.rf.5e60f5c9942f47b5ca03cf5e2f450700.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-38-28-AM_png.rf.46f700175938fe100e267e4d3781404d.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-07-12-PM_png.rf.e63beb0b46db426ba8161939cd85761f.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-10-19-PM_png.rf.cbd1ea6045847d8dc5dbcc77046facf4.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-25-46-PM_png.rf.c9f48c7ed14ce218883288b1e304753e.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-52-19-PM_png.rf.eda1002a60f66d3f1e38887d379a6037.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-47-18-PM_png.rf.01ea3869f8ad74d5a9ee15c7f87fb12e.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-57-57-PM_png.rf.b8fc2bb82beaedb22c62ebaa6310fbad.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-11-21-PM_png.rf.254b662282421dae3d7ddcbd791b7fd7.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-44-24-AM_png.rf.476683395646d58920ac8a787b12e749.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-48-34-PM_png.rf.ce0915a5ff1d49edc66f9e40d76f1b0a.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-26-19-PM_png.rf.a7b78792bd969b37120c8bb618d88a30.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-00-12-PM_png.rf.0c8958d3ce02986257205be339e956f8.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-11-10-19-AM_png.rf.8345a4818c1913a7452bb35edac083b2.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-06-52-PM_png.rf.105601eb6b92150f522b1c32de5b7ebb.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-56-36-PM_png.rf.7d8d4e4c9fc1169626a891e4045f5805.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-22-55-PM_png.rf.55ac278ab886a5c04c1e6190207e4927.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-51-01-PM_png.rf.346ec8019e02e4a28d05443efcdc5b2e.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-51-58-PM_png.rf.955b42bba7c2eef8920d85795c3c160f.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-38-58-AM_png.rf.630a1aa590f81ee260f56c3cf1bc34dd.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-05-43-PM_png.rf.2000f89abed8261809c9c22aaefc1a98.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-56-36-PM_png.rf.b95298004c99cf60a837116cc391655e.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-11-10-13-AM_png.rf.4da16e750ba76f7575b8a15012648f75.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-36-10-AM_png.rf.f581f7db3527e733165b351385592330.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-03-11-PM_png.rf.68d2bef07f74de0699f85b1410dface5.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-17-31-PM_png.rf.8038e79d0b3027bd3b4914cf431b3f9e.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-05-36-PM_png.rf.bdea4f06408e42f5b0bda7a0ac169815.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-56-47-PM_png.rf.8d7a4b2442fbd6b0eb3c1b5caa778826.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-13-05-PM_png.rf.9073f7a91050b02dc2e6d7924600b7f3.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-06-52-PM_png.rf.11fbc2c16f5785e3fed3f5868fe8f46f.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-27-33-PM_png.rf.244361e86167343819816cfc71d66bbf.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-07-23-PM_png.rf.f9ce32b0c67585013b33193d0c0fe3ff.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-52-28-PM_png.rf.5fbfb09ce288bf9a626d87bc6a112df1.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-14-11-PM_png.rf.e4fe62bc2f687c1df175d0a19780aa49.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-52-25-PM_png.rf.85e19ee211404e3f664d1aa89924dcb2.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-25-46-PM_png.rf.86edbb2883660f955777a5d980b79576.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-06-03-PM_png.rf.64c009ed38f4e72b161cc0b488e5b062.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-19-18-PM_png.rf.5b65c72771d63f6ed8e08fa9d3dfab09.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-9-30-50-AM_png.rf.01a0b573ad637eb8c8e635e2af97687b.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-18-57-PM_png.rf.ddc7ded4a3ad0c5fc54c8223130b04d5.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-05-44-PM_png.rf.e7dc8a7529828409c6abf084a909ab63.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-50-57-PM_png.rf.4be3bee3fe22bc58412c333f9445a29c.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-18-17-PM_png.rf.9d418f1c5af68a512c4353b980e70f30.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-06-59-PM_png.rf.38da7056220e4f2a537c02aa1da41f37.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-17-34-PM_png.rf.87366cc04fcf9742a84289d59659b61d.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-10-09-17-PM_png.rf.6e3b3e8d57af2af1c7299e80aef391b0.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-43-43-AM_png.rf.6c50787b57cda69b76af2eaf659f507e.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-46-28-PM_png.rf.8e4a4d79c020dde1905d793840b1a018.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-00-19-PM_png.rf.823861b7b71a878d8bdcac8352df95c5.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-11-05-07-AM_png.rf.eb4b1322eacc8af297f605ca7535ec47.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-06-00-PM_png.rf.47e1c3e28d373e730b0c37e2bae8060d.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-42-05-AM_png.rf.05ef6fbab5357f407982ba2cc79c1c4d.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-15-03-PM_png.rf.379b82047ab835907bf0595e86302c79.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-22-07-PM_png.rf.a1d378a55d47c364fc0a76bb561ec87c.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-51-05-PM_png.rf.49df55920e4cd067e160fe0cec9c9742.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-48-57-PM_png.rf.76a5f9d036af93305301083e5c3d1f12.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-25-44-PM_png.rf.9f21cade77022c641ca21bc69c056443.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-14-42-PM_png.rf.e994b6e5fb438f2cb7bc307956a9d162.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-9-40-42-AM_png.rf.5b0f3309cbcd0da687f043279ea63bc1.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-03-01-PM_png.rf.9e048cd8f250acdb7038910d38a89d64.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-08-51-PM_png.rf.f1a8a9ea2ea08b665914dbe1964d046e.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-9-40-14-AM_png.rf.50fef477de41106977635fb51fb00a0b.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-52-28-PM_png.rf.f9132516c927a58c64706d4e9426fe60.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-9-40-14-AM_png.rf.1b169b2ab18ead3ce1367fa94645154d.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-41-59-AM_png.rf.0449668d891b2f25cb581da64db629fb.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-18-28-PM_png.rf.40eefe22bbb965ddff860fcbc05408e0.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-57-37-PM_png.rf.a3f1f7f9266856afba79785c1028f16d.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-49-11-PM_png.rf.3f7339ec091545c461dfaac7107678c5.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-11-21-PM_png.rf.54e125bbdac895774eb0be5b5901c880.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-18-25-PM_png.rf.876fbc17e9f2a28bf55ba43d1a2cb821.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-02-29-PM_png.rf.a72428e0df790a8f2d2a48c9c209fa96.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-55-16-PM_png.rf.40e9258124438ccdd42758f4daf831df.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-10-19-PM_png.rf.ff4d9e4f97fbb7230f3cc9969e097e4e.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-10-10-34-PM_png.rf.90c372cfaa609b790b8807e55e6bd3e1.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-22-07-PM_png.rf.30f14805bfd40825b3b1988f0f7c9eb5.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-52-22-PM_png.rf.b23cbd970380f38ba9248ff79feefbf7.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-50-08-PM_png.rf.fe6825edf419bc7da852fefaef39d910.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-51-21-AM_png.rf.502f394d4bbef8824cbd7a68cc4bd4e8.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-26-55-PM_png.rf.cc0c70c624838d743c1d75045ffa7dec.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-50-57-PM_png.rf.ee5b49939e4d77717ac97748bd84b819.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-21-16-PM_png.rf.3d91d82844db3c62c756fcf83380dc86.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-11-11-08-AM_png.rf.ed88dd9ee58ecce94a8ad6df40f70b1f.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-21-33-PM_png.rf.ba57c742489c18d91cf5898b6e92586f.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-51-34-AM_png.rf.8e55a7d552035e0a595b2436179b26c1.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-11-11-08-AM_png.rf.a2bc7e8dca77a012adc147cdd086447b.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-18-25-PM_png.rf.8022c86daf89465d014b87660785135b.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-51-13-AM_png.rf.1188a13bb6645b2bd2be529a1f9558e8.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-26-29-PM_png.rf.b4ad0e5b8c86c9bea3a46075a6f6542e.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-11-26-PM_png.rf.ed370a22d238bd703d7ba453ffba5e5a.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-10-06-33-PM_png.rf.61ff005cb02a6076cd511fb864fd12f8.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-13-05-PM_png.rf.56c8ac2ce68e52efb8ea44f80b0ec2c1.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-9-31-06-AM_png.rf.53629f0f52d8f93b7c319b6890a93d25.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-09-59-PM_png.rf.7a9cc921dfffe97ddfd84b7981918c4e.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-43-46-AM_png.rf.020015f536c0f6cd8b87421b50930bf2.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-27-33-PM_png.rf.7eb53bb2d11e237febfd34866f26bc71.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-44-53-AM_png.rf.7a05ab50a8c15f196ef600bac0fe2fbe.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-57-46-PM_png.rf.3935e375bc5086b7499b13063773080f.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-15-37-PM_png.rf.45ddb66565aea88e0adcd5499dd8c2f3.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-48-57-PM_png.rf.56d80482d60ef8600f34299c839be7c5.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-10-08-12-PM_png.rf.ddf2c95a89999913c64bd2d175ea9236.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-07-07-PM_png.rf.37aad7959a09fc9a3b3875b5a9e3c34c.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-11-17-PM_png.rf.2c5e912db9732da7ff341362e9cc56db.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-09-59-PM_png.rf.1c6a1bd2cbb3d89a30fd2e7f31af107d.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-10-08-12-PM_png.rf.3e480dc49841582d8d338d0243aaf5c0.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-26-02-PM_png.rf.c6b8a65114a9e1b5354a55f23f1acc94.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-10-07-PM_png.rf.15ea6de8993357568365d6c4430f3c9a.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-21-16-PM_png.rf.9aaa9dcdd55ab3a71251cfa623f06d73.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-09-59-PM_png.rf.3734ea96fa04a2f97710416b20f0691e.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-11-17-PM_png.rf.466a3c2438e2b92c3ad377ac73a85da6.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-48-12-PM_png.rf.053a264251be1a0ec09ec9bfc2afbe6f.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-53-45-PM_png.rf.669d5f436a1f6a60f14d1243dd4a528c.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-29-07-PM_png.rf.9f90b801c0353bbfe70355d420c6b1de.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-47-11-PM_png.rf.e152b0aa3b42440d67f67aa6eaed9c45.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-10-09-35-PM_png.rf.5962882e0ab125da4f3990c04789751c.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-10-10-02-PM_png.rf.ff3bee7eeb3f9538c504b46daa76d73e.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-18-25-PM_png.rf.79457b9c3d4fa8edb7e2a11c04766ab3.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-40-02-AM_png.rf.87b5e0e1cbf8843724af2ac763277fd4.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-47-06-PM_png.rf.98cedb408337db2d4af1e7fd6290ea8e.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-48-08-PM_png.rf.6483044ab047ad311fe0bfa45fba365b.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-19-45-PM_png.rf.ae393a5c9b194f7c1f831fcb3dabaced.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-10-09-35-PM_png.rf.74b49657d13d160bae632c0a407871ed.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-29-14-PM_png.rf.15cce7dd0f484d660ab9f35e058cee8f.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-25-44-PM_png.rf.dafcba6f88b3de41a8a604466b101f9b.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-57-46-PM_png.rf.265aa238990e41e7f05f49c5f592c6da.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-29-02-PM_png.rf.d19427d6ca740fd1b5a679eeb72e9a0b.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-27-50-PM_png.rf.de1e50512c0cdb84d44f1b8faa7f14b3.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-19-22-PM_png.rf.e5bef54a84f6a61a48c25c5654f03309.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-51-21-AM_png.rf.45c71bb267dc9c831d4766bc3a8389a4.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-26-19-PM_png.rf.48e3d54d7a767ae0b02114e05c368fed.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-14-11-PM_png.rf.591af90032256219d10cd40204c3e040.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-02-19-PM_png.rf.178e7be25e6d5b4825dbeef2bd552baa.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-17-24-PM_png.rf.7330c1082d7a5312962c31053461d2ea.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-17-34-PM_png.rf.adfcc87ae941bf75b8ddf22c405c94ce.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-44-53-AM_png.rf.98ae4d9cca4e1348cea4db88f1450495.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-9-40-42-AM_png.rf.009a89f9f6f86460d1aff6f5aa4f46b2.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-05-41-PM_png.rf.d66dc6eaa47882611fb807a638bd93ee.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-15-47-PM_png.rf.41441eb32a11a4aa4fdbe12dfae48e5a.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-18-20-PM_png.rf.6a54b12f85962ae547483735e84a53f6.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-4-49-53-PM_png.rf.bc4ee4fa65d3db032d6c73248fda436b.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-48-08-PM_png.rf.b8d10c7bcecb25a76368119160145050.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-06-33-PM_png.rf.e7022f324855dcaf8a9e5c58e9954447.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-46-32-PM_png.rf.d318e9707f195d29d9358dee46ff72c6.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-48-12-PM_png.rf.c43e2a20099ea54120061f0d2cc0f8d6.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-40-02-AM_png.rf.565c0203d68af2847372ad3fa8983960.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-9-40-42-AM_png.rf.bbe7162e8dceb1ca21b83ef485a3efcf.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-21-43-PM_png.rf.e5497dacb4f30b5fd7ab78a6618eaadb.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-47-35-PM_png.rf.505a66d48d60cb030e85e72d119e7f37.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-46-00-AM_png.rf.09c87bd93e98584a54f91c6b9e5bc071.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-11-11-08-AM_png.rf.3fabf08fbcf6e0033d5bbb263a11e2af.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-14-49-PM_png.rf.2278b7ef5dde324b942ed5b45d909116.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-48-12-PM_png.rf.15006792f8619263e4aab3bd34b87f80.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-06-03-PM_png.rf.97d1956f4642b8f9a66b948894c0309f.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-8-11-26-PM_png.rf.fbe81615c8ea3c20f323293a3c5e872e.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-52-25-PM_png.rf.28dc3fc0c823c2c648b4dee9f52a5c94.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-10-10-41-PM_png.rf.3f0411354c2c0f60f2573c68d2e04fb5.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-46-00-AM_png.rf.a0d8d4ebfd3119bfa53cb2dbd010f6b8.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-39-17-AM_png.rf.7bcd41c0521cf43efdc68d3ebf649a79.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-26-55-PM_png.rf.bbccd0834da773b3ab29ecb74e7d5eb7.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-11-05-16-AM_png.rf.6eec4b606ffd42ad78eee5297b7a27cb.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-08-51-PM_png.rf.afa7815a63fb70981fea3b81a71d6105.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-11-05-02-AM_png.rf.6f9d76e0ff4f50ba55c07c29be26222f.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-07-23-PM_png.rf.34e83cc1f8c49234d2b03cee4e275bc4.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-10-06-28-PM_png.rf.38ef55f9d27249c222944c5e51c80fe4.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-39-37-AM_png.rf.3cfa1f6010b3ff435758371214ea58a7.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-36-15-AM_png.rf.07fe9e00799550cf0f7834112b8b1a9d.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-45-38-AM_png.rf.f228ad6354f46e1a1b711e572f852752.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-27-22-PM_png.rf.5d0d94967de6ec88184d00d361245754.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-36-37-AM_png.rf.227669e2b2368073a855df3e61632938.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-50-05-PM_png.rf.9a2574774862d9f7149ef32fa3b84f33.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-38-53-AM_png.rf.9a97e42cff1827ef3cc84a2b8dab33c1.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-10-06-57-PM_png.rf.f28f26b0b8dcfb826bc2d2c893076983.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-36-37-AM_png.rf.5f92dc76065c8ba870e0269cab99afc7.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-27-36-PM_png.rf.04508b66fbd4b04b01fc481375e7e8b8.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-06-56-PM_png.rf.36a82022f24ece9ea6ab485d77a6d183.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-26-02-PM_png.rf.c2ecfc9546eeec9c03ce32aadf4150ba.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-9-46-05-PM_png.rf.013717b068a0548f1a23f12a1f7cd09c.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-9-31-17-AM_png.rf.c3fa5d65339c3d1278758db86b6a77d0.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-10-15-at-10-36-46-AM_png.rf.bf9f623157fffac83f1c47476459b956.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-10-10-02-PM_png.rf.39d01b7ad323e211dbc2eb29cb246b74.jpg
# /kaggle/input/nail-disease-detection-dataset/data/train/blue_finger/Screen-Shot-2021-11-22-at-5-26-02-PM_png.rf.bf53966750be2dcf733d84487f188e90.jpg
# ...
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h215_png.rf.0f8f9e2d157f712e7f440d8ca0659344.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h52_png.rf.8d894b3243e710d78be4ff0dc783bb61.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h47_png.rf.11a696fc711997ed0686552a66657df7.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h253_png.rf.c68dfa44f01cbab7b6a4c25d32ba1763.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h172_png.rf.b61c05f50f07fc49349fbd692e819788.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h279_png.rf.2d16e6ce368e91ef38dffd1678d57344.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h118_png.rf.247d6937c0d9ba74e56c2ee9498efd50.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h260_png.rf.f2fbef94c6dd26d8acbc91d79f994d5b.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h80_png.rf.b4eb41089333cc699a2133904f621ccf.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h236_png.rf.a5964c44f4597ae5bfcbb796ce3c75c6.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h39_png.rf.1317842d60a66973c5ed9fc49ee57206.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h262_png.rf.d6c2ea839ebcb529044e871f00fb07de.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h11_png.rf.74636675cb087ccfcf925696bcf8e6f0.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h254_png.rf.48232775e2bf1392301404126fec44d8.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h87_png.rf.9ce98643ff5842481e3a634daa723b3c.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h13_png.rf.07bf345415a5036d5f933293a543c2fb.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h239_png.rf.962a2a1b6c18b8cbff530a0ab7a51a44.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h193_png.rf.e8aa84d8ae3cbeba1909040644dda647.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h78_png.rf.86e063d5a0687c35004a0eadc37d0d86.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h227_png.rf.7738a1c9dce225e1def7d7f364708366.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h90_png.rf.f3495c3eb27cdd59cef1758f089dc336.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h241_png.rf.b818d63106e1591cc2925fd004fa975a.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h61_png.rf.9991b929612f1c1295f496f4d4f9055f.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h122_png.rf.91ee26e4775dd4eba2b455291b9f9469.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h225_png.rf.c61f202ac2e556310cb1e397724f7f30.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h61_png.rf.552163a6f04105e3843a5220c98ce2c4.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h287_png.rf.13ce89991698acbba2b72de1a24c1f21.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h91_png.rf.4f1edf9810956aabd7e91e9f205e93f9.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h164_png.rf.fcf1664ea94d8702c705aad760f81d2b.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h204_png.rf.312322895ea1606c3fcdf82edcf3970d.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h206_png.rf.e0313adab321f8ad9c2292c0794faeda.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h254_png.rf.e5029515effae0d5529bab0333747afe.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h120_png.rf.be42712f1572fb1cedf0c459d8c6c12e.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h215_png.rf.3cd80f8d935c1e6d06d2206104377eee.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h29_png.rf.0389b5023edcc96d79d9a61db69e9425.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h187_png.rf.c869995a61f47b663aa84cad4dec9084.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h149_png.rf.d98edc1af2b1bc9a01480ca9500a849b.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h139_png.rf.d49706dd9198a3b97dbc61179887a4d6.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h214_png.rf.d0578faea0f989269b1ff29557f3eaf6.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h133_png.rf.d15b8b1929136d409a109e3010250474.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h203_png.rf.150d733fd3a4473e50864487e6571a31.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h239_png.rf.8f9c9e3c56bb0ad2a251cf0d1d5adbac.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h198_png.rf.4b0dc37f37a55cb453d7cab97297d74d.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h202_png.rf.a51890b186d27572c17c00bcdea5d548.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h58_png.rf.4fa3217d68dbf56a8e3fe4da5806f925.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h277_png.rf.6d28c184b655dc37507f4c05c932e579.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h201_png.rf.703f8a4793987a72ce39dac07593cb3a.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h243_png.rf.807ce9faf59d3a6aab8b4c0a3f995cd6.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h82_png.rf.16201cfa37a0f90feeea767113ce70d9.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h200_png.rf.13175718027e6970f4d6bf5219118ed2.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h144_png.rf.5036007dd2a54714d1ad8462006d8f6b.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h162_png.rf.7be3a78f4b4a4ab1db12ae0eb0876d81.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h49_png.rf.db6e9a0fe2175d2a82c4cddbaf45d827.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h231_png.rf.3eab9e31934144f83bca4c59be86af1a.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h96_png.rf.a86bf7b86aebb82a11f5f310ec8b0365.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h261_png.rf.29322429ef1fe3498a706dd1b1b7743b.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h94_png.rf.28b247a7026c205d5fac12f94c9eb0d1.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h161_png.rf.edfd3c4123fcd7262eb94b254e1f1ee7.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h192_png.rf.1346d430dcdebb22f31316f90aa4e612.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h9_png.rf.4a11c4365a9b6e4c3a7ba8dae35f0236.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h213_png.rf.194bc06fd233f0a7a7b4b7b5ebb11103.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h169_png.rf.a9619babd848f85548ab0c97b549f890.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h183_png.rf.29bfe60873ddb26daf1a08f04172d1fb.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h50_png.rf.f97d3f64fb68832546289314c7509963.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h228_png.rf.2ac9afc41532be731f528113af9805cb.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h163_png.rf.a11236d665124d14be9567160117a634.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h9_png.rf.46012a4bda464392a96a7e1c54ab8fa9.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h242_png.rf.999e6aadc3afd0f42024793110f883ac.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h194_png.rf.12fda15fd0cdbe0ab56aa9170a69d499.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h53_png.rf.a395cd41b3201ea7ddf73762e4f42903.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h110_png.rf.84ba1cd9dca9edfd159c0f7e76453f8d.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h271_png.rf.b0c9b5c6ac365a40c2a69202260f0a01.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h153_png.rf.af080bd4eb53dd96cb09d2d97c2f0a97.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h71_png.rf.04f738cd92eb9e66495d71a6f42653bf.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h194_png.rf.36959e1eb76fb93563f5ec232db1b909.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h45_png.rf.ab5e1ddce36707185521a8c2686ffdc5.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h53_png.rf.83b0ac2c88cc382fb8749ca92352cbc7.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h63_png.rf.65db10cc4e0fa918d2198363da4ffb73.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h129_png.rf.6a842e5a1f792a9de2470a8379efe6e1.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h133_png.rf.4c51304845bc79457f299cc328d827a0.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h40_png.rf.671dd1b753b1a1e3de51363e34673e80.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h130_png.rf.8acac3613aa3cbc1acf1f1e2db7a6a95.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h129_png.rf.5c0f71e54be0103c4240a49d579cec47.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h156_png.rf.16a36faf90963d495bf9253a70dcdb06.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h32_png.rf.359367efa0a82fcebecb401b28687641.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h174_png.rf.fb11729ca47ca1e7e47d7d368939a56d.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h147_png.rf.bd7032ed9dd526c85b3579e1b3c9d5cb.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h63_png.rf.b8044c4edc647671cc86a20fb45535d1.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h148_png.rf.a75da4e2435f174e8b90f4f89311887d.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h7_png.rf.d3e5329860a2f1204ffcfa7f7b723337.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h104_png.rf.a9d878a9da04641c85603d3e42c8360a.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h154_png.rf.020818914e9e98b6527a920b364953ec.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h123_png.rf.e99a0fe34b92997dcde8ce1d44853444.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h180_png.rf.6a23519fd10e3c7cd815c6477e5a60df.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h131_png.rf.42f1e50a8cd3ccce9bc6938f13ba69a7.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h132_png.rf.f837aa21de478ec2bff354d8fb39afff.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h135_png.rf.0f26330d76367f663de7a74449795fcb.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h31_png.rf.59c4192cb298ad94ccb7db7981f162fa.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h97_png.rf.6e5a919232edb755a78cfaeb3299cbeb.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h204_png.rf.0676ee5875a0aa60a9545e31ba580365.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h243_png.rf.c6e9bf247abaeac9d94809f01631e69e.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h187_png.rf.a90e8ffc5131cb04b19d8e8b97f398ff.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h269_png.rf.d73ab563c1bdb58119d3694258a3880f.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h193_png.rf.8d5df3dcc0c9e912e707bff1b5e02651.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h110_png.rf.3dea125e0af4b85dd7188fd3a40f1c21.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h138_png.rf.58888bef9967b360f603869cb3923a47.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h141_png.rf.0510aaee32ef8560e7cc658e8cd53e83.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h268_png.rf.641c738b8048495e4f8d5bfeaf6a7b20.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h147_png.rf.c326097c25de8483937c1bf4a1f4776d.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h257_png.rf.b6fa620d740aec3c05c9939369bd1246.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h68_png.rf.96bbb14eab5b7a57d29c989530ce9923.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h80_png.rf.8dff9a7b4712db38b56739905c127ab6.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h77_png.rf.8dca6157d8f88d742155b918f0263888.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h14_png.rf.2e14dbbd69dfe15e888521fd5a4a9f5f.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h45_png.rf.85aa349d6960492da89c1ab0a2275053.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h111_png.rf.2798e970f4a3fadd652084a876714168.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h119_png.rf.fac4bc16393dbd0800a12c4337ee4c87.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h221_png.rf.e6ede1f041876f1774dad0a3f6f8c189.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h124_png.rf.5091089d5bc0a03466ac396574b9a119.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h281_png.rf.5f5fed3f69e8a348e6df9b53d574f63d.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h141_png.rf.346abfd529845353266b5e9370558e8d.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h260_png.rf.3dc359076d07fc4e618fff2f186f030f.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h85_png.rf.24fa7bb59fbc85ad9e7ddfe225903039.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h188_png.rf.fef821d12b34074953ae66f15eea9bd1.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h137_png.rf.e87cee9f6182be7903a4136bf36c623d.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h191_png.rf.93ee2a7519935c3dada4673aed51f1f1.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h184_png.rf.84c32ebbc134638d6fb6a2ce6b36dd43.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h145_png.rf.1c3c64324eb7605f7977417399f4ed4a.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h83_png.rf.c283bc5280f140e92a0417f7ccb20827.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h142_png.rf.7094274b3d53567ef2d114a08d5eedc2.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h167_png.rf.78bc8f305ee604b56042887ca890b89c.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h206_png.rf.2250238101655d46c81729dd4eab1249.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h232_png.rf.12d122e6d592038cc3dd3baecf93057a.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h83_png.rf.603107f528555e3d2c28f07dbd76a052.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h52_png.rf.aa6d1e1f60582ad2d57a33d3d28c3987.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h153_png.rf.cfea22f3dfd7a4ac553e32ff2f08b566.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h257_png.rf.51f4a7f718ad6c43f56bfc92a1beaafb.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h199_png.rf.01f599cd88a3c4ca6f49aa94dd722f9e.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h48_png.rf.54a3d27b2ffe24e26ff0e89f093c533f.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h89_png.rf.f8058a345103e18af30def0341086aa0.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h241_png.rf.fab67d730189dd8acdb58bff896be7c2.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h67_png.rf.0365a652ed3e989f56cf05b461aee8b7.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h222_png.rf.15936ae3569341cfd791a527ceff1f91.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h156_png.rf.4b18f484ec2effed3a4a1e905946cc03.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h251_png.rf.f90e932f96280e47669a748a805ca65a.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h230_png.rf.fd0bbdbccfadbdd545dedc7918f076d7.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h158_png.rf.fd24d2cf75bc5a5d473afbdd1c9a62bb.jpg
# /kaggle/input/nail-disease-classes/data/train/Healthy_Nail/h167_png.rf.84a101120c2dcbffeb066ad9cf721b95.jpg

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, models, transforms
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
from collections import OrderedDict
import pandas as pd

# Check for GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda:0

# %%
# ===========================
# DATA LOADING & PREPROCESSING
# ===========================

train_dir = '/kaggle/input/nail-disease-classes/data/train'
valid_dir = '/kaggle/input/nail-disease-classes/data/valid'
test_dir = '/kaggle/input/nail-disease-classes/data/test'

# Data transformations 
data_transforms = {
    'training': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.RandomRotation(30),
        transforms.ColorJitter(brightness=0.2, contrast=0.2),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                           [0.229, 0.224, 0.225])
    ]),
    
    'validation': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                           [0.229, 0.224, 0.225])
    ]),
    
    'testing': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                           [0.229, 0.224, 0.225])
    ])
}

batch_size = 32

# Create datasets
image_datasets = {
    'training': datasets.ImageFolder(train_dir, transform=data_transforms['training']),
    'validation': datasets.ImageFolder(valid_dir, transform=data_transforms['validation']),
    'testing': datasets.ImageFolder(test_dir, transform=data_transforms['testing'])
}

dataloaders = {
    'training': torch.utils.data.DataLoader(
        image_datasets['training'],
        batch_size=batch_size,
        shuffle=True,
        num_workers=2,
        pin_memory=True
    ),
    'validation': torch.utils.data.DataLoader(
        image_datasets['validation'],
        batch_size=batch_size,
        shuffle=False,
        num_workers=2,
        pin_memory=True
    ),
    'testing': torch.utils.data.DataLoader(
        image_datasets['testing'],
        batch_size=batch_size,
        shuffle=False,
        num_workers=2,
        pin_memory=True
    )
}

# Get lengths and class information
training_len = len(dataloaders['training'])
validation_len = len(dataloaders['validation'])
testing_len = len(dataloaders['testing'])
class_to_idx = image_datasets['training'].class_to_idx
idx_to_class = {v: k for k, v in class_to_idx.items()}
num_classes = len(class_to_idx)

print(f'We have {training_len} batches of training images; each with {batch_size} images')
print(f'We have {validation_len} batches of validation images; each with {batch_size} images')
print(f'We have {testing_len} batches of test images; each with {batch_size} images')
print(f'Number of classes: {num_classes}')
print(f'Classes: {list(class_to_idx.keys())}')
print(f'\nSingle batch shape: {next(iter(dataloaders["training"]))[0].shape}')
# Out:
# We have 100 batches of training images; each with 32 images
# We have 18 batches of validation images; each with 32 images
# We have 3 batches of test images; each with 32 images
# Number of classes: 6
# Classes: ['Acral_Lentiginous_Melanoma', 'Healthy_Nail', 'Onychogryphosis', 'blue_finger', 'clubbing', 'pitting']
#
# Single batch shape: torch.Size([32, 3, 224, 224])

# %%
# ===========================
# MODEL SETUP (DenseNet201)
# ===========================

from torchvision import models
from torch import nn
from collections import OrderedDict

# Load pre-trained DenseNet201
model = models.densenet201(pretrained=True)

# Freeze all parameters in the feature extractor
for param in model.parameters():
    param.requires_grad = False

print("\nOriginal DenseNet201 classifier:")
print(model.classifier)

# Define custom classifier
# DenseNet201 feature output size = 1920
hidden_units = 1024

classifier = nn.Sequential(OrderedDict([
    ('fc1', nn.Linear(1920, hidden_units)),  # DenseNet201 features output 1920
    ('relu1', nn.ReLU()),
    ('dropout1', nn.Dropout(0.5)),
    ('fc2', nn.Linear(hidden_units, 512)),
    ('relu2', nn.ReLU()),
    ('dropout2', nn.Dropout(0.3)),
    ('fc3', nn.Linear(512, num_classes)),
    ('output', nn.LogSoftmax(dim=1))
]))

# Replace the original classifier
model.classifier = classifier

print("\nNew custom classifier:")
print(model.classifier)

# Move model to device (GPU/CPU)
model.to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet201_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet201_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Original DenseNet201 classifier:
# Linear(in_features=1920, out_features=1000, bias=True)
#
# New custom classifier:
# Sequential(
#   (fc1): Linear(in_features=1920, out_features=1024, bias=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=1024, out_features=512, bias=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (fc3): Linear(in_features=512, out_features=6, bias=True)
#   (output): LogSoftmax(dim=1)
# )
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer25): _DenseLayer(
#         (norm1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer26): _DenseLayer(
#         (norm1): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1056, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer27): _DenseLayer(
#         (norm1): BatchNorm2d(1088, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1088, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer28): _DenseLayer(
#         (norm1): BatchNorm2d(1120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1120, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer29): _DenseLayer(
#         (norm1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1152, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer30): _DenseLayer(
#         (norm1): BatchNorm2d(1184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1184, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer31): _DenseLayer(
#         (norm1): BatchNorm2d(1216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1216, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer32): _DenseLayer(
#         (norm1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1248, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer33): _DenseLayer(
#         (norm1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1280, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer34): _DenseLayer(
#         (norm1): BatchNorm2d(1312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1312, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer35): _DenseLayer(
#         (norm1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1344, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer36): _DenseLayer(
#         (norm1): BatchNorm2d(1376, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1376, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer37): _DenseLayer(
#         (norm1): BatchNorm2d(1408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1408, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer38): _DenseLayer(
#         (norm1): BatchNorm2d(1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1440, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer39): _DenseLayer(
#         (norm1): BatchNorm2d(1472, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1472, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer40): _DenseLayer(
#         (norm1): BatchNorm2d(1504, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1504, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer41): _DenseLayer(
#         (norm1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1536, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer42): _DenseLayer(
#         (norm1): BatchNorm2d(1568, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1568, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer43): _DenseLayer(
#         (norm1): BatchNorm2d(1600, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1600, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer44): _DenseLayer(
#         (norm1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1632, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer45): _DenseLayer(
#         (norm1): BatchNorm2d(1664, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1664, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer46): _DenseLayer(
#         (norm1): BatchNorm2d(1696, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1696, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer47): _DenseLayer(
#         (norm1): BatchNorm2d(1728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1728, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer48): _DenseLayer(
#         (norm1): BatchNorm2d(1760, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1760, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1792, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1792, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1056, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(1088, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1088, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(1120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1120, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1152, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(1184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1184, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(1216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1216, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1248, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1280, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(1312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1312, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1344, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(1376, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1376, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(1408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1408, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1440, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(1472, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1472, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(1504, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1504, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1536, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(1568, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1568, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(1600, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1600, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1632, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer25): _DenseLayer(
#         (norm1): BatchNorm2d(1664, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1664, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer26): _DenseLayer(
#         (norm1): BatchNorm2d(1696, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1696, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer27): _DenseLayer(
#         (norm1): BatchNorm2d(1728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1728, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer28): _DenseLayer(
#         (norm1): BatchNorm2d(1760, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1760, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer29): _DenseLayer(
#         (norm1): BatchNorm2d(1792, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1792, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer30): _DenseLayer(
#         (norm1): BatchNorm2d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1824, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer31): _DenseLayer(
#         (norm1): BatchNorm2d(1856, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1856, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer32): _DenseLayer(
#         (norm1): BatchNorm2d(1888, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1888, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=1920, out_features=1024, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.5, inplace=False)
#     (fc2): Linear(in_features=1024, out_features=512, bias=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.3, inplace=False)
#     (fc3): Linear(in_features=512, out_features=6, bias=True)
#     (output): LogSoftmax(dim=1)
#   )
# )

# %%
# ===========================
# TRAINING SETUP
# ===========================

epochs = 10
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)
criterion = nn.NLLLoss()
print_every = 20 

validation_accuracies, training_accuracies = [], []
validation_losses, training_losses = [], []

best_validation_accuracy = 0
best_model_weights = None

print("\n" + "="*60)
print("STARTING TRAINING - DenseNet Model")
print("="*60)

# ===========================
# TRAINING LOOP
# ===========================

import time
start_time = time.time()

for e in range(epochs):
    
    training_loss = training_accuracy = 0
    validation_loss = validation_accuracy = 0
    
    # ===== TRAINING PHASE =====
    model.train()
    for batch_idx, (images, labels) in enumerate(dataloaders['training']):
        
        # Move to device
        images, labels = images.to(device), labels.to(device)
        
        # Forward pass
        log_ps = model.forward(images)
        loss = criterion(log_ps, labels)
        
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Calculate accuracy
        ps = torch.exp(log_ps)
        top_ps, top_class = ps.topk(1, dim=1)
        matches = (top_class == labels.view(*top_class.shape)).type(torch.FloatTensor)
        train_batch_accuracy = matches.mean()
        
        # Track metrics
        training_loss += loss.item()
        train_batch_loss = loss.item()
        training_accuracy += train_batch_accuracy.item()
        
        # Print less frequently for speed
        if batch_idx % print_every == 0:
            print(f'Epoch {e}, Batch {batch_idx} - Loss: {train_batch_loss:.4f}, Acc: {train_batch_accuracy.item():.4f}')
    
    # ===== VALIDATION PHASE =====
    model.eval()
    with torch.no_grad():
        for batch_idx, (images, labels) in enumerate(dataloaders['validation']):
            images, labels = images.to(device), labels.to(device)
            
            log_ps = model(images)
            loss = criterion(log_ps, labels)
            
            ps = torch.exp(log_ps)
            top_ps, top_class = ps.topk(1, dim=1)
            matches = (top_class == labels.view(*top_class.shape)).type(torch.FloatTensor)
            validation_batch_accuracy = matches.mean()
            
            # Track validation metrics
            validation_loss += loss.item()
            validation_batch_loss = loss.item()
            validation_accuracy += validation_batch_accuracy.item()
    
    # Save best model
    if validation_accuracy >= best_validation_accuracy:
        best_validation_accuracy = validation_accuracy
        best_model_weights = model.state_dict()
        print(f"  ✓ New best DenseNet model saved!")
    
    # Epoch summary
    avg_train_loss = training_loss / training_len
    avg_train_acc = training_accuracy / training_len
    avg_val_loss = validation_loss / validation_len
    avg_val_acc = validation_accuracy / validation_len
    
    print(f'\nEpoch {e} Summary:')
    print(f'  Avg training loss: {avg_train_loss:.4f}')
    print(f'  Avg training accuracy: {avg_train_acc:.4f} ({avg_train_acc*100:.2f}%)')
    print(f'  Avg validation loss: {avg_val_loss:.4f}')
    print(f'  Avg validation accuracy: {avg_val_acc:.4f} ({avg_val_acc*100:.2f}%)')
    print()
    
    training_losses.append(avg_train_loss)
    training_accuracies.append(avg_train_acc)
    validation_losses.append(avg_val_loss)
    validation_accuracies.append(avg_val_acc)

# Load best model weights
model.load_state_dict(best_model_weights)

# Calculate mean best validation accuracy
best_val_acc_mean = best_validation_accuracy / validation_len
print("="*60)
print(f"Best Validation Accuracy: {best_val_acc_mean:.3f} ({best_val_acc_mean*100:.2f}%)")
print("="*60)

# ===========================
# PLOT TRAINING HISTORY
# ===========================

def plot_training_history(train_losses, val_losses, train_accs, val_accs):
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    epochs_range = range(len(train_losses))
    
    # Loss plot
    axes[0].plot(epochs_range, train_losses, label='Training Loss', marker='o')
    axes[0].plot(epochs_range, val_losses, label='Validation Loss', marker='s')
    axes[0].set_title('DenseNet - Training and Validation Loss')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].grid(True)
    
    # Accuracy plot
    axes[1].plot(epochs_range, train_accs, label='Training Accuracy', marker='o')
    axes[1].plot(epochs_range, val_accs, label='Validation Accuracy', marker='s')
    axes[1].set_title('DenseNet - Training and Validation Accuracy')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    axes[1].grid(True)
    
    plt.tight_layout()
    plt.show()

plot_training_history(training_losses, validation_losses, 
                     training_accuracies, validation_accuracies)

# ===========================
# DETAILED EVALUATION ON TEST SET
# ===========================

print("\n" + "="*60)
print("DETAILED MODEL EVALUATION ON TEST SET - DenseNet")
print("="*60)
print("Note: Using TEST set for final evaluation (not validation set)")
print("="*60)

# Get all predictions and true labels from TEST set
model.eval()
all_preds = []
all_labels = []
all_probs = []

with torch.no_grad():
    for images, labels in dataloaders['testing']:
        images, labels = images.to(device), labels.to(device)
        
        log_ps = model(images)
        ps = torch.exp(log_ps)
        top_ps, top_class = ps.topk(1, dim=1)
        
        all_preds.extend(top_class.cpu().numpy().flatten())
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(ps.cpu().numpy())

all_preds = np.array(all_preds)
all_labels = np.array(all_labels)
all_probs = np.array(all_probs)

# Class names
class_names = [idx_to_class[i] for i in range(num_classes)]

# ===========================
# METRICS
# ===========================

# Calculate confusion matrix
cm = confusion_matrix(all_labels, all_preds)

# Calculate Overall Accuracy
overall_accuracy = np.trace(cm) / cm.sum()

# Calculate TP, FP, FN, TN for each class
metrics = []
for i, class_name in enumerate(class_names):
    TP = cm[i, i]
    FP = cm[:, i].sum() - TP
    FN = cm[i, :].sum() - TP
    TN = cm.sum() - TP - FP - FN
    
    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    support = cm[i, :].sum()
    
    metrics.append({
        'Class': class_name,
        'TP': TP,
        'FP': FP,
        'FN': FN,
        'TN': TN,
        'Precision': round(precision, 4),
        'Recall': round(recall, 4),
        'F1-Score': round(f1, 4),
        'Support': support
    })

metrics_df = pd.DataFrame(metrics)

# Calculate Macro Average
macro_avg = {
    'Class': 'Macro Avg',
    'TP': ' ',
    'FP': ' ',
    'FN': ' ',
    'TN': ' ',
    'Precision': round(metrics_df['Precision'].mean(), 4),
    'Recall': round(metrics_df['Recall'].mean(), 4),
    'F1-Score': round(metrics_df['F1-Score'].mean(), 4),
    'Support': metrics_df['Support'].sum()
}

# Calculate Weighted Average
total_support = metrics_df['Support'].sum()
weighted_avg = {
    'Class': 'Weighted Avg',
    'TP': ' ',
    'FP': ' ',
    'FN': ' ',
    'TN': ' ',
    'Precision': round((metrics_df['Precision'] * metrics_df['Support']).sum() / total_support, 4),
    'Recall': round((metrics_df['Recall'] * metrics_df['Support']).sum() / total_support, 4),
    'F1-Score': round((metrics_df['F1-Score'] * metrics_df['Support']).sum() / total_support, 4),
    'Support': total_support
}

# Add averages to dataframe
metrics_df = pd.concat([metrics_df, pd.DataFrame([macro_avg, weighted_avg])], ignore_index=True)

# Print results
print(f"\n{'='*60}")
print(f"TEST SET OVERALL ACCURACY: {round(overall_accuracy, 4)} ({round(overall_accuracy*100, 2)}%)")
print(f"{'='*60}\n")
print(metrics_df.to_string(index=False))

# ===========================
# CONFUSION MATRIX
# ===========================

cm = confusion_matrix(all_labels, all_preds)

# Raw confusion matrix
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('DenseNet - Test Set Confusion Matrix', fontsize=16)
plt.ylabel('True Label', fontsize=12)
plt.xlabel('Predicted Label', fontsize=12)
plt.tight_layout()
plt.show()

# Normalized confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
plt.figure(figsize=(12, 10))
sns.heatmap(cm_normalized, annot=True, fmt='.2%', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('DenseNet - Test Set Normalized Confusion Matrix (%)', fontsize=16)
plt.ylabel('True Label', fontsize=12)
plt.xlabel('Predicted Label', fontsize=12)
plt.tight_layout()
plt.show()

# ===========================
# PER-CLASS PERFORMANCE
# ===========================

per_class_metrics = classification_report(all_labels, all_preds,
                                         target_names=class_names,
                                         output_dict=True)

classes_df = pd.DataFrame(per_class_metrics).T[:-3]  # Exclude avg rows
classes_df = classes_df.sort_values('f1-score', ascending=False)

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

classes_df['precision'].plot(kind='barh', ax=axes[0], color='skyblue')
axes[0].set_title('DenseNet - Test Set Precision by Class', fontsize=14)
axes[0].set_xlabel('Precision', fontsize=12)
axes[0].grid(True, alpha=0.3)

classes_df['recall'].plot(kind='barh', ax=axes[1], color='lightcoral')
axes[1].set_title('DenseNet - Test Set Recall by Class', fontsize=14)
axes[1].set_xlabel('Recall', fontsize=12)
axes[1].grid(True, alpha=0.3)

classes_df['f1-score'].plot(kind='barh', ax=axes[2], color='lightgreen')
axes[2].set_title('DenseNet - Test Set F1-Score by Class', fontsize=14)
axes[2].set_xlabel('F1-Score', fontsize=12)
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# ===========================
# SAMPLE PREDICTIONS
# ===========================

def visualize_predictions(dataloader, model, device, num_samples=9):
    model.eval()
    images, labels = next(iter(dataloader))
    images, labels = images.to(device), labels.to(device)
    
    with torch.no_grad():
        log_ps = model(images)
        ps = torch.exp(log_ps)
        top_ps, top_class = ps.topk(1, dim=1)
    
    images = images.cpu()
    labels = labels.cpu()
    top_class = top_class.cpu()
    top_ps = top_ps.cpu()
    
    fig, axes = plt.subplots(3, 3, figsize=(15, 15))
    axes = axes.ravel()
    
    for i in range(min(num_samples, len(images))):
        # Denormalize image
        img = images[i].numpy().transpose((1, 2, 0))
        mean = np.array([0.485, 0.456, 0.406])
        std = np.array([0.229, 0.224, 0.225])
        img = std * img + mean
        img = np.clip(img, 0, 1)
        
        axes[i].imshow(img)
        
        true_label = idx_to_class[labels[i].item()]
        pred_label = idx_to_class[top_class[i].item()]
        confidence = top_ps[i].item() * 100
        
        color = 'green' if labels[i].item() == top_class[i].item() else 'red'
        axes[i].set_title(f'True: {true_label}\nPred: {pred_label}\nConf: {confidence:.1f}%',
                         color=color, fontsize=10)
        axes[i].axis('off')
    
    plt.tight_layout()
    plt.show()

print("\n" + "-"*60)
print("SAMPLE PREDICTIONS ON TEST SET - DenseNet")
print("-"*60)
visualize_predictions(dataloaders['testing'], model, device)

# ===========================
# SAVE MODEL (KAGGLE OUTPUT)
# ===========================

# Save the model checkpoint
checkpoint = {
    'model_state_dict': best_model_weights,
    'class_to_idx': class_to_idx,
    'classifier': model.classifier,
    'epochs': epochs,
    'optimizer_state_dict': optimizer.state_dict(),
}

# Add test metrics if available
try:
    checkpoint['test_accuracy'] = overall_accuracy
    checkpoint['test_precision_macro'] = precision_macro
    checkpoint['test_recall_macro'] = recall_macro
    checkpoint['test_f1_macro'] = f1_macro
except NameError:
    pass

torch.save(checkpoint, '/kaggle/working/densenet_nail_disease_best.pth')
print("\nDenseNet model checkpoint saved as 'densenet_nail_disease_best.pth'")
print("Download from: Output tab (right sidebar)")

# Also save just the model
torch.save(model.state_dict(), '/kaggle/working/densenet_nail_disease_weights.pth')
print("DenseNet model weights saved as 'densenet_nail_disease_weights.pth'")

print("\n" + "="*60)
print("TRAINING AND EVALUATION COMPLETE!")
print("="*60)
# Out:
# ============================================================
# STARTING TRAINING - DenseNet Model
# ============================================================
# Epoch 0, Batch 0 - Loss: 1.8167, Acc: 0.1250
# Epoch 0, Batch 20 - Loss: 1.4634, Acc: 0.4062
# Epoch 0, Batch 40 - Loss: 1.4522, Acc: 0.3750
# Epoch 0, Batch 60 - Loss: 1.0671, Acc: 0.6562
# Epoch 0, Batch 80 - Loss: 1.0843, Acc: 0.6562
#   ✓ New best DenseNet model saved!
#
# Epoch 0 Summary:
#   Avg training loss: 1.3278
#   Avg training accuracy: 0.4370 (43.70%)
#   Avg validation loss: 0.8812
#   Avg validation accuracy: 0.6734 (67.34%)
#
# Epoch 1, Batch 0 - Loss: 0.7665, Acc: 0.7188
# Epoch 1, Batch 20 - Loss: 0.9524, Acc: 0.5625
# Epoch 1, Batch 40 - Loss: 1.0083, Acc: 0.5938
# Epoch 1, Batch 60 - Loss: 1.0905, Acc: 0.4375
# Epoch 1, Batch 80 - Loss: 0.8407, Acc: 0.6562
#
# Epoch 1 Summary:
#   Avg training loss: 1.0200
#   Avg training accuracy: 0.5817 (58.17%)
#   Avg validation loss: 0.8894
#   Avg validation accuracy: 0.6630 (66.30%)
#
# Epoch 2, Batch 0 - Loss: 1.0449, Acc: 0.6250
# Epoch 2, Batch 20 - Loss: 0.8115, Acc: 0.6562
# Epoch 2, Batch 40 - Loss: 0.6721, Acc: 0.7500
# Epoch 2, Batch 60 - Loss: 0.9713, Acc: 0.5938
# Epoch 2, Batch 80 - Loss: 0.9214, Acc: 0.6562
#   ✓ New best DenseNet model saved!
#
# Epoch 2 Summary:
#   Avg training loss: 0.9262
#   Avg training accuracy: 0.6442 (64.42%)
#   Avg validation loss: 0.7313
#   Avg validation accuracy: 0.7384 (73.84%)
#
# Epoch 3, Batch 0 - Loss: 1.0930, Acc: 0.5938
# Epoch 3, Batch 20 - Loss: 0.6203, Acc: 0.7188
# Epoch 3, Batch 40 - Loss: 0.6453, Acc: 0.7500
# Epoch 3, Batch 60 - Loss: 0.7189, Acc: 0.6250
# Epoch 3, Batch 80 - Loss: 0.9256, Acc: 0.6562
#   ✓ New best DenseNet model saved!
#
# Epoch 3 Summary:
#   Avg training loss: 0.8904
#   Avg training accuracy: 0.6495 (64.95%)
#   Avg validation loss: 0.6965
#   Avg validation accuracy: 0.7515 (75.15%)
#
# Epoch 4, Batch 0 - Loss: 0.7109, Acc: 0.7188
# Epoch 4, Batch 20 - Loss: 1.0268, Acc: 0.6875
# Epoch 4, Batch 40 - Loss: 0.9966, Acc: 0.6250
# Epoch 4, Batch 60 - Loss: 0.9117, Acc: 0.6250
# Epoch 4, Batch 80 - Loss: 0.9979, Acc: 0.6250
#
# Epoch 4 Summary:
#   Avg training loss: 0.8629
#   Avg training accuracy: 0.6673 (66.73%)
#   Avg validation loss: 0.7960
#   Avg validation accuracy: 0.7031 (70.31%)
#
# Epoch 5, Batch 0 - Loss: 1.0898, Acc: 0.6250
# Epoch 5, Batch 20 - Loss: 0.8338, Acc: 0.5938
# Epoch 5, Batch 40 - Loss: 0.8844, Acc: 0.6250
# Epoch 5, Batch 60 - Loss: 0.8112, Acc: 0.6875
# Epoch 5, Batch 80 - Loss: 0.6509, Acc: 0.7812
#
# Epoch 5 Summary:
#   Avg training loss: 0.8473
#   Avg training accuracy: 0.6723 (67.23%)
#   Avg validation loss: 0.6646
#   Avg validation accuracy: 0.7502 (75.02%)
#
# Epoch 6, Batch 0 - Loss: 0.5705, Acc: 0.8125
# Epoch 6, Batch 20 - Loss: 1.1316, Acc: 0.5625
# Epoch 6, Batch 40 - Loss: 0.8046, Acc: 0.6562
# Epoch 6, Batch 60 - Loss: 0.6080, Acc: 0.7500
# Epoch 6, Batch 80 - Loss: 0.7976, Acc: 0.6562
#
# Epoch 6 Summary:
#   Avg training loss: 0.8251
#   Avg training accuracy: 0.6801 (68.01%)
#   Avg validation loss: 0.6939
#   Avg validation accuracy: 0.7359 (73.59%)
#
# Epoch 7, Batch 0 - Loss: 0.6147, Acc: 0.7812
# Epoch 7, Batch 20 - Loss: 0.9318, Acc: 0.6875
# Epoch 7, Batch 40 - Loss: 1.1246, Acc: 0.6250
# Epoch 7, Batch 60 - Loss: 1.0969, Acc: 0.6875
# Epoch 7, Batch 80 - Loss: 0.6640, Acc: 0.8125
#   ✓ New best DenseNet model saved!
#
# Epoch 7 Summary:
#   Avg training loss: 0.8659
#   Avg training accuracy: 0.6790 (67.90%)
#   Avg validation loss: 0.6457
#   Avg validation accuracy: 0.7728 (77.28%)
#
# Epoch 8, Batch 0 - Loss: 0.7521, Acc: 0.7500
# Epoch 8, Batch 20 - Loss: 0.8271, Acc: 0.6875
# Epoch 8, Batch 40 - Loss: 0.6439, Acc: 0.7812
# Epoch 8, Batch 60 - Loss: 0.7826, Acc: 0.7188
# Epoch 8, Batch 80 - Loss: 0.8067, Acc: 0.7188
#
# Epoch 8 Summary:
#   Avg training loss: 0.8482
#   Avg training accuracy: 0.6718 (67.18%)
#   Avg validation loss: 0.6312
#   Avg validation accuracy: 0.7689 (76.89%)
#
# Epoch 9, Batch 0 - Loss: 0.7561, Acc: 0.7188
# Epoch 9, Batch 20 - Loss: 0.8551, Acc: 0.6250
# Epoch 9, Batch 40 - Loss: 0.9387, Acc: 0.6250
# Epoch 9, Batch 60 - Loss: 0.6824, Acc: 0.7500
# Epoch 9, Batch 80 - Loss: 0.5397, Acc: 0.8125
#
# Epoch 9 Summary:
#   Avg training loss: 0.7874
#   Avg training accuracy: 0.6995 (69.95%)
#   Avg validation loss: 0.6201
#   Avg validation accuracy: 0.7679 (76.79%)
#
# ============================================================
# Best Validation Accuracy: 0.773 (77.28%)
# ============================================================
# ============================================================
# DETAILED MODEL EVALUATION ON TEST SET - DenseNet
# ============================================================
# Note: Using TEST set for final evaluation (not validation set)
# ============================================================
#
# ============================================================
# TEST SET OVERALL ACCURACY: 0.875 (87.5%)
# ============================================================
#
#                      Class TP FP FN TN  Precision  Recall  F1-Score  Support
# Acral_Lentiginous_Melanoma 15  6  0 67     0.7143  1.0000    0.8333       15
#               Healthy_Nail 20  0  0 68     1.0000  1.0000    1.0000       20
#            Onychogryphosis  9  3  3 73     0.7500  0.7500    0.7500       12
#                blue_finger  7  1  2 78     0.8750  0.7778    0.8235        9
#                   clubbing 12  0  4 72     1.0000  0.7500    0.8571       16
#                    pitting 14  1  2 71     0.9333  0.8750    0.9032       16
#                  Macro Avg                 0.8788  0.8588    0.8612       88
#               Weighted Avg                 0.8923  0.8750    0.8759       88
# ------------------------------------------------------------
# SAMPLE PREDICTIONS ON TEST SET - DenseNet
# ------------------------------------------------------------
# DenseNet model checkpoint saved as 'densenet_nail_disease_best.pth'
# Download from: Output tab (right sidebar)
# DenseNet model weights saved as 'densenet_nail_disease_weights.pth'
#
# ============================================================
# TRAINING AND EVALUATION COMPLETE!
# ============================================================
