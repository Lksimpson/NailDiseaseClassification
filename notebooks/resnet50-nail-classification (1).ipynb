# %%
import matplotlib.pyplot as plt

from copy import deepcopy
import torch
from torchvision import models  
from torch import nn
from torch import optim
from torchvision import datasets, transforms, models

# download the data
data_dir = '/Users/malikahnathani/Downloads/data'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# Process with some data transformation, do not change
data_transforms = {
    'training': transforms.Compose([transforms.RandomResizedCrop(224),
                                    transforms.RandomHorizontalFlip(),
                                    transforms.RandomRotation(30),
                                    transforms.ToTensor(),
                                    transforms.Normalize([0.485, 0.456, 0.406],
                                                         [0.229, 0.224,
                                                          0.225])]),

    'validation': transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize(
                                          [0.485, 0.456, 0.406],
                                          [0.229, 0.224, 0.225])]),

    'testing': transforms.Compose([transforms.Resize(256),
                                   transforms.CenterCrop(224),
                                   transforms.ToTensor(),
                                   transforms.Normalize([0.485, 0.456, 0.406],
                                                        [0.229, 0.224,
                                                         0.225])])
}
# This specifies how many images to process per training/validation
batch_size = 32

image_datasets = {
    'training': datasets.ImageFolder(train_dir,
                                     transform=data_transforms['training']),
    'testing': datasets.ImageFolder(test_dir,
                                    transform=data_transforms['testing']),
    'validation': datasets.ImageFolder(valid_dir,
                                       transform=data_transforms['validation'])
}

dataloaders = {
    'training': torch.utils.data.DataLoader(image_datasets['training'],
                                            batch_size=batch_size,
                                            shuffle=True),
    'testing': torch.utils.data.DataLoader(image_datasets['testing'],
                                           batch_size=batch_size,
                                           shuffle=False),
    'validation': torch.utils.data.DataLoader(image_datasets['validation'],
                                              batch_size=batch_size,
                                              shuffle=True)
}

# get the length of each dataloaders; with batch size=256, you should have 26 batches of training samples, each with 256 images 
training_len = len(dataloaders['training'])
test_len = len(dataloaders['testing'])
validation_len = len(dataloaders['validation'])
class_to_idx = image_datasets['training'].class_to_idx

print('We have ', training_len, 'batches of training images;', 'each with',
      batch_size, 'images')
print('We have ', validation_len, 'batches of validation images;', 'each with',
      batch_size, 'images')
print('We have ', test_len, 'batches of testing images;', 'each with',
      batch_size, 'images')

# Let us preview size of each batch
print('Single batch', next(iter(dataloaders['training']))[0].shape)
# Transfer learning with ResNet50
model = models.resnet50(weights='DEFAULT')
for param in model.parameters():
    param.requires_grad = False

print(model)

# This is the original classifier with resnet50
print()
print('Original classifier of ResNet50')
print(model.fc)

# Defining number of hidden units in our fully connected layer
number_of_classes = len(class_to_idx) 
model.fc = nn.Linear(2048, number_of_classes)
print(model)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)

epochs = 10
optimizer = optim.Adam(model.fc.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()  # Changed from NLLLoss - this works with raw logits
print_every = 5

validation_accuracies, training_accuracies = [], []
validation_losses, training_losses = [], []

best_validation_accuracy = 0
best_model_weights = None

for e in range(epochs):

    training_loss = training_accuracy = 0
    validation_loss = validation_accuracy = 0

    model.train()
    for batch_idx, (images, labels) in enumerate(dataloaders['training']):

        # Moving images & labels to the GPU if there is one
        images, labels = images.to(device), labels.to(device)

        # Zero gradients first
        optimizer.zero_grad()

        # Forward pass
        logits = model.forward(images)  # Changed variable name for clarity
        loss = criterion(logits, labels)
        
        # Backward pass to compute gradients
        loss.backward()
        
        # Update weights after backward
        optimizer.step()

        # Calculating metrics
        ps = torch.softmax(logits, dim=1)  # Changed from exp since we have raw logits now
        top_ps, top_class = ps.topk(1, dim=1)
        matches = (top_class == labels.view(*top_class.shape)).type(
            torch.FloatTensor)
        train_batch_accuracy = matches.mean()

        # Tracking metrics
        training_loss += loss.item()
        train_batch_loss = loss.item()
        training_accuracy += train_batch_accuracy.item()

        if batch_idx % print_every == 0:
            print('epoch', e, 'batch', batch_idx)
            print('training loss per batch', train_batch_loss)
            print('training accuracy per batch', train_batch_accuracy.item())

    # Validation
    model.eval()
    with torch.no_grad():
        for batch_idx, (images, labels) in enumerate(
                dataloaders['validation']):
            images, labels = images.to(device), labels.to(device)
            logits = model(images)  # Changed variable name
            loss = criterion(logits, labels)
            ps = torch.softmax(logits, dim=1)  # Changed from exp
            top_ps, top_class = ps.topk(1, dim=1)
            matches = (top_class == labels.view(*top_class.shape)).type(
                torch.FloatTensor)
            validation_batch_accuracy = matches.mean()

            validation_loss += loss.item()
            validation_batch_loss = loss.item()
            validation_accuracy += validation_batch_accuracy

    # Save best model
    if validation_accuracy >= best_validation_accuracy:
        best_validation_accuracy = validation_accuracy
        best_model_weights = model.state_dict()

    # Summary per epoch
    print('epoch', e, 'summary')
    print('avg training loss per epoch', training_loss / training_len)
    print('avg training accuracy per epoch', training_accuracy / training_len)
    training_losses.append(training_loss / training_len)
    training_accuracies.append(training_accuracy / training_len)

    print('avg validation loss per epoch', validation_loss / validation_len)
    print('avg validation accuracy per epoch',
          validation_accuracy / validation_len)
    validation_losses.append(validation_loss / validation_len)
    validation_accuracies.append(validation_accuracy / validation_len)

    print()
plt.figure()
plt.title("Training Summary of Loss")
plt.plot(training_losses, label='Training Loss')
plt.plot(validation_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure()
plt.title("Training Summary of Accuracy")
plt.plot(training_accuracies, label='Training Accuracy')
plt.plot(validation_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Load the best model so far
model.load_state_dict(best_model_weights)
model.eval()  # Set to evaluation mode

total_correct = 0
total_samples = 0
predictions = []
label_data = []

with torch.no_grad():  # Disable gradient computation for testing
    for images, labels in dataloaders['testing']:
        images, labels = images.to(device), labels.to(device)
        
        logits = model(images)
        ps = torch.softmax(logits, dim=1)
        
        top_ps, top_class = ps.topk(1, dim=1)
        
        total_correct += (top_class == labels.view(*top_class.shape)).sum().item()
        total_samples += labels.size(0)
        
        predictions.append(top_class)
        label_data.append(labels)

test_accuracy = total_correct / total_samples
print(f'Test Accuracy: {test_accuracy:.4f}')

predictions = torch.cat(predictions).cpu()
label_data = torch.cat(label_data).cpu()

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix as conf_mat
import numpy as np

# Your class labels - replace these with your actual class names
class_names = ['Acral Lentiginous Melanoma', 'Blue Finger', 'Clubbing', 'Healthy Nail', 'Onychogryphosis', 'Pitting']

cf = conf_mat(label_data, predictions)

# Plot raw confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cf, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.tight_layout()
plt.show()

# Plot normalized confusion matrix
plt.figure(figsize=(10, 8))
ncf = cf.astype('float') / cf.sum(axis=1, keepdims=True)  # Normalize by row (true labels)
sns.heatmap(ncf, annot=True, fmt='.2%', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('Normalized Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.tight_layout()
plt.show()

import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix as conf_mat

# Your class labels - replace with actual names
class_names = ['Acral Lentiginous Melanoma', 'Blue Finger', 'Clubbing', 'Healthy Nail', 'Onychogryphosis', 'Pitting']

cf = conf_mat(label_data, predictions)

# Calculate Overall Accuracy
overall_accuracy = np.trace(cf) / cf.sum()

# Calculate TP, FP, FN, TN for each class
metrics = []
for i, class_name in enumerate(class_names):
    TP = cf[i, i]
    FP = cf[:, i].sum() - TP
    FN = cf[i, :].sum() - TP
    TN = cf.sum() - TP - FP - FN
    
    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    support = cf[i, :].sum()
    
    metrics.append({
        'Class': class_name,
        'TP': TP,
        'FP': FP,
        'FN': FN,
        'TN': TN,
        'Precision': round(precision, 4),
        'Recall': round(recall, 4),
        'F1-Score': round(f1, 4),
        'Support': support
    })

metrics_df = pd.DataFrame(metrics)

# Calculate Macro Average
macro_avg = {
    'Class': 'Macro Avg',
    'TP': ' ',
    'FP': ' ',
    'FN': ' ',
    'TN': ' ',
    'Precision': round(metrics_df['Precision'].mean(), 4),
    'Recall': round(metrics_df['Recall'].mean(), 4),
    'F1-Score': round(metrics_df['F1-Score'].mean(), 4),
    'Support': metrics_df['Support'].sum()
}

# Calculate Weighted Average
total_support = metrics_df['Support'].sum()
weighted_avg = {
    'Class': 'Weighted Avg',
    'TP': ' ',
    'FP': ' ',
    'FN': ' ',
    'TN': ' ',
    'Precision': round((metrics_df['Precision'] * metrics_df['Support']).sum() / total_support, 4),
    'Recall': round((metrics_df['Recall'] * metrics_df['Support']).sum() / total_support, 4),
    'F1-Score': round((metrics_df['F1-Score'] * metrics_df['Support']).sum() / total_support, 4),
    'Support': total_support
}

# Add averages to dataframe
metrics_df = pd.concat([metrics_df, pd.DataFrame([macro_avg, weighted_avg])], ignore_index=True)

# Print results
print(f"{'='*60}")
print(f"OVERALL ACCURACY: {round(overall_accuracy, 4)} ({round(overall_accuracy*100, 2)}%)")
print(f"{'='*60}\n")
print(metrics_df.to_string(index=False))
# Out:
# We have  100 batches of training images; each with 32 images
# We have  18 batches of validation images; each with 32 images
# We have  3 batches of testing images; each with 32 images
# Single batch torch.Size([32, 3, 224, 224])
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /Users/malikahnathani/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:23<00:00, 4.38MB/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )
#
# Original classifier of ResNet50
# Linear(in_features=2048, out_features=1000, bias=True)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=6, bias=True)
# )
# epoch 0 batch 0
# training loss per batch 1.7958849668502808
# training accuracy per batch 0.03125
# epoch 0 batch 5
# training loss per batch 1.746996283531189
# training accuracy per batch 0.25
# epoch 0 batch 10
# training loss per batch 1.6277799606323242
# training accuracy per batch 0.34375
# epoch 0 batch 15
# training loss per batch 1.4917595386505127
# training accuracy per batch 0.4375
# epoch 0 batch 20
# training loss per batch 1.431952714920044
# training accuracy per batch 0.46875
# epoch 0 batch 25
# training loss per batch 1.3754771947860718
# training accuracy per batch 0.53125
# epoch 0 batch 30
# training loss per batch 1.416965126991272
# training accuracy per batch 0.625
# epoch 0 batch 35
# training loss per batch 1.3037422895431519
# training accuracy per batch 0.59375
# epoch 0 batch 40
# training loss per batch 1.2436679601669312
# training accuracy per batch 0.75
# epoch 0 batch 45
# training loss per batch 1.4142307043075562
# training accuracy per batch 0.46875
# epoch 0 batch 50
# training loss per batch 1.2843273878097534
# training accuracy per batch 0.53125
# epoch 0 batch 55
# training loss per batch 1.2267847061157227
# training accuracy per batch 0.53125
# epoch 0 batch 60
# training loss per batch 1.1702412366867065
# training accuracy per batch 0.65625
# epoch 0 batch 65
# training loss per batch 1.0948259830474854
# training accuracy per batch 0.59375
# epoch 0 batch 70
# training loss per batch 1.1118258237838745
# training accuracy per batch 0.65625
# epoch 0 batch 75
# training loss per batch 1.1058095693588257
# training accuracy per batch 0.59375
# epoch 0 batch 80
# training loss per batch 1.2094758749008179
# training accuracy per batch 0.59375
# epoch 0 batch 85
# training loss per batch 0.969676673412323
# training accuracy per batch 0.65625
# epoch 0 batch 90
# training loss per batch 1.2401587963104248
# training accuracy per batch 0.5625
# epoch 0 batch 95
# training loss per batch 1.3466905355453491
# training accuracy per batch 0.4375
# epoch 0 summary
# avg training loss per epoch 1.3005017393827438
# avg training accuracy per epoch 0.5365909093618393
# avg validation loss per epoch 1.026430709494485
# avg validation accuracy per epoch tensor(0.6863)
#
# epoch 1 batch 0
# training loss per batch 1.0821744203567505
# training accuracy per batch 0.53125
# epoch 1 batch 5
# training loss per batch 1.2715833187103271
# training accuracy per batch 0.5625
# epoch 1 batch 10
# training loss per batch 1.0973902940750122
# training accuracy per batch 0.5625
# epoch 1 batch 15
# training loss per batch 1.1978342533111572
# training accuracy per batch 0.53125
# epoch 1 batch 20
# training loss per batch 1.2199627161026
# training accuracy per batch 0.53125
# epoch 1 batch 25
# training loss per batch 0.9167443513870239
# training accuracy per batch 0.625
# epoch 1 batch 30
# training loss per batch 0.8396780490875244
# training accuracy per batch 0.6875
# epoch 1 batch 35
# training loss per batch 0.9482532143592834
# training accuracy per batch 0.65625
# epoch 1 batch 40
# training loss per batch 0.7426477670669556
# training accuracy per batch 0.78125
# epoch 1 batch 45
# training loss per batch 0.739981472492218
# training accuracy per batch 0.75
# epoch 1 batch 50
# training loss per batch 0.9934621453285217
# training accuracy per batch 0.65625
# epoch 1 batch 55
# training loss per batch 1.136965036392212
# training accuracy per batch 0.5
# epoch 1 batch 60
# training loss per batch 1.1772620677947998
# training accuracy per batch 0.5625
# epoch 1 batch 65
# training loss per batch 0.9893791079521179
# training accuracy per batch 0.53125
# epoch 1 batch 70
# training loss per batch 1.0717291831970215
# training accuracy per batch 0.59375
# epoch 1 batch 75
# training loss per batch 0.9648560285568237
# training accuracy per batch 0.6875
# epoch 1 batch 80
# training loss per batch 0.9384664297103882
# training accuracy per batch 0.625
# epoch 1 batch 85
# training loss per batch 0.9398365616798401
# training accuracy per batch 0.6875
# epoch 1 batch 90
# training loss per batch 0.7814090251922607
# training accuracy per batch 0.75
# epoch 1 batch 95
# training loss per batch 0.9781042337417603
# training accuracy per batch 0.59375
# epoch 1 summary
# avg training loss per epoch 0.9892874878644943
# avg training accuracy per epoch 0.6460511362552643
# avg validation loss per epoch 0.882801416847441
# avg validation accuracy per epoch tensor(0.7261)
#
# epoch 2 batch 0
# training loss per batch 1.052699327468872
# training accuracy per batch 0.59375
# epoch 2 batch 5
# training loss per batch 0.9595721364021301
# training accuracy per batch 0.6875
# epoch 2 batch 10
# training loss per batch 0.9120064377784729
# training accuracy per batch 0.78125
# epoch 2 batch 15
# training loss per batch 0.9174789190292358
# training accuracy per batch 0.59375
# epoch 2 batch 20
# training loss per batch 0.765167772769928
# training accuracy per batch 0.75
# epoch 2 batch 25
# training loss per batch 0.8726401329040527
# training accuracy per batch 0.625
# epoch 2 batch 30
# training loss per batch 0.8676397800445557
# training accuracy per batch 0.75
# epoch 2 batch 35
# training loss per batch 0.9100233912467957
# training accuracy per batch 0.65625
# epoch 2 batch 40
# training loss per batch 0.850897490978241
# training accuracy per batch 0.71875
# epoch 2 batch 45
# training loss per batch 1.0243526697158813
# training accuracy per batch 0.65625
# epoch 2 batch 50
# training loss per batch 0.7779452800750732
# training accuracy per batch 0.8125
# epoch 2 batch 55
# training loss per batch 0.744892954826355
# training accuracy per batch 0.78125
# epoch 2 batch 60
# training loss per batch 0.9929652214050293
# training accuracy per batch 0.6875
# epoch 2 batch 65
# training loss per batch 0.8473986387252808
# training accuracy per batch 0.65625
# epoch 2 batch 70
# training loss per batch 1.0982716083526611
# training accuracy per batch 0.46875
# epoch 2 batch 75
# training loss per batch 0.9463833570480347
# training accuracy per batch 0.65625
# epoch 2 batch 80
# training loss per batch 0.8142873048782349
# training accuracy per batch 0.75
# epoch 2 batch 85
# training loss per batch 0.8855982422828674
# training accuracy per batch 0.71875
# epoch 2 batch 90
# training loss per batch 0.852493405342102
# training accuracy per batch 0.75
# epoch 2 batch 95
# training loss per batch 0.8650063872337341
# training accuracy per batch 0.6875
# epoch 2 summary
# avg training loss per epoch 0.905142018198967
# avg training accuracy per epoch 0.6819886362552643
# avg validation loss per epoch 0.8080693913830651
# avg validation accuracy per epoch tensor(0.7683)
#
# epoch 3 batch 0
# training loss per batch 0.8273651003837585
# training accuracy per batch 0.625
# epoch 3 batch 5
# training loss per batch 0.8274945020675659
# training accuracy per batch 0.65625
# epoch 3 batch 10
# training loss per batch 1.1365236043930054
# training accuracy per batch 0.5
# epoch 3 batch 15
# training loss per batch 0.8809601068496704
# training accuracy per batch 0.59375
# epoch 3 batch 20
# training loss per batch 0.7532441020011902
# training accuracy per batch 0.71875
# epoch 3 batch 25
# training loss per batch 1.0178959369659424
# training accuracy per batch 0.5
# epoch 3 batch 30
# training loss per batch 0.9705341458320618
# training accuracy per batch 0.625
# epoch 3 batch 35
# training loss per batch 1.1074802875518799
# training accuracy per batch 0.5625
# epoch 3 batch 40
# training loss per batch 0.6299616098403931
# training accuracy per batch 0.84375
# epoch 3 batch 45
# training loss per batch 0.7928046584129333
# training accuracy per batch 0.625
# epoch 3 batch 50
# training loss per batch 1.0462137460708618
# training accuracy per batch 0.53125
# epoch 3 batch 55
# training loss per batch 0.8547645211219788
# training accuracy per batch 0.59375
# epoch 3 batch 60
# training loss per batch 0.6444273591041565
# training accuracy per batch 0.8125
# epoch 3 batch 65
# training loss per batch 0.8596153259277344
# training accuracy per batch 0.625
# epoch 3 batch 70
# training loss per batch 0.9735788106918335
# training accuracy per batch 0.625
# epoch 3 batch 75
# training loss per batch 0.8285149931907654
# training accuracy per batch 0.625
# epoch 3 batch 80
# training loss per batch 0.7862025499343872
# training accuracy per batch 0.75
# epoch 3 batch 85
# training loss per batch 0.8309748768806458
# training accuracy per batch 0.71875
# epoch 3 batch 90
# training loss per batch 0.9829830527305603
# training accuracy per batch 0.625
# epoch 3 batch 95
# training loss per batch 0.8536590337753296
# training accuracy per batch 0.71875
# epoch 3 summary
# avg training loss per epoch 0.868551344871521
# avg training accuracy per epoch 0.6739204546809197
# avg validation loss per epoch 0.7604683621062173
# avg validation accuracy per epoch tensor(0.7542)
#
# epoch 4 batch 0
# training loss per batch 1.0857110023498535
# training accuracy per batch 0.4375
# epoch 4 batch 5
# training loss per batch 1.1275815963745117
# training accuracy per batch 0.5625
# epoch 4 batch 10
# training loss per batch 0.8848560452461243
# training accuracy per batch 0.65625
# epoch 4 batch 15
# training loss per batch 1.0127559900283813
# training accuracy per batch 0.59375
# epoch 4 batch 20
# training loss per batch 0.7555987238883972
# training accuracy per batch 0.75
# epoch 4 batch 25
# training loss per batch 1.1204330921173096
# training accuracy per batch 0.53125
# epoch 4 batch 30
# training loss per batch 0.7194952964782715
# training accuracy per batch 0.78125
# epoch 4 batch 35
# training loss per batch 0.6791957020759583
# training accuracy per batch 0.8125
# epoch 4 batch 40
# training loss per batch 0.7771034836769104
# training accuracy per batch 0.6875
# epoch 4 batch 45
# training loss per batch 0.8490139245986938
# training accuracy per batch 0.625
# epoch 4 batch 50
# training loss per batch 0.7634705901145935
# training accuracy per batch 0.6875
# epoch 4 batch 55
# training loss per batch 0.49043163657188416
# training accuracy per batch 0.875
# epoch 4 batch 60
# training loss per batch 0.9760571718215942
# training accuracy per batch 0.625
# epoch 4 batch 65
# training loss per batch 0.762658953666687
# training accuracy per batch 0.75
# epoch 4 batch 70
# training loss per batch 0.7319337725639343
# training accuracy per batch 0.78125
# epoch 4 batch 75
# training loss per batch 0.5395866632461548
# training accuracy per batch 0.875
# epoch 4 batch 80
# training loss per batch 0.6272239685058594
# training accuracy per batch 0.75
# epoch 4 batch 85
# training loss per batch 0.7015170454978943
# training accuracy per batch 0.78125
# epoch 4 batch 90
# training loss per batch 0.8174426555633545
# training accuracy per batch 0.8125
# epoch 4 batch 95
# training loss per batch 0.9909772872924805
# training accuracy per batch 0.53125
# epoch 4 summary
# avg training loss per epoch 0.8098654875159264
# avg training accuracy per epoch 0.7003693181276321
# avg validation loss per epoch 0.702649152941174
# avg validation accuracy per epoch tensor(0.7849)
#
# epoch 5 batch 0
# training loss per batch 1.0134896039962769
# training accuracy per batch 0.6875
# epoch 5 batch 5
# training loss per batch 0.9337542653083801
# training accuracy per batch 0.6875
# epoch 5 batch 10
# training loss per batch 0.6253110766410828
# training accuracy per batch 0.75
# epoch 5 batch 15
# training loss per batch 0.8747205138206482
# training accuracy per batch 0.6875
# epoch 5 batch 20
# training loss per batch 0.7414215803146362
# training accuracy per batch 0.75
# epoch 5 batch 25
# training loss per batch 0.781292200088501
# training accuracy per batch 0.78125
# epoch 5 batch 30
# training loss per batch 0.9711783528327942
# training accuracy per batch 0.6875
# epoch 5 batch 35
# training loss per batch 0.6125628352165222
# training accuracy per batch 0.875
# epoch 5 batch 40
# training loss per batch 0.747376561164856
# training accuracy per batch 0.75
# epoch 5 batch 45
# training loss per batch 0.6506153345108032
# training accuracy per batch 0.78125
# epoch 5 batch 50
# training loss per batch 0.9597603678703308
# training accuracy per batch 0.59375
# epoch 5 batch 55
# training loss per batch 0.7857957482337952
# training accuracy per batch 0.71875
# epoch 5 batch 60
# training loss per batch 0.576265275478363
# training accuracy per batch 0.875
# epoch 5 batch 65
# training loss per batch 0.7787379622459412
# training accuracy per batch 0.71875
# epoch 5 batch 70
# training loss per batch 0.7535027265548706
# training accuracy per batch 0.6875
# epoch 5 batch 75
# training loss per batch 0.6307489275932312
# training accuracy per batch 0.84375
# epoch 5 batch 80
# training loss per batch 0.6725606918334961
# training accuracy per batch 0.78125
# epoch 5 batch 85
# training loss per batch 0.7901970744132996
# training accuracy per batch 0.75
# epoch 5 batch 90
# training loss per batch 0.7520641088485718
# training accuracy per batch 0.78125
# epoch 5 batch 95
# training loss per batch 0.6274385452270508
# training accuracy per batch 0.8125
# epoch 5 summary
# avg training loss per epoch 0.7913526290655136
# avg training accuracy per epoch 0.7182386362552643
# avg validation loss per epoch 0.6782297442356745
# avg validation accuracy per epoch tensor(0.7998)
#
# epoch 6 batch 0
# training loss per batch 0.7109179496765137
# training accuracy per batch 0.75
# epoch 6 batch 5
# training loss per batch 0.637589156627655
# training accuracy per batch 0.75
# epoch 6 batch 10
# training loss per batch 0.7983555793762207
# training accuracy per batch 0.5625
# epoch 6 batch 15
# training loss per batch 0.7111709117889404
# training accuracy per batch 0.78125
# epoch 6 batch 20
# training loss per batch 0.6558652520179749
# training accuracy per batch 0.75
# epoch 6 batch 25
# training loss per batch 0.7353682518005371
# training accuracy per batch 0.65625
# epoch 6 batch 30
# training loss per batch 0.6815177202224731
# training accuracy per batch 0.75
# epoch 6 batch 35
# training loss per batch 0.723824679851532
# training accuracy per batch 0.65625
# epoch 6 batch 40
# training loss per batch 0.6466905474662781
# training accuracy per batch 0.75
# epoch 6 batch 45
# training loss per batch 0.8878628611564636
# training accuracy per batch 0.71875
# epoch 6 batch 50
# training loss per batch 0.8410110473632812
# training accuracy per batch 0.65625
# epoch 6 batch 55
# training loss per batch 0.7176921367645264
# training accuracy per batch 0.75
# epoch 6 batch 60
# training loss per batch 0.7654680013656616
# training accuracy per batch 0.78125
# epoch 6 batch 65
# training loss per batch 0.8736773133277893
# training accuracy per batch 0.75
# epoch 6 batch 70
# training loss per batch 0.7426031231880188
# training accuracy per batch 0.75
# epoch 6 batch 75
# training loss per batch 0.5805428624153137
# training accuracy per batch 0.78125
# epoch 6 batch 80
# training loss per batch 0.7931930422782898
# training accuracy per batch 0.6875
# epoch 6 batch 85
# training loss per batch 0.5561589598655701
# training accuracy per batch 0.84375
# epoch 6 batch 90
# training loss per batch 0.7002545595169067
# training accuracy per batch 0.6875
# epoch 6 batch 95
# training loss per batch 0.5913847088813782
# training accuracy per batch 0.84375
# epoch 6 summary
# avg training loss per epoch 0.7329958873987198
# avg training accuracy per epoch 0.7344318181276321
# avg validation loss per epoch 0.6610600782765282
# avg validation accuracy per epoch tensor(0.7953)
#
# epoch 7 batch 0
# training loss per batch 0.6774197816848755
# training accuracy per batch 0.8125
# epoch 7 batch 5
# training loss per batch 0.7770528197288513
# training accuracy per batch 0.625
# epoch 7 batch 10
# training loss per batch 0.5740001797676086
# training accuracy per batch 0.78125
# epoch 7 batch 15
# training loss per batch 0.6989768743515015
# training accuracy per batch 0.71875
# epoch 7 batch 20
# training loss per batch 0.6804777383804321
# training accuracy per batch 0.8125
# epoch 7 batch 25
# training loss per batch 0.6196082830429077
# training accuracy per batch 0.75
# epoch 7 batch 30
# training loss per batch 0.7448379993438721
# training accuracy per batch 0.6875
# epoch 7 batch 35
# training loss per batch 0.6722157597541809
# training accuracy per batch 0.75
# epoch 7 batch 40
# training loss per batch 0.7010570764541626
# training accuracy per batch 0.78125
# epoch 7 batch 45
# training loss per batch 0.5638403296470642
# training accuracy per batch 0.75
# epoch 7 batch 50
# training loss per batch 0.8004719614982605
# training accuracy per batch 0.6875
# epoch 7 batch 55
# training loss per batch 0.6605621576309204
# training accuracy per batch 0.75
# epoch 7 batch 60
# training loss per batch 0.7824864387512207
# training accuracy per batch 0.625
# epoch 7 batch 65
# training loss per batch 0.7588101625442505
# training accuracy per batch 0.71875
# epoch 7 batch 70
# training loss per batch 0.5796540975570679
# training accuracy per batch 0.78125
# epoch 7 batch 75
# training loss per batch 0.9939877986907959
# training accuracy per batch 0.59375
# epoch 7 batch 80
# training loss per batch 0.5034552216529846
# training accuracy per batch 0.90625
# epoch 7 batch 85
# training loss per batch 0.6273825764656067
# training accuracy per batch 0.71875
# epoch 7 batch 90
# training loss per batch 0.8507193922996521
# training accuracy per batch 0.625
# epoch 7 batch 95
# training loss per batch 0.7461668848991394
# training accuracy per batch 0.71875
# epoch 7 summary
# avg training loss per epoch 0.7442626911401748
# avg training accuracy per epoch 0.7298579546809196
# avg validation loss per epoch 0.6253366735246446
# avg validation accuracy per epoch tensor(0.7907)
#
# epoch 8 batch 0
# training loss per batch 0.5959351658821106
# training accuracy per batch 0.75
# epoch 8 batch 5
# training loss per batch 0.689923107624054
# training accuracy per batch 0.8125
# epoch 8 batch 10
# training loss per batch 0.7325440049171448
# training accuracy per batch 0.75
# epoch 8 batch 15
# training loss per batch 0.7553396224975586
# training accuracy per batch 0.625
# epoch 8 batch 20
# training loss per batch 0.4849804639816284
# training accuracy per batch 0.875
# epoch 8 batch 25
# training loss per batch 1.0067673921585083
# training accuracy per batch 0.53125
# epoch 8 batch 30
# training loss per batch 0.7183036804199219
# training accuracy per batch 0.75
# epoch 8 batch 35
# training loss per batch 0.6983745694160461
# training accuracy per batch 0.78125
# epoch 8 batch 40
# training loss per batch 0.5398581027984619
# training accuracy per batch 0.8125
# epoch 8 batch 45
# training loss per batch 0.5993844270706177
# training accuracy per batch 0.84375
# epoch 8 batch 50
# training loss per batch 0.607246994972229
# training accuracy per batch 0.8125
# epoch 8 batch 55
# training loss per batch 0.7297712564468384
# training accuracy per batch 0.78125
# epoch 8 batch 60
# training loss per batch 0.855798065662384
# training accuracy per batch 0.75
# epoch 8 batch 65
# training loss per batch 0.6850492358207703
# training accuracy per batch 0.8125
# epoch 8 batch 70
# training loss per batch 0.6768885254859924
# training accuracy per batch 0.71875
# epoch 8 batch 75
# training loss per batch 0.655686616897583
# training accuracy per batch 0.75
# epoch 8 batch 80
# training loss per batch 0.7621296048164368
# training accuracy per batch 0.65625
# epoch 8 batch 85
# training loss per batch 0.8990321159362793
# training accuracy per batch 0.65625
# epoch 8 batch 90
# training loss per batch 0.7302258610725403
# training accuracy per batch 0.75
# epoch 8 batch 95
# training loss per batch 0.8022393584251404
# training accuracy per batch 0.71875
# epoch 8 summary
# avg training loss per epoch 0.7396676602959633
# avg training accuracy per epoch 0.7344318181276321
# avg validation loss per epoch 0.6194284442398283
# avg validation accuracy per epoch tensor(0.8088)
#
# epoch 9 batch 0
# training loss per batch 0.5587688088417053
# training accuracy per batch 0.8125
# epoch 9 batch 5
# training loss per batch 0.929061233997345
# training accuracy per batch 0.65625
# epoch 9 batch 10
# training loss per batch 0.649071991443634
# training accuracy per batch 0.65625
# epoch 9 batch 15
# training loss per batch 0.5195918679237366
# training accuracy per batch 0.84375
# epoch 9 batch 20
# training loss per batch 0.542116641998291
# training accuracy per batch 0.875
# epoch 9 batch 25
# training loss per batch 0.532814085483551
# training accuracy per batch 0.84375
# epoch 9 batch 30
# training loss per batch 0.7172066569328308
# training accuracy per batch 0.75
# epoch 9 batch 35
# training loss per batch 0.7850925922393799
# training accuracy per batch 0.59375
# epoch 9 batch 40
# training loss per batch 1.207190752029419
# training accuracy per batch 0.59375
# epoch 9 batch 45
# training loss per batch 0.610025942325592
# training accuracy per batch 0.78125
# epoch 9 batch 50
# training loss per batch 1.001594066619873
# training accuracy per batch 0.625
# epoch 9 batch 55
# training loss per batch 0.7995784878730774
# training accuracy per batch 0.65625
# epoch 9 batch 60
# training loss per batch 0.6012179255485535
# training accuracy per batch 0.78125
# epoch 9 batch 65
# training loss per batch 0.8594122529029846
# training accuracy per batch 0.71875
# epoch 9 batch 70
# training loss per batch 0.6713906526565552
# training accuracy per batch 0.75
# epoch 9 batch 75
# training loss per batch 0.7248827219009399
# training accuracy per batch 0.71875
# epoch 9 batch 80
# training loss per batch 0.6721857786178589
# training accuracy per batch 0.78125
# epoch 9 batch 85
# training loss per batch 0.830788254737854
# training accuracy per batch 0.6875
# epoch 9 batch 90
# training loss per batch 0.7109823822975159
# training accuracy per batch 0.8125
# epoch 9 batch 95
# training loss per batch 0.6005678176879883
# training accuracy per batch 0.75
# epoch 9 summary
# avg training loss per epoch 0.7055604237318039
# avg training accuracy per epoch 0.7432386362552643
# avg validation loss per epoch 0.6101998454994626
# avg validation accuracy per epoch tensor(0.7984)
# Test Accuracy: 0.8750
# ============================================================
# OVERALL ACCURACY: 0.875 (87.5%)
# ============================================================
#
#                      Class TP FP FN TN  Precision  Recall  F1-Score  Support
# Acral Lentiginous Melanoma 15  5  0 68     0.7500  1.0000    0.8571       15
#                Blue Finger 20  0  0 68     1.0000  1.0000    1.0000       20
#                   Clubbing  7  1  5 75     0.8750  0.5833    0.7000       12
#               Healthy Nail  8  3  1 76     0.7273  0.8889    0.8000        9
#            Onychogryphosis 12  0  4 72     1.0000  0.7500    0.8571       16
#                    Pitting 15  2  1 70     0.8824  0.9375    0.9091       16
#                  Macro Avg                 0.8724  0.8600    0.8539       88
#               Weighted Avg                 0.8911  0.8750    0.8718       88
