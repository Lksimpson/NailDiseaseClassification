# %%
import matplotlib.pyplot as plt
from collections import OrderedDict

from copy import deepcopy
import torch
from torchvision import models  
from torch import nn
from torch import optim
from torchvision import datasets, transforms, models

# download the data
data_dir = 'dataset'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# Process with some data transformation, including normalization, resizing, cropping, flipping, and rotation
data_transforms = {
    'training': transforms.Compose([transforms.RandomResizedCrop(224),
                                    transforms.RandomHorizontalFlip(),
                                    transforms.RandomRotation(30),
                                    transforms.ToTensor(),
                                    transforms.Normalize([0.485, 0.456, 0.406],
                                                         [0.229, 0.224,
                                                          0.225])]),

    'validation': transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize(
                                          [0.485, 0.456, 0.406],
                                          [0.229, 0.224, 0.225])]),

    'testing': transforms.Compose([transforms.Resize(256),
                                   transforms.CenterCrop(224),
                                   transforms.ToTensor(),
                                   transforms.Normalize([0.485, 0.456, 0.406],
                                                        [0.229, 0.224,
                                                         0.225])])
}
# This specifies how many images to process per training/validation
batch_size = 32

image_datasets = {
    'training': datasets.ImageFolder(train_dir,
                                     transform=data_transforms['training']),
    'testing': datasets.ImageFolder(test_dir,
                                    transform=data_transforms['testing']),
    'validation': datasets.ImageFolder(valid_dir,
                                       transform=data_transforms['validation'])
}

dataloaders = {
    'training': torch.utils.data.DataLoader(image_datasets['training'],
                                            batch_size=batch_size,
                                            shuffle=True),
    'testing': torch.utils.data.DataLoader(image_datasets['testing'],
                                           batch_size=batch_size,
                                           shuffle=False),
    'validation': torch.utils.data.DataLoader(image_datasets['validation'],
                                              batch_size=batch_size,
                                              shuffle=True)
}

# get the length of each dataloaders with batch size 32
training_len = len(dataloaders['training'])
test_len = len(dataloaders['testing'])
validation_len = len(dataloaders['validation'])
class_to_idx = image_datasets['training'].class_to_idx

print('We have ', training_len, 'batches of training images;', 'each with',
      batch_size, 'images')
print('We have ', validation_len, 'batches of validation images;', 'each with',
      batch_size, 'images')
print('We have ', test_len, 'batches of testing images;', 'each with',
      batch_size, 'images')

# Let us preview size of each batch
print('Single batch', next(iter(dataloaders['training']))[0].shape)
# Out:
# We have  100 batches of training images; each with 32 images
# We have  18 batches of validation images; each with 32 images
# We have  3 batches of testing images; each with 32 images
# Single batch torch.Size([32, 3, 224, 224])

# %%
# Transfer learning with GoogLeNet
model = models.googlenet(weights='DEFAULT')

# %%
for param in model.parameters():
    param.requires_grad = False

print(model)

# This is the original classifier with GoogleNet
print()
print('Original classifier of GoogLeNet')
print(model.fc)

# Defining number of hidden units in our fully connected layer
number_of_classes = len(class_to_idx) 
model.fc = nn.Linear(1024, number_of_classes)
print(model)
# Out:
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception3a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception3b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception4a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4c): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4d): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4e): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception5a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception5b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(48, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (aux1): None
#   (aux2): None
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=1024, out_features=1000, bias=True)
# )
#
# Original classifier of GoogLeNet
# Linear(in_features=1024, out_features=1000, bias=True)
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception3a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception3b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception4a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4c): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4d): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4e): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception5a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception5b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(48, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (aux1): None
#   (aux2): None
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=1024, out_features=6, bias=True)
# )

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)

epochs = 10
optimizer = optim.Adam(model.fc.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()  # Changed from NLLLoss to work with raw logits
print_every = 5

validation_accuracies, training_accuracies = [], []
validation_losses, training_losses = [], []

best_validation_accuracy = 0
best_model_weights = None

for e in range(epochs):

    training_loss = training_accuracy = 0
    validation_loss = validation_accuracy = 0

    model.train()
    for batch_idx, (images, labels) in enumerate(dataloaders['training']):

        # Moving images & labels to the GPU if there is one
        images, labels = images.to(device), labels.to(device)

        # Zero gradients first
        optimizer.zero_grad()

        # Forward pass
        logits = model.forward(images)
        loss = criterion(logits, labels)
        
        # Backward pass to compute gradients
        loss.backward()
        
        # Update weights after backward
        optimizer.step()

        # Calculating metrics
        ps = torch.softmax(logits, dim=1)
        top_ps, top_class = ps.topk(1, dim=1)
        matches = (top_class == labels.view(*top_class.shape)).type(
            torch.FloatTensor)
        train_batch_accuracy = matches.mean()

        # Tracking metrics
        training_loss += loss.item()
        train_batch_loss = loss.item()
        training_accuracy += train_batch_accuracy.item()

        if batch_idx % print_every == 0:
            print('epoch', e, 'batch', batch_idx)
            print('training loss per batch', train_batch_loss)
            print('training accuracy per batch', train_batch_accuracy.item())

    # Validation
    model.eval()
    with torch.no_grad():
        for batch_idx, (images, labels) in enumerate(
                dataloaders['validation']):
            images, labels = images.to(device), labels.to(device)
            logits = model(images)  # Changed variable name
            loss = criterion(logits, labels)
            ps = torch.softmax(logits, dim=1)  # Changed from exp
            top_ps, top_class = ps.topk(1, dim=1)
            matches = (top_class == labels.view(*top_class.shape)).type(
                torch.FloatTensor)
            validation_batch_accuracy = matches.mean()

            validation_loss += loss.item()
            validation_batch_loss = loss.item()
            validation_accuracy += validation_batch_accuracy

    # Save best model
    if validation_accuracy >= best_validation_accuracy:
        best_validation_accuracy = validation_accuracy
        best_model_weights = model.state_dict()

    # Summary per epoch
    print('epoch', e, 'summary')
    print('avg training loss per epoch', training_loss / training_len)
    print('avg training accuracy per epoch', training_accuracy / training_len)
    training_losses.append(training_loss / training_len)
    training_accuracies.append(training_accuracy / training_len)

    print('avg validation loss per epoch', validation_loss / validation_len)
    print('avg validation accuracy per epoch',
          validation_accuracy / validation_len)
    validation_losses.append(validation_loss / validation_len)
    validation_accuracies.append(validation_accuracy / validation_len)

    print()
# Out:
# epoch 0 batch 0
# training loss per batch 1.876617431640625
# training accuracy per batch 0.0625
# epoch 0 batch 5
# training loss per batch 1.7793283462524414
# training accuracy per batch 0.1875
# epoch 0 batch 10
# training loss per batch 1.654608130455017
# training accuracy per batch 0.3125
# epoch 0 batch 15
# training loss per batch 1.6375173330307007
# training accuracy per batch 0.34375
# epoch 0 batch 20
# training loss per batch 1.598780632019043
# training accuracy per batch 0.28125
# epoch 0 batch 25
# training loss per batch 1.4488565921783447
# training accuracy per batch 0.5625
# epoch 0 batch 30
# training loss per batch 1.5091675519943237
# training accuracy per batch 0.4375
# epoch 0 batch 35
# training loss per batch 1.3764734268188477
# training accuracy per batch 0.46875
# epoch 0 batch 40
# training loss per batch 1.561377763748169
# training accuracy per batch 0.375
# epoch 0 batch 45
# training loss per batch 1.3257347345352173
# training accuracy per batch 0.5
# epoch 0 batch 50
# training loss per batch 1.4700417518615723
# training accuracy per batch 0.40625
# epoch 0 batch 55
# training loss per batch 1.3121777772903442
# training accuracy per batch 0.59375
# epoch 0 batch 60
# training loss per batch 1.2056450843811035
# training accuracy per batch 0.4375
# epoch 0 batch 65
# training loss per batch 1.2573988437652588
# training accuracy per batch 0.625
# epoch 0 batch 70
# training loss per batch 1.2302902936935425
# training accuracy per batch 0.53125
# epoch 0 batch 75
# training loss per batch 1.2790309190750122
# training accuracy per batch 0.375
# epoch 0 batch 80
# training loss per batch 1.3275762796401978
# training accuracy per batch 0.5
# epoch 0 batch 85
# training loss per batch 1.2252763509750366
# training accuracy per batch 0.625
# epoch 0 batch 90
# training loss per batch 1.2885490655899048
# training accuracy per batch 0.59375
# epoch 0 batch 95
# training loss per batch 1.1052182912826538
# training accuracy per batch 0.59375
# epoch 0 summary
# avg training loss per epoch 1.420344271659851
# avg training accuracy per epoch 0.45928977280855177
# avg validation loss per epoch 1.040184564060635
# avg validation accuracy per epoch tensor(0.7025)
#
# epoch 1 batch 0
# training loss per batch 1.2201815843582153
# training accuracy per batch 0.5
# epoch 1 batch 5
# training loss per batch 1.2554110288619995
# training accuracy per batch 0.5
# epoch 1 batch 10
# training loss per batch 1.0392529964447021
# training accuracy per batch 0.71875
# epoch 1 batch 15
# training loss per batch 1.038400650024414
# training accuracy per batch 0.65625
# epoch 1 batch 20
# training loss per batch 1.2685028314590454
# training accuracy per batch 0.65625
# epoch 1 batch 25
# training loss per batch 1.19390070438385
# training accuracy per batch 0.40625
# epoch 1 batch 30
# training loss per batch 1.0480079650878906
# training accuracy per batch 0.65625
# epoch 1 batch 35
# training loss per batch 1.11304771900177
# training accuracy per batch 0.46875
# epoch 1 batch 40
# training loss per batch 1.3138790130615234
# training accuracy per batch 0.46875
# epoch 1 batch 45
# training loss per batch 1.0809012651443481
# training accuracy per batch 0.65625
# epoch 1 batch 50
# training loss per batch 1.1060959100723267
# training accuracy per batch 0.59375
# epoch 1 batch 55
# training loss per batch 0.9698867797851562
# training accuracy per batch 0.6875
# epoch 1 batch 60
# training loss per batch 1.0183459520339966
# training accuracy per batch 0.59375
# epoch 1 batch 65
# training loss per batch 1.0463824272155762
# training accuracy per batch 0.65625
# epoch 1 batch 70
# training loss per batch 0.9570449590682983
# training accuracy per batch 0.71875
# epoch 1 batch 75
# training loss per batch 0.8810329437255859
# training accuracy per batch 0.65625
# epoch 1 batch 80
# training loss per batch 0.8821204900741577
# training accuracy per batch 0.71875
# epoch 1 batch 85
# training loss per batch 1.0797796249389648
# training accuracy per batch 0.59375
# epoch 1 batch 90
# training loss per batch 1.223178505897522
# training accuracy per batch 0.53125
# epoch 1 batch 95
# training loss per batch 1.1095011234283447
# training accuracy per batch 0.5
# epoch 1 summary
# avg training loss per epoch 1.0815848851203917
# avg training accuracy per epoch 0.6067045456171036
# avg validation loss per epoch 0.8606146739588844
# avg validation accuracy per epoch tensor(0.7317)
#
# epoch 2 batch 0
# training loss per batch 0.9335887432098389
# training accuracy per batch 0.71875
# epoch 2 batch 5
# training loss per batch 0.9588674306869507
# training accuracy per batch 0.65625
# epoch 2 batch 10
# training loss per batch 1.0780566930770874
# training accuracy per batch 0.59375
# epoch 2 batch 15
# training loss per batch 0.9815270900726318
# training accuracy per batch 0.59375
# epoch 2 batch 20
# training loss per batch 1.0161261558532715
# training accuracy per batch 0.65625
# epoch 2 batch 25
# training loss per batch 1.0133333206176758
# training accuracy per batch 0.53125
# epoch 2 batch 30
# training loss per batch 1.0360487699508667
# training accuracy per batch 0.65625
# epoch 2 batch 35
# training loss per batch 1.0450365543365479
# training accuracy per batch 0.59375
# epoch 2 batch 40
# training loss per batch 1.0592882633209229
# training accuracy per batch 0.5625
# epoch 2 batch 45
# training loss per batch 0.9467126131057739
# training accuracy per batch 0.5625
# epoch 2 batch 50
# training loss per batch 0.9326894283294678
# training accuracy per batch 0.6875
# epoch 2 batch 55
# training loss per batch 0.8383504152297974
# training accuracy per batch 0.6875
# epoch 2 batch 60
# training loss per batch 1.12553870677948
# training accuracy per batch 0.46875
# epoch 2 batch 65
# training loss per batch 0.9301194548606873
# training accuracy per batch 0.59375
# epoch 2 batch 70
# training loss per batch 0.9284003973007202
# training accuracy per batch 0.625
# epoch 2 batch 75
# training loss per batch 1.0639595985412598
# training accuracy per batch 0.71875
# epoch 2 batch 80
# training loss per batch 1.0245466232299805
# training accuracy per batch 0.65625
# epoch 2 batch 85
# training loss per batch 0.8801521062850952
# training accuracy per batch 0.6875
# epoch 2 batch 90
# training loss per batch 0.936698853969574
# training accuracy per batch 0.5625
# epoch 2 batch 95
# training loss per batch 0.9521104097366333
# training accuracy per batch 0.625
# epoch 2 summary
# avg training loss per epoch 0.9899642616510391
# avg training accuracy per epoch 0.6232670456171036
# avg validation loss per epoch 0.7925941314962175
# avg validation accuracy per epoch tensor(0.7407)
#
# epoch 3 batch 0
# training loss per batch 0.9745280742645264
# training accuracy per batch 0.71875
# epoch 3 batch 5
# training loss per batch 0.936552882194519
# training accuracy per batch 0.625
# epoch 3 batch 10
# training loss per batch 0.9030596017837524
# training accuracy per batch 0.71875
# epoch 3 batch 15
# training loss per batch 0.8015488982200623
# training accuracy per batch 0.6875
# epoch 3 batch 20
# training loss per batch 1.1554111242294312
# training accuracy per batch 0.53125
# epoch 3 batch 25
# training loss per batch 1.0067787170410156
# training accuracy per batch 0.625
# epoch 3 batch 30
# training loss per batch 0.9181743264198303
# training accuracy per batch 0.75
# epoch 3 batch 35
# training loss per batch 0.9927054643630981
# training accuracy per batch 0.625
# epoch 3 batch 40
# training loss per batch 0.9276872277259827
# training accuracy per batch 0.71875
# epoch 3 batch 45
# training loss per batch 0.9351480603218079
# training accuracy per batch 0.59375
# epoch 3 batch 50
# training loss per batch 0.9057186245918274
# training accuracy per batch 0.875
# epoch 3 batch 55
# training loss per batch 0.6828184127807617
# training accuracy per batch 0.71875
# epoch 3 batch 60
# training loss per batch 0.770354151725769
# training accuracy per batch 0.71875
# epoch 3 batch 65
# training loss per batch 1.0862033367156982
# training accuracy per batch 0.5625
# epoch 3 batch 70
# training loss per batch 0.8108937740325928
# training accuracy per batch 0.6875
# epoch 3 batch 75
# training loss per batch 0.8700634241104126
# training accuracy per batch 0.625
# epoch 3 batch 80
# training loss per batch 0.9038267731666565
# training accuracy per batch 0.53125
# epoch 3 batch 85
# training loss per batch 1.063535213470459
# training accuracy per batch 0.59375
# epoch 3 batch 90
# training loss per batch 0.8537725210189819
# training accuracy per batch 0.75
# epoch 3 batch 95
# training loss per batch 1.0721644163131714
# training accuracy per batch 0.53125
# epoch 3 summary
# avg training loss per epoch 0.9470948022603989
# avg training accuracy per epoch 0.6463068181276321
# avg validation loss per epoch 0.74951162106461
# avg validation accuracy per epoch tensor(0.7589)
#
# epoch 4 batch 0
# training loss per batch 0.8579649329185486
# training accuracy per batch 0.65625
# epoch 4 batch 5
# training loss per batch 0.9299691319465637
# training accuracy per batch 0.625
# epoch 4 batch 10
# training loss per batch 0.9368754029273987
# training accuracy per batch 0.59375
# epoch 4 batch 15
# training loss per batch 0.8194591999053955
# training accuracy per batch 0.59375
# epoch 4 batch 20
# training loss per batch 1.2632904052734375
# training accuracy per batch 0.53125
# epoch 4 batch 25
# training loss per batch 0.9147526025772095
# training accuracy per batch 0.6875
# epoch 4 batch 30
# training loss per batch 0.6050599217414856
# training accuracy per batch 0.78125
# epoch 4 batch 35
# training loss per batch 0.9611284732818604
# training accuracy per batch 0.625
# epoch 4 batch 40
# training loss per batch 0.820953905582428
# training accuracy per batch 0.71875
# epoch 4 batch 45
# training loss per batch 0.7262582182884216
# training accuracy per batch 0.71875
# epoch 4 batch 50
# training loss per batch 0.8825017809867859
# training accuracy per batch 0.65625
# epoch 4 batch 55
# training loss per batch 1.0446165800094604
# training accuracy per batch 0.5625
# epoch 4 batch 60
# training loss per batch 0.9275486469268799
# training accuracy per batch 0.625
# epoch 4 batch 65
# training loss per batch 0.7979992628097534
# training accuracy per batch 0.625
# epoch 4 batch 70
# training loss per batch 1.271107792854309
# training accuracy per batch 0.46875
# epoch 4 batch 75
# training loss per batch 0.8557637929916382
# training accuracy per batch 0.6875
# epoch 4 batch 80
# training loss per batch 0.9359471201896667
# training accuracy per batch 0.71875
# epoch 4 batch 85
# training loss per batch 0.9691387414932251
# training accuracy per batch 0.65625
# epoch 4 batch 90
# training loss per batch 0.8616156578063965
# training accuracy per batch 0.625
# epoch 4 batch 95
# training loss per batch 0.876480221748352
# training accuracy per batch 0.75
# epoch 4 summary
# avg training loss per epoch 0.923050457239151
# avg training accuracy per epoch 0.6392329546809197
# avg validation loss per epoch 0.7878729403018951
# avg validation accuracy per epoch tensor(0.7176)
#
# epoch 5 batch 0
# training loss per batch 0.6682023406028748
# training accuracy per batch 0.78125
# epoch 5 batch 5
# training loss per batch 0.9104695320129395
# training accuracy per batch 0.65625
# epoch 5 batch 10
# training loss per batch 0.8092088103294373
# training accuracy per batch 0.75
# epoch 5 batch 15
# training loss per batch 0.844493567943573
# training accuracy per batch 0.59375
# epoch 5 batch 20
# training loss per batch 0.9724196791648865
# training accuracy per batch 0.65625
# epoch 5 batch 25
# training loss per batch 1.3448588848114014
# training accuracy per batch 0.5
# epoch 5 batch 30
# training loss per batch 1.116460919380188
# training accuracy per batch 0.53125
# epoch 5 batch 35
# training loss per batch 1.056409478187561
# training accuracy per batch 0.5
# epoch 5 batch 40
# training loss per batch 0.8802206516265869
# training accuracy per batch 0.625
# epoch 5 batch 45
# training loss per batch 1.0328197479248047
# training accuracy per batch 0.59375
# epoch 5 batch 50
# training loss per batch 0.9993471503257751
# training accuracy per batch 0.59375
# epoch 5 batch 55
# training loss per batch 0.9986286163330078
# training accuracy per batch 0.6875
# epoch 5 batch 60
# training loss per batch 0.7465681433677673
# training accuracy per batch 0.6875
# epoch 5 batch 65
# training loss per batch 0.9452674984931946
# training accuracy per batch 0.59375
# epoch 5 batch 70
# training loss per batch 0.907429039478302
# training accuracy per batch 0.625
# epoch 5 batch 75
# training loss per batch 0.9414737820625305
# training accuracy per batch 0.6875
# epoch 5 batch 80
# training loss per batch 0.9026311635971069
# training accuracy per batch 0.6875
# epoch 5 batch 85
# training loss per batch 1.111924409866333
# training accuracy per batch 0.5625
# epoch 5 batch 90
# training loss per batch 0.8840949535369873
# training accuracy per batch 0.65625
# epoch 5 batch 95
# training loss per batch 0.9517650604248047
# training accuracy per batch 0.625
# epoch 5 summary
# avg training loss per epoch 0.9137444174289704
# avg training accuracy per epoch 0.6444602274894714
# avg validation loss per epoch 0.6980909920401044
# avg validation accuracy per epoch tensor(0.7672)
#
# epoch 6 batch 0
# training loss per batch 1.0170533657073975
# training accuracy per batch 0.625
# epoch 6 batch 5
# training loss per batch 0.6388335824012756
# training accuracy per batch 0.78125
# epoch 6 batch 10
# training loss per batch 1.028868556022644
# training accuracy per batch 0.625
# epoch 6 batch 15
# training loss per batch 1.2344558238983154
# training accuracy per batch 0.53125
# epoch 6 batch 20
# training loss per batch 0.8341813683509827
# training accuracy per batch 0.71875
# epoch 6 batch 25
# training loss per batch 0.6818034648895264
# training accuracy per batch 0.78125
# epoch 6 batch 30
# training loss per batch 0.9194361567497253
# training accuracy per batch 0.6875
# epoch 6 batch 35
# training loss per batch 1.1186151504516602
# training accuracy per batch 0.59375
# epoch 6 batch 40
# training loss per batch 0.8177838325500488
# training accuracy per batch 0.6875
# epoch 6 batch 45
# training loss per batch 0.967319905757904
# training accuracy per batch 0.53125
# epoch 6 batch 50
# training loss per batch 1.0996798276901245
# training accuracy per batch 0.65625
# epoch 6 batch 55
# training loss per batch 0.9613200426101685
# training accuracy per batch 0.65625
# epoch 6 batch 60
# training loss per batch 0.8338522911071777
# training accuracy per batch 0.625
# epoch 6 batch 65
# training loss per batch 0.7383537292480469
# training accuracy per batch 0.78125
# epoch 6 batch 70
# training loss per batch 0.674635112285614
# training accuracy per batch 0.75
# epoch 6 batch 75
# training loss per batch 0.979894757270813
# training accuracy per batch 0.59375
# epoch 6 batch 80
# training loss per batch 0.6963096857070923
# training accuracy per batch 0.78125
# epoch 6 batch 85
# training loss per batch 0.7938582897186279
# training accuracy per batch 0.6875
# epoch 6 batch 90
# training loss per batch 0.9507215619087219
# training accuracy per batch 0.71875
# epoch 6 batch 95
# training loss per batch 0.830442488193512
# training accuracy per batch 0.6875
# epoch 6 summary
# avg training loss per epoch 0.8815593069791794
# avg training accuracy per epoch 0.6654545456171036
# avg validation loss per epoch 0.6857999149296019
# avg validation accuracy per epoch tensor(0.7641)
#
# epoch 7 batch 0
# training loss per batch 0.9014745950698853
# training accuracy per batch 0.59375
# epoch 7 batch 5
# training loss per batch 0.9183300733566284
# training accuracy per batch 0.6875
# epoch 7 batch 10
# training loss per batch 0.7889596819877625
# training accuracy per batch 0.71875
# epoch 7 batch 15
# training loss per batch 0.9784314036369324
# training accuracy per batch 0.625
# epoch 7 batch 20
# training loss per batch 0.8139034509658813
# training accuracy per batch 0.6875
# epoch 7 batch 25
# training loss per batch 0.8286377191543579
# training accuracy per batch 0.65625
# epoch 7 batch 30
# training loss per batch 1.071642279624939
# training accuracy per batch 0.53125
# epoch 7 batch 35
# training loss per batch 0.8376664519309998
# training accuracy per batch 0.65625
# epoch 7 batch 40
# training loss per batch 0.8682109117507935
# training accuracy per batch 0.78125
# epoch 7 batch 45
# training loss per batch 1.1215945482254028
# training accuracy per batch 0.5625
# epoch 7 batch 50
# training loss per batch 0.9610399007797241
# training accuracy per batch 0.65625
# epoch 7 batch 55
# training loss per batch 0.8077053427696228
# training accuracy per batch 0.8125
# epoch 7 batch 60
# training loss per batch 0.849369466304779
# training accuracy per batch 0.6875
# epoch 7 batch 65
# training loss per batch 0.7643728256225586
# training accuracy per batch 0.65625
# epoch 7 batch 70
# training loss per batch 0.621457576751709
# training accuracy per batch 0.78125
# epoch 7 batch 75
# training loss per batch 0.6961053013801575
# training accuracy per batch 0.78125
# epoch 7 batch 80
# training loss per batch 0.8644071817398071
# training accuracy per batch 0.6875
# epoch 7 batch 85
# training loss per batch 0.9634099006652832
# training accuracy per batch 0.59375
# epoch 7 batch 90
# training loss per batch 1.0009931325912476
# training accuracy per batch 0.65625
# epoch 7 batch 95
# training loss per batch 0.8305877447128296
# training accuracy per batch 0.625
# epoch 7 summary
# avg training loss per epoch 0.8949487048387528
# avg training accuracy per epoch 0.6575852274894715
# avg validation loss per epoch 0.7162472042772505
# avg validation accuracy per epoch tensor(0.7263)
#
# epoch 8 batch 0
# training loss per batch 0.758979320526123
# training accuracy per batch 0.75
# epoch 8 batch 5
# training loss per batch 1.1122318506240845
# training accuracy per batch 0.59375
# epoch 8 batch 10
# training loss per batch 1.0070245265960693
# training accuracy per batch 0.46875
# epoch 8 batch 15
# training loss per batch 0.851080060005188
# training accuracy per batch 0.6875
# epoch 8 batch 20
# training loss per batch 0.8275125026702881
# training accuracy per batch 0.75
# epoch 8 batch 25
# training loss per batch 0.7673806548118591
# training accuracy per batch 0.65625
# epoch 8 batch 30
# training loss per batch 1.1810253858566284
# training accuracy per batch 0.46875
# epoch 8 batch 35
# training loss per batch 0.7901806831359863
# training accuracy per batch 0.6875
# epoch 8 batch 40
# training loss per batch 0.7780674695968628
# training accuracy per batch 0.625
# epoch 8 batch 45
# training loss per batch 0.9109804034233093
# training accuracy per batch 0.71875
# epoch 8 batch 50
# training loss per batch 1.0408775806427002
# training accuracy per batch 0.59375
# epoch 8 batch 55
# training loss per batch 0.7826484441757202
# training accuracy per batch 0.5625
# epoch 8 batch 60
# training loss per batch 1.152579665184021
# training accuracy per batch 0.5
# epoch 8 batch 65
# training loss per batch 0.9510161280632019
# training accuracy per batch 0.6875
# epoch 8 batch 70
# training loss per batch 0.6971575021743774
# training accuracy per batch 0.75
# epoch 8 batch 75
# training loss per batch 0.5488039255142212
# training accuracy per batch 0.71875
# epoch 8 batch 80
# training loss per batch 0.9476715326309204
# training accuracy per batch 0.6875
# epoch 8 batch 85
# training loss per batch 0.9492081999778748
# training accuracy per batch 0.5
# epoch 8 batch 90
# training loss per batch 0.87555992603302
# training accuracy per batch 0.59375
# epoch 8 batch 95
# training loss per batch 0.8225367665290833
# training accuracy per batch 0.6875
# epoch 8 summary
# avg training loss per epoch 0.9056037896871567
# avg training accuracy per epoch 0.6410795456171036
# avg validation loss per epoch 0.6861935787730746
# avg validation accuracy per epoch tensor(0.7380)
#
# epoch 9 batch 0
# training loss per batch 0.8949500322341919
# training accuracy per batch 0.625
# epoch 9 batch 5
# training loss per batch 0.8774673938751221
# training accuracy per batch 0.65625
# epoch 9 batch 10
# training loss per batch 1.0465483665466309
# training accuracy per batch 0.46875
# epoch 9 batch 15
# training loss per batch 0.8293802738189697
# training accuracy per batch 0.6875
# epoch 9 batch 20
# training loss per batch 0.6392765045166016
# training accuracy per batch 0.75
# epoch 9 batch 25
# training loss per batch 0.8018122315406799
# training accuracy per batch 0.71875
# epoch 9 batch 30
# training loss per batch 0.621322512626648
# training accuracy per batch 0.8125
# epoch 9 batch 35
# training loss per batch 0.6673434972763062
# training accuracy per batch 0.8125
# epoch 9 batch 40
# training loss per batch 0.7869987487792969
# training accuracy per batch 0.78125
# epoch 9 batch 45
# training loss per batch 0.9140664935112
# training accuracy per batch 0.59375
# epoch 9 batch 50
# training loss per batch 0.6789293885231018
# training accuracy per batch 0.71875
# epoch 9 batch 55
# training loss per batch 0.8944469690322876
# training accuracy per batch 0.65625
# epoch 9 batch 60
# training loss per batch 0.9282252788543701
# training accuracy per batch 0.625
# epoch 9 batch 65
# training loss per batch 0.8209079504013062
# training accuracy per batch 0.71875
# epoch 9 batch 70
# training loss per batch 0.8056864738464355
# training accuracy per batch 0.65625
# epoch 9 batch 75
# training loss per batch 0.9327680468559265
# training accuracy per batch 0.65625
# epoch 9 batch 80
# training loss per batch 1.1401691436767578
# training accuracy per batch 0.53125
# epoch 9 batch 85
# training loss per batch 0.8127601742744446
# training accuracy per batch 0.71875
# epoch 9 batch 90
# training loss per batch 0.6902391314506531
# training accuracy per batch 0.84375
# epoch 9 batch 95
# training loss per batch 1.053714632987976
# training accuracy per batch 0.625
# epoch 9 summary
# avg training loss per epoch 0.8522992730140686
# avg training accuracy per epoch 0.6775852274894715
# avg validation loss per epoch 0.6664133850071166
# avg validation accuracy per epoch tensor(0.7558)

# %%
# Plotting the summary of training and validation losses
plt.figure()
plt.title("Training Summary of Loss")
plt.plot(training_losses, label='Training Loss')
plt.plot(validation_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plotting the summary of training and validation accuracies
plt.figure()
plt.title("Training Summary of Accuracy")
plt.plot(training_accuracies, label='Training Accuracy')
plt.plot(validation_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Load the best model so far
model.load_state_dict(best_model_weights)
model.eval()  # Set to evaluation mode

total_correct = 0
total_samples = 0
predictions = []
label_data = []

with torch.no_grad():  # Disable gradient computation for testing
    for images, labels in dataloaders['testing']:
        images, labels = images.to(device), labels.to(device)
        
        logits = model(images)
        ps = torch.softmax(logits, dim=1)
        
        top_ps, top_class = ps.topk(1, dim=1)
        
        total_correct += (top_class == labels.view(*top_class.shape)).sum().item()
        total_samples += labels.size(0)
        
        predictions.append(top_class)
        label_data.append(labels)

test_accuracy = total_correct / total_samples
print(f'Test Accuracy: {test_accuracy:.4f}')

predictions = torch.cat(predictions)
label_data = torch.cat(label_data)
# Out:
# Test Accuracy: 0.7955

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix as conf_mat
import numpy as np

# Defining class labels
class_names = ['Acral Lentiginous Melanoma', 'Blue Finger', 'Clubbing', 'Healthy Nail', 'Onychogryphosis', 'Pitting']

cf = conf_mat(label_data, predictions)

# Plot raw confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cf, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.tight_layout()
plt.show()

# Plot normalized confusion matrix
plt.figure(figsize=(10, 8))
ncf = cf.astype('float') / cf.sum(axis=1, keepdims=True)  # Normalize by row (true labels)
sns.heatmap(ncf, annot=True, fmt='.2%', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('Normalized Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix as conf_mat

# Defining class lables
class_names = ['Acral Lentiginous Melanoma', 'Blue Finger', 'Clubbing', 'Healthy Nail', 'Onychogryphosis', 'Pitting']

cf = conf_mat(label_data, predictions)

# Calculate Overall Accuracy
overall_accuracy = np.trace(cf) / cf.sum()

# Calculate TP, FP, FN, TN for each class
metrics = []
for i, class_name in enumerate(class_names):
    TP = cf[i, i]
    FP = cf[:, i].sum() - TP
    FN = cf[i, :].sum() - TP
    TN = cf.sum() - TP - FP - FN
    
    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    support = cf[i, :].sum()
    
    metrics.append({
        'Class': class_name,
        'TP': TP,
        'FP': FP,
        'FN': FN,
        'TN': TN,
        'Precision': round(precision, 4),
        'Recall': round(recall, 4),
        'F1-Score': round(f1, 4),
        'Support': support
    })

metrics_df = pd.DataFrame(metrics)

# Calculate Macro Average
macro_avg = {
    'Class': 'Macro Avg',
    'TP': ' ',
    'FP': ' ',
    'FN': ' ',
    'TN': ' ',
    'Precision': round(metrics_df['Precision'].mean(), 4),
    'Recall': round(metrics_df['Recall'].mean(), 4),
    'F1-Score': round(metrics_df['F1-Score'].mean(), 4),
    'Support': metrics_df['Support'].sum()
}

# Calculate Weighted Average
total_support = metrics_df['Support'].sum()
weighted_avg = {
    'Class': 'Weighted Avg',
    'TP': ' ',
    'FP': ' ',
    'FN': ' ',
    'TN': ' ',
    'Precision': round((metrics_df['Precision'] * metrics_df['Support']).sum() / total_support, 4),
    'Recall': round((metrics_df['Recall'] * metrics_df['Support']).sum() / total_support, 4),
    'F1-Score': round((metrics_df['F1-Score'] * metrics_df['Support']).sum() / total_support, 4),
    'Support': total_support
}

# Add averages to dataframe
metrics_df = pd.concat([metrics_df, pd.DataFrame([macro_avg, weighted_avg])], ignore_index=True)

# Print results
print(f"{'='*60}")
print(f"OVERALL ACCURACY: {round(overall_accuracy, 4)} ({round(overall_accuracy*100, 2)}%)")
print(f"{'='*60}\n")
print(metrics_df.to_string(index=False))
# Out:
# ============================================================
# OVERALL ACCURACY: 0.7955 (79.55%)
# ============================================================
#
#                      Class TP FP FN TN  Precision  Recall  F1-Score  Support
# Acral Lentiginous Melanoma 15  5  0 68     0.7500  1.0000    0.8571       15
#                Blue Finger 20  0  0 68     1.0000  1.0000    1.0000       20
#                   Clubbing  7  2  5 74     0.7778  0.5833    0.6667       12
#               Healthy Nail  9  8  0 71     0.5294  1.0000    0.6923        9
#            Onychogryphosis  6  1 10 71     0.8571  0.3750    0.5217       16
#                    Pitting 13  2  3 70     0.8667  0.8125    0.8387       16
#                  Macro Avg                 0.7968  0.7951    0.7628       88
#               Weighted Avg                 0.8287  0.7954    0.7824       88
