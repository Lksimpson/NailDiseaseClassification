# %%
import matplotlib.pyplot as plt
from collections import OrderedDict

from copy import deepcopy
import torch
from torchvision import models  
from torch import nn
from torch import optim
from torchvision import datasets, transforms, models

# download the data
data_dir = '/kaggle/input/clean-datasetsplit8515/data'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# Process with some data transformation, do not change
data_transforms = {
    'training': transforms.Compose([transforms.RandomResizedCrop(224),
                                    transforms.RandomHorizontalFlip(),
                                    transforms.RandomRotation(30),
                                    transforms.ToTensor(),
                                    transforms.Normalize([0.485, 0.456, 0.406],
                                                         [0.229, 0.224,
                                                          0.225])]),

    'validation': transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize(
                                          [0.485, 0.456, 0.406],
                                          [0.229, 0.224, 0.225])]),

    'testing': transforms.Compose([transforms.Resize(256),
                                   transforms.CenterCrop(224),
                                   transforms.ToTensor(),
                                   transforms.Normalize([0.485, 0.456, 0.406],
                                                        [0.229, 0.224,
                                                         0.225])])
}
# This specifies how many images to process per training/validation
batch_size = 32

image_datasets = {
    'training': datasets.ImageFolder(train_dir,
                                     transform=data_transforms['training']),
    'testing': datasets.ImageFolder(test_dir,
                                    transform=data_transforms['testing']),
    'validation': datasets.ImageFolder(valid_dir,
                                       transform=data_transforms['validation'])
}

dataloaders = {
    'training': torch.utils.data.DataLoader(image_datasets['training'],
                                            batch_size=batch_size,
                                            shuffle=True),
    'testing': torch.utils.data.DataLoader(image_datasets['testing'],
                                           batch_size=batch_size,
                                           shuffle=False),
    'validation': torch.utils.data.DataLoader(image_datasets['validation'],
                                              batch_size=batch_size,
                                              shuffle=True)
}

# get the length of each dataloaders; with batch size=256, you should have 26 batches of training samples, each with 256 images 
training_len = len(dataloaders['training'])
test_len = len(dataloaders['testing'])
validation_len = len(dataloaders['validation'])
class_to_idx = image_datasets['training'].class_to_idx

print('We have ', training_len, 'batches of training images;', 'each with',
      batch_size, 'images')
print('We have ', validation_len, 'batches of validation images;', 'each with',
      batch_size, 'images')
print('We have ', test_len, 'batches of testing images;', 'each with',
      batch_size, 'images')

# Let us preview size of each batch
print('Single batch', next(iter(dataloaders['training']))[0].shape)
# Transfer learning with AlexNet
model = models.alexnet(weights='DEFAULT')
for param in model.parameters():
    param.requires_grad = False

print(model)

# This is the original classifier with alexnet
print()
print('Original classifier of AlexNet')
print(model.classifier)

# Defining number of hidden units in our fully connected layer
number_of_classes = len(class_to_idx) 
model.classifier[6] = nn.Linear(4096, number_of_classes)
print(model)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)

epochs = 10
optimizer = optim.Adam(model.classifier[6].parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()  # Changed from NLLLoss - this works with raw logits
print_every = 5

validation_accuracies, training_accuracies = [], []
validation_losses, training_losses = [], []

best_validation_accuracy = 0
best_model_weights = None

for e in range(epochs):

    training_loss = training_accuracy = 0
    validation_loss = validation_accuracy = 0

    model.train()
    for batch_idx, (images, labels) in enumerate(dataloaders['training']):

        # Moving images & labels to the GPU if there is one
        images, labels = images.to(device), labels.to(device)

        # Zero gradients first
        optimizer.zero_grad()

        # Forward pass
        logits = model.forward(images)  # Changed variable name for clarity
        loss = criterion(logits, labels)
        
        # Backward pass to compute gradients
        loss.backward()
        
        # Update weights after backward
        optimizer.step()

        # Calculating metrics
        ps = torch.softmax(logits, dim=1)  # Changed from exp since we have raw logits now
        top_ps, top_class = ps.topk(1, dim=1)
        matches = (top_class == labels.view(*top_class.shape)).type(
            torch.FloatTensor)
        train_batch_accuracy = matches.mean()

        # Tracking metrics
        training_loss += loss.item()
        train_batch_loss = loss.item()
        training_accuracy += train_batch_accuracy.item()

        if batch_idx % print_every == 0:
            print('epoch', e, 'batch', batch_idx)
            print('training loss per batch', train_batch_loss)
            print('training accuracy per batch', train_batch_accuracy.item())

    # Validation
    model.eval()
    with torch.no_grad():
        for batch_idx, (images, labels) in enumerate(
                dataloaders['validation']):
            images, labels = images.to(device), labels.to(device)
            logits = model(images)  # Changed variable name
            loss = criterion(logits, labels)
            ps = torch.softmax(logits, dim=1)  # Changed from exp
            top_ps, top_class = ps.topk(1, dim=1)
            matches = (top_class == labels.view(*top_class.shape)).type(
                torch.FloatTensor)
            validation_batch_accuracy = matches.mean()

            validation_loss += loss.item()
            validation_batch_loss = loss.item()
            validation_accuracy += validation_batch_accuracy

    # Save best model
    if validation_accuracy >= best_validation_accuracy:
        best_validation_accuracy = validation_accuracy
        best_model_weights = model.state_dict()

    # Summary per epoch
    print('epoch', e, 'summary')
    print('avg training loss per epoch', training_loss / training_len)
    print('avg training accuracy per epoch', training_accuracy / training_len)
    training_losses.append(training_loss / training_len)
    training_accuracies.append(training_accuracy / training_len)

    print('avg validation loss per epoch', validation_loss / validation_len)
    print('avg validation accuracy per epoch',
          validation_accuracy / validation_len)
    validation_losses.append(validation_loss / validation_len)
    validation_accuracies.append(validation_accuracy / validation_len)

    print()
plt.figure()
plt.title("Training Summary of Loss")
plt.plot(training_losses, label='Training Loss')
plt.plot(validation_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure()
plt.title("Training Summary of Accuracy")
plt.plot(training_accuracies, label='Training Accuracy')
plt.plot(validation_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Load the best model so far
model.load_state_dict(best_model_weights)
model.eval()  # Set to evaluation mode

total_correct = 0
total_samples = 0
predictions = []
label_data = []

with torch.no_grad():  # Disable gradient computation for testing
    for images, labels in dataloaders['testing']:
        images, labels = images.to(device), labels.to(device)
        
        logits = model(images)
        ps = torch.softmax(logits, dim=1)
        
        top_ps, top_class = ps.topk(1, dim=1)
        
        total_correct += (top_class == labels.view(*top_class.shape)).sum().item()
        total_samples += labels.size(0)
        
        predictions.append(top_class)
        label_data.append(labels)

test_accuracy = total_correct / total_samples
print(f'Test Accuracy: {test_accuracy:.4f}')

predictions = torch.cat(predictions).cpu()
label_data = torch.cat(label_data).cpu()

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix as conf_mat
import numpy as np

# Your class labels - replace these with your actual class names
class_names = ['Acral Lentiginous Melanoma', 'Blue Finger', 'Clubbing', 'Healthy Nail', 'Onychogryphosis', 'Pitting']

cf = conf_mat(label_data, predictions)

# Plot raw confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cf, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.tight_layout()
plt.show()

# Plot normalized confusion matrix
plt.figure(figsize=(10, 8))
ncf = cf.astype('float') / cf.sum(axis=1, keepdims=True)  # Normalize by row (true labels)
sns.heatmap(ncf, annot=True, fmt='.2%', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('Normalized Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.tight_layout()
plt.show()

import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix as conf_mat

# Your class labels - replace with actual names
class_names = ['Acral Lentiginous Melanoma', 'Blue Finger', 'Clubbing', 'Healthy Nail', 'Onychogryphosis', 'Pitting']

cf = conf_mat(label_data, predictions)

# Calculate Overall Accuracy
overall_accuracy = np.trace(cf) / cf.sum()

# Calculate TP, FP, FN, TN for each class
metrics = []
for i, class_name in enumerate(class_names):
    TP = cf[i, i]
    FP = cf[:, i].sum() - TP
    FN = cf[i, :].sum() - TP
    TN = cf.sum() - TP - FP - FN
    
    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    support = cf[i, :].sum()
    
    metrics.append({
        'Class': class_name,
        'TP': TP,
        'FP': FP,
        'FN': FN,
        'TN': TN,
        'Precision': round(precision, 4),
        'Recall': round(recall, 4),
        'F1-Score': round(f1, 4),
        'Support': support
    })

metrics_df = pd.DataFrame(metrics)

# Calculate Macro Average
macro_avg = {
    'Class': 'Macro Avg',
    'TP': ' ',
    'FP': ' ',
    'FN': ' ',
    'TN': ' ',
    'Precision': round(metrics_df['Precision'].mean(), 4),
    'Recall': round(metrics_df['Recall'].mean(), 4),
    'F1-Score': round(metrics_df['F1-Score'].mean(), 4),
    'Support': metrics_df['Support'].sum()
}

# Calculate Weighted Average
total_support = metrics_df['Support'].sum()
weighted_avg = {
    'Class': 'Weighted Avg',
    'TP': ' ',
    'FP': ' ',
    'FN': ' ',
    'TN': ' ',
    'Precision': round((metrics_df['Precision'] * metrics_df['Support']).sum() / total_support, 4),
    'Recall': round((metrics_df['Recall'] * metrics_df['Support']).sum() / total_support, 4),
    'F1-Score': round((metrics_df['F1-Score'] * metrics_df['Support']).sum() / total_support, 4),
    'Support': total_support
}

# Add averages to dataframe
metrics_df = pd.concat([metrics_df, pd.DataFrame([macro_avg, weighted_avg])], ignore_index=True)

# Print results
print(f"{'='*60}")
print(f"OVERALL ACCURACY: {round(overall_accuracy, 4)} ({round(overall_accuracy*100, 2)}%)")
print(f"{'='*60}\n")
print(metrics_df.to_string(index=False))
# Out:
# We have  100 batches of training images; each with 32 images
# We have  18 batches of validation images; each with 32 images
# We have  3 batches of testing images; each with 32 images
# Single batch torch.Size([32, 3, 224, 224])
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 205MB/s]
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )
#
# Original classifier of AlexNet
# Sequential(
#   (0): Dropout(p=0.5, inplace=False)
#   (1): Linear(in_features=9216, out_features=4096, bias=True)
#   (2): ReLU(inplace=True)
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=4096, out_features=4096, bias=True)
#   (5): ReLU(inplace=True)
#   (6): Linear(in_features=4096, out_features=1000, bias=True)
# )
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=6, bias=True)
#   )
# )
# epoch 0 batch 0
# training loss per batch 1.8430776596069336
# training accuracy per batch 0.1875
# epoch 0 batch 5
# training loss per batch 1.7071681022644043
# training accuracy per batch 0.40625
# epoch 0 batch 10
# training loss per batch 1.3483339548110962
# training accuracy per batch 0.5
# epoch 0 batch 15
# training loss per batch 1.1393165588378906
# training accuracy per batch 0.53125
# epoch 0 batch 20
# training loss per batch 0.8681997060775757
# training accuracy per batch 0.625
# epoch 0 batch 25
# training loss per batch 0.9789304733276367
# training accuracy per batch 0.59375
# epoch 0 batch 30
# training loss per batch 1.0836758613586426
# training accuracy per batch 0.625
# epoch 0 batch 35
# training loss per batch 1.0134379863739014
# training accuracy per batch 0.625
# epoch 0 batch 40
# training loss per batch 1.2182643413543701
# training accuracy per batch 0.375
# epoch 0 batch 45
# training loss per batch 0.9060396552085876
# training accuracy per batch 0.65625
# epoch 0 batch 50
# training loss per batch 0.9973421692848206
# training accuracy per batch 0.625
# epoch 0 batch 55
# training loss per batch 1.4520153999328613
# training accuracy per batch 0.4375
# epoch 0 batch 60
# training loss per batch 1.0837291479110718
# training accuracy per batch 0.59375
# epoch 0 batch 65
# training loss per batch 0.9936219453811646
# training accuracy per batch 0.65625
# epoch 0 batch 70
# training loss per batch 1.04402756690979
# training accuracy per batch 0.5
# epoch 0 batch 75
# training loss per batch 1.0981690883636475
# training accuracy per batch 0.5625
# epoch 0 batch 80
# training loss per batch 1.0554823875427246
# training accuracy per batch 0.59375
# epoch 0 batch 85
# training loss per batch 0.9439663290977478
# training accuracy per batch 0.59375
# epoch 0 batch 90
# training loss per batch 1.1100069284439087
# training accuracy per batch 0.625
# epoch 0 batch 95
# training loss per batch 0.9733633399009705
# training accuracy per batch 0.65625
# epoch 0 summary
# avg training loss per epoch 1.1596114021539687
# avg training accuracy per epoch 0.5389204546809196
# avg validation loss per epoch 0.8322069280677371
# avg validation accuracy per epoch tensor(0.6807)
#
# epoch 1 batch 0
# training loss per batch 1.088944435119629
# training accuracy per batch 0.53125
# epoch 1 batch 5
# training loss per batch 1.1466344594955444
# training accuracy per batch 0.5
# epoch 1 batch 10
# training loss per batch 0.6469739675521851
# training accuracy per batch 0.71875
# epoch 1 batch 15
# training loss per batch 1.3289631605148315
# training accuracy per batch 0.53125
# epoch 1 batch 20
# training loss per batch 1.119014859199524
# training accuracy per batch 0.53125
# epoch 1 batch 25
# training loss per batch 0.7049140334129333
# training accuracy per batch 0.65625
# epoch 1 batch 30
# training loss per batch 1.1824500560760498
# training accuracy per batch 0.46875
# epoch 1 batch 35
# training loss per batch 1.0150853395462036
# training accuracy per batch 0.65625
# epoch 1 batch 40
# training loss per batch 0.8991262316703796
# training accuracy per batch 0.59375
# epoch 1 batch 45
# training loss per batch 1.024405837059021
# training accuracy per batch 0.625
# epoch 1 batch 50
# training loss per batch 1.0424561500549316
# training accuracy per batch 0.53125
# epoch 1 batch 55
# training loss per batch 1.0542917251586914
# training accuracy per batch 0.625
# epoch 1 batch 60
# training loss per batch 1.200594186782837
# training accuracy per batch 0.53125
# epoch 1 batch 65
# training loss per batch 0.9780959486961365
# training accuracy per batch 0.53125
# epoch 1 batch 70
# training loss per batch 1.4509568214416504
# training accuracy per batch 0.46875
# epoch 1 batch 75
# training loss per batch 1.160331130027771
# training accuracy per batch 0.59375
# epoch 1 batch 80
# training loss per batch 0.9286540150642395
# training accuracy per batch 0.625
# epoch 1 batch 85
# training loss per batch 1.1332950592041016
# training accuracy per batch 0.53125
# epoch 1 batch 90
# training loss per batch 1.045827865600586
# training accuracy per batch 0.53125
# epoch 1 batch 95
# training loss per batch 0.7902256846427917
# training accuracy per batch 0.71875
# epoch 1 summary
# avg training loss per epoch 1.0113651114702225
# avg training accuracy per epoch 0.5986079546809197
# avg validation loss per epoch 0.7538071009847853
# avg validation accuracy per epoch tensor(0.7224)
#
# epoch 2 batch 0
# training loss per batch 1.0600883960723877
# training accuracy per batch 0.65625
# epoch 2 batch 5
# training loss per batch 0.8106570839881897
# training accuracy per batch 0.6875
# epoch 2 batch 10
# training loss per batch 1.0849997997283936
# training accuracy per batch 0.65625
# epoch 2 batch 15
# training loss per batch 1.1558223962783813
# training accuracy per batch 0.53125
# epoch 2 batch 20
# training loss per batch 0.9004100561141968
# training accuracy per batch 0.53125
# epoch 2 batch 25
# training loss per batch 1.3454091548919678
# training accuracy per batch 0.40625
# epoch 2 batch 30
# training loss per batch 1.2329100370407104
# training accuracy per batch 0.46875
# epoch 2 batch 35
# training loss per batch 1.1254812479019165
# training accuracy per batch 0.46875
# epoch 2 batch 40
# training loss per batch 0.8546749949455261
# training accuracy per batch 0.625
# epoch 2 batch 45
# training loss per batch 0.9313045144081116
# training accuracy per batch 0.5625
# epoch 2 batch 50
# training loss per batch 1.1175509691238403
# training accuracy per batch 0.59375
# epoch 2 batch 55
# training loss per batch 1.0344561338424683
# training accuracy per batch 0.625
# epoch 2 batch 60
# training loss per batch 1.5522868633270264
# training accuracy per batch 0.5
# epoch 2 batch 65
# training loss per batch 0.944196343421936
# training accuracy per batch 0.6875
# epoch 2 batch 70
# training loss per batch 1.3568856716156006
# training accuracy per batch 0.5
# epoch 2 batch 75
# training loss per batch 1.5454764366149902
# training accuracy per batch 0.5
# epoch 2 batch 80
# training loss per batch 0.9307860136032104
# training accuracy per batch 0.59375
# epoch 2 batch 85
# training loss per batch 1.4037941694259644
# training accuracy per batch 0.40625
# epoch 2 batch 90
# training loss per batch 0.7130561470985413
# training accuracy per batch 0.6875
# epoch 2 batch 95
# training loss per batch 1.0551272630691528
# training accuracy per batch 0.625
# epoch 2 summary
# avg training loss per epoch 1.002793429493904
# avg training accuracy per epoch 0.6026704546809196
# avg validation loss per epoch 0.7394405917988883
# avg validation accuracy per epoch tensor(0.7263)
#
# epoch 3 batch 0
# training loss per batch 0.8924709558486938
# training accuracy per batch 0.65625
# epoch 3 batch 5
# training loss per batch 1.430903673171997
# training accuracy per batch 0.46875
# epoch 3 batch 10
# training loss per batch 1.0913708209991455
# training accuracy per batch 0.59375
# epoch 3 batch 15
# training loss per batch 0.9974521398544312
# training accuracy per batch 0.65625
# epoch 3 batch 20
# training loss per batch 1.2083631753921509
# training accuracy per batch 0.53125
# epoch 3 batch 25
# training loss per batch 0.819723904132843
# training accuracy per batch 0.71875
# epoch 3 batch 30
# training loss per batch 0.6305310726165771
# training accuracy per batch 0.84375
# epoch 3 batch 35
# training loss per batch 0.9573805332183838
# training accuracy per batch 0.59375
# epoch 3 batch 40
# training loss per batch 1.357866644859314
# training accuracy per batch 0.4375
# epoch 3 batch 45
# training loss per batch 0.4807926118373871
# training accuracy per batch 0.90625
# epoch 3 batch 50
# training loss per batch 0.8674187660217285
# training accuracy per batch 0.65625
# epoch 3 batch 55
# training loss per batch 0.6150183081626892
# training accuracy per batch 0.78125
# epoch 3 batch 60
# training loss per batch 0.8450265526771545
# training accuracy per batch 0.65625
# epoch 3 batch 65
# training loss per batch 1.2659480571746826
# training accuracy per batch 0.4375
# epoch 3 batch 70
# training loss per batch 0.9539369344711304
# training accuracy per batch 0.65625
# epoch 3 batch 75
# training loss per batch 0.9927444458007812
# training accuracy per batch 0.65625
# epoch 3 batch 80
# training loss per batch 1.2342113256454468
# training accuracy per batch 0.625
# epoch 3 batch 85
# training loss per batch 0.940666139125824
# training accuracy per batch 0.71875
# epoch 3 batch 90
# training loss per batch 1.280146598815918
# training accuracy per batch 0.53125
# epoch 3 batch 95
# training loss per batch 0.7349188327789307
# training accuracy per batch 0.75
# epoch 3 summary
# avg training loss per epoch 0.970983472764492
# avg training accuracy per epoch 0.6250568181276321
# avg validation loss per epoch 0.7040937195221583
# avg validation accuracy per epoch tensor(0.7519)
#
# epoch 4 batch 0
# training loss per batch 0.9125658273696899
# training accuracy per batch 0.6875
# epoch 4 batch 5
# training loss per batch 0.7622478008270264
# training accuracy per batch 0.75
# epoch 4 batch 10
# training loss per batch 1.2976378202438354
# training accuracy per batch 0.46875
# epoch 4 batch 15
# training loss per batch 0.9726575613021851
# training accuracy per batch 0.5625
# epoch 4 batch 20
# training loss per batch 0.856386125087738
# training accuracy per batch 0.6875
# epoch 4 batch 25
# training loss per batch 0.7509713768959045
# training accuracy per batch 0.71875
# epoch 4 batch 30
# training loss per batch 0.7332183718681335
# training accuracy per batch 0.71875
# epoch 4 batch 35
# training loss per batch 1.1850422620773315
# training accuracy per batch 0.5
# epoch 4 batch 40
# training loss per batch 0.8544830679893494
# training accuracy per batch 0.5625
# epoch 4 batch 45
# training loss per batch 0.969291090965271
# training accuracy per batch 0.75
# epoch 4 batch 50
# training loss per batch 1.1023445129394531
# training accuracy per batch 0.625
# epoch 4 batch 55
# training loss per batch 0.9676352143287659
# training accuracy per batch 0.625
# epoch 4 batch 60
# training loss per batch 0.9115553498268127
# training accuracy per batch 0.625
# epoch 4 batch 65
# training loss per batch 1.1450759172439575
# training accuracy per batch 0.53125
# epoch 4 batch 70
# training loss per batch 0.986178994178772
# training accuracy per batch 0.65625
# epoch 4 batch 75
# training loss per batch 0.9727585315704346
# training accuracy per batch 0.65625
# epoch 4 batch 80
# training loss per batch 0.9918131232261658
# training accuracy per batch 0.59375
# epoch 4 batch 85
# training loss per batch 1.1461445093154907
# training accuracy per batch 0.5625
# epoch 4 batch 90
# training loss per batch 0.9574004411697388
# training accuracy per batch 0.625
# epoch 4 batch 95
# training loss per batch 1.157650351524353
# training accuracy per batch 0.46875
# epoch 4 summary
# avg training loss per epoch 0.9727024325728416
# avg training accuracy per epoch 0.6182102274894714
# avg validation loss per epoch 0.64756507674853
# avg validation accuracy per epoch tensor(0.7757)
#
# epoch 5 batch 0
# training loss per batch 0.7450453042984009
# training accuracy per batch 0.65625
# epoch 5 batch 5
# training loss per batch 1.0713266134262085
# training accuracy per batch 0.65625
# epoch 5 batch 10
# training loss per batch 1.013479232788086
# training accuracy per batch 0.65625
# epoch 5 batch 15
# training loss per batch 1.0491493940353394
# training accuracy per batch 0.5625
# epoch 5 batch 20
# training loss per batch 0.9049338102340698
# training accuracy per batch 0.5625
# epoch 5 batch 25
# training loss per batch 0.8695688247680664
# training accuracy per batch 0.65625
# epoch 5 batch 30
# training loss per batch 0.8394031524658203
# training accuracy per batch 0.6875
# epoch 5 batch 35
# training loss per batch 1.0893590450286865
# training accuracy per batch 0.625
# epoch 5 batch 40
# training loss per batch 1.156829833984375
# training accuracy per batch 0.53125
# epoch 5 batch 45
# training loss per batch 0.8333670496940613
# training accuracy per batch 0.71875
# epoch 5 batch 50
# training loss per batch 1.339160680770874
# training accuracy per batch 0.53125
# epoch 5 batch 55
# training loss per batch 1.3788881301879883
# training accuracy per batch 0.46875
# epoch 5 batch 60
# training loss per batch 0.7378931641578674
# training accuracy per batch 0.6875
# epoch 5 batch 65
# training loss per batch 0.8071737885475159
# training accuracy per batch 0.65625
# epoch 5 batch 70
# training loss per batch 0.7370709180831909
# training accuracy per batch 0.78125
# epoch 5 batch 75
# training loss per batch 1.0825682878494263
# training accuracy per batch 0.59375
# epoch 5 batch 80
# training loss per batch 0.7898463606834412
# training accuracy per batch 0.625
# epoch 5 batch 85
# training loss per batch 0.7910582423210144
# training accuracy per batch 0.75
# epoch 5 batch 90
# training loss per batch 1.0569084882736206
# training accuracy per batch 0.53125
# epoch 5 batch 95
# training loss per batch 0.5691660642623901
# training accuracy per batch 0.78125
# epoch 5 summary
# avg training loss per epoch 0.9653817677497863
# avg training accuracy per epoch 0.6278977274894715
# avg validation loss per epoch 0.6556825240453085
# avg validation accuracy per epoch tensor(0.7623)
#
# epoch 6 batch 0
# training loss per batch 1.397067904472351
# training accuracy per batch 0.46875
# epoch 6 batch 5
# training loss per batch 1.1779755353927612
# training accuracy per batch 0.59375
# epoch 6 batch 10
# training loss per batch 0.5964165925979614
# training accuracy per batch 0.75
# epoch 6 batch 15
# training loss per batch 1.004696011543274
# training accuracy per batch 0.625
# epoch 6 batch 20
# training loss per batch 0.8723719716072083
# training accuracy per batch 0.625
# epoch 6 batch 25
# training loss per batch 0.662960946559906
# training accuracy per batch 0.6875
# epoch 6 batch 30
# training loss per batch 1.2293055057525635
# training accuracy per batch 0.46875
# epoch 6 batch 35
# training loss per batch 1.0973047018051147
# training accuracy per batch 0.59375
# epoch 6 batch 40
# training loss per batch 0.915215790271759
# training accuracy per batch 0.625
# epoch 6 batch 45
# training loss per batch 0.7421751022338867
# training accuracy per batch 0.6875
# epoch 6 batch 50
# training loss per batch 0.9069600105285645
# training accuracy per batch 0.59375
# epoch 6 batch 55
# training loss per batch 1.14749276638031
# training accuracy per batch 0.65625
# epoch 6 batch 60
# training loss per batch 0.8831448554992676
# training accuracy per batch 0.6875
# epoch 6 batch 65
# training loss per batch 1.3456600904464722
# training accuracy per batch 0.5
# epoch 6 batch 70
# training loss per batch 0.8784165978431702
# training accuracy per batch 0.625
# epoch 6 batch 75
# training loss per batch 0.8399056196212769
# training accuracy per batch 0.65625
# epoch 6 batch 80
# training loss per batch 0.7520642876625061
# training accuracy per batch 0.71875
# epoch 6 batch 85
# training loss per batch 0.7290706634521484
# training accuracy per batch 0.6875
# epoch 6 batch 90
# training loss per batch 0.9593837261199951
# training accuracy per batch 0.65625
# epoch 6 batch 95
# training loss per batch 0.9104887843132019
# training accuracy per batch 0.59375
# epoch 6 summary
# avg training loss per epoch 0.9638566035032272
# avg training accuracy per epoch 0.6323011362552643
# avg validation loss per epoch 0.6331549303399192
# avg validation accuracy per epoch tensor(0.7824)
#
# epoch 7 batch 0
# training loss per batch 1.3610875606536865
# training accuracy per batch 0.53125
# epoch 7 batch 5
# training loss per batch 0.8254044651985168
# training accuracy per batch 0.6875
# epoch 7 batch 10
# training loss per batch 0.6465499997138977
# training accuracy per batch 0.71875
# epoch 7 batch 15
# training loss per batch 0.9746781587600708
# training accuracy per batch 0.65625
# epoch 7 batch 20
# training loss per batch 0.873401939868927
# training accuracy per batch 0.6875
# epoch 7 batch 25
# training loss per batch 1.1889581680297852
# training accuracy per batch 0.59375
# epoch 7 batch 30
# training loss per batch 1.0530765056610107
# training accuracy per batch 0.5625
# epoch 7 batch 35
# training loss per batch 1.0554535388946533
# training accuracy per batch 0.5625
# epoch 7 batch 40
# training loss per batch 0.9083524942398071
# training accuracy per batch 0.6875
# epoch 7 batch 45
# training loss per batch 0.9325199127197266
# training accuracy per batch 0.625
# epoch 7 batch 50
# training loss per batch 0.9250813126564026
# training accuracy per batch 0.53125
# epoch 7 batch 55
# training loss per batch 0.9968959093093872
# training accuracy per batch 0.5
# epoch 7 batch 60
# training loss per batch 1.0728501081466675
# training accuracy per batch 0.59375
# epoch 7 batch 65
# training loss per batch 0.833184540271759
# training accuracy per batch 0.59375
# epoch 7 batch 70
# training loss per batch 0.9156956672668457
# training accuracy per batch 0.65625
# epoch 7 batch 75
# training loss per batch 1.2439621686935425
# training accuracy per batch 0.59375
# epoch 7 batch 80
# training loss per batch 0.8816582560539246
# training accuracy per batch 0.65625
# epoch 7 batch 85
# training loss per batch 0.7794283628463745
# training accuracy per batch 0.75
# epoch 7 batch 90
# training loss per batch 1.0085333585739136
# training accuracy per batch 0.71875
# epoch 7 batch 95
# training loss per batch 0.9743590354919434
# training accuracy per batch 0.65625
# epoch 7 summary
# avg training loss per epoch 0.9512734520435333
# avg training accuracy per epoch 0.6366477274894714
# avg validation loss per epoch 0.6894059545463986
# avg validation accuracy per epoch tensor(0.7537)
#
# epoch 8 batch 0
# training loss per batch 1.5491218566894531
# training accuracy per batch 0.46875
# epoch 8 batch 5
# training loss per batch 1.0723965167999268
# training accuracy per batch 0.59375
# epoch 8 batch 10
# training loss per batch 1.3712618350982666
# training accuracy per batch 0.46875
# epoch 8 batch 15
# training loss per batch 0.940429151058197
# training accuracy per batch 0.6875
# epoch 8 batch 20
# training loss per batch 0.9807096719741821
# training accuracy per batch 0.59375
# epoch 8 batch 25
# training loss per batch 0.9118655323982239
# training accuracy per batch 0.625
# epoch 8 batch 30
# training loss per batch 0.895977795124054
# training accuracy per batch 0.625
# epoch 8 batch 35
# training loss per batch 1.1971546411514282
# training accuracy per batch 0.53125
# epoch 8 batch 40
# training loss per batch 0.6691599488258362
# training accuracy per batch 0.65625
# epoch 8 batch 45
# training loss per batch 1.0478097200393677
# training accuracy per batch 0.5625
# epoch 8 batch 50
# training loss per batch 0.6462046504020691
# training accuracy per batch 0.6875
# epoch 8 batch 55
# training loss per batch 1.3744022846221924
# training accuracy per batch 0.4375
# epoch 8 batch 60
# training loss per batch 1.1371698379516602
# training accuracy per batch 0.625
# epoch 8 batch 65
# training loss per batch 0.9300279021263123
# training accuracy per batch 0.625
# epoch 8 batch 70
# training loss per batch 1.1998244524002075
# training accuracy per batch 0.4375
# epoch 8 batch 75
# training loss per batch 1.0975829362869263
# training accuracy per batch 0.53125
# epoch 8 batch 80
# training loss per batch 0.983670175075531
# training accuracy per batch 0.59375
# epoch 8 batch 85
# training loss per batch 0.782607913017273
# training accuracy per batch 0.65625
# epoch 8 batch 90
# training loss per batch 0.8069280385971069
# training accuracy per batch 0.65625
# epoch 8 batch 95
# training loss per batch 0.6370545029640198
# training accuracy per batch 0.78125
# epoch 8 summary
# avg training loss per epoch 0.9966348344087601
# avg training accuracy per epoch 0.6102556818723679
# avg validation loss per epoch 0.749275835023986
# avg validation accuracy per epoch tensor(0.7346)
#
# epoch 9 batch 0
# training loss per batch 1.3066723346710205
# training accuracy per batch 0.4375
# epoch 9 batch 5
# training loss per batch 1.6597094535827637
# training accuracy per batch 0.5
# epoch 9 batch 10
# training loss per batch 0.9943764209747314
# training accuracy per batch 0.59375
# epoch 9 batch 15
# training loss per batch 0.9122633337974548
# training accuracy per batch 0.625
# epoch 9 batch 20
# training loss per batch 0.5764499306678772
# training accuracy per batch 0.71875
# epoch 9 batch 25
# training loss per batch 0.6562479138374329
# training accuracy per batch 0.8125
# epoch 9 batch 30
# training loss per batch 1.049142599105835
# training accuracy per batch 0.5625
# epoch 9 batch 35
# training loss per batch 0.9257396459579468
# training accuracy per batch 0.59375
# epoch 9 batch 40
# training loss per batch 0.7849520444869995
# training accuracy per batch 0.65625
# epoch 9 batch 45
# training loss per batch 0.6385015845298767
# training accuracy per batch 0.75
# epoch 9 batch 50
# training loss per batch 1.127186894416809
# training accuracy per batch 0.5625
# epoch 9 batch 55
# training loss per batch 1.14853835105896
# training accuracy per batch 0.65625
# epoch 9 batch 60
# training loss per batch 0.8376321792602539
# training accuracy per batch 0.65625
# epoch 9 batch 65
# training loss per batch 1.3287538290023804
# training accuracy per batch 0.46875
# epoch 9 batch 70
# training loss per batch 0.6689983606338501
# training accuracy per batch 0.71875
# epoch 9 batch 75
# training loss per batch 1.0227257013320923
# training accuracy per batch 0.5625
# epoch 9 batch 80
# training loss per batch 1.0845880508422852
# training accuracy per batch 0.59375
# epoch 9 batch 85
# training loss per batch 0.9769377112388611
# training accuracy per batch 0.625
# epoch 9 batch 90
# training loss per batch 0.793840765953064
# training accuracy per batch 0.6875
# epoch 9 batch 95
# training loss per batch 0.6767497658729553
# training accuracy per batch 0.75
# epoch 9 summary
# avg training loss per epoch 0.9809762167930604
# avg training accuracy per epoch 0.6170738637447357
# avg validation loss per epoch 0.7299529231256909
# avg validation accuracy per epoch tensor(0.7496)
# Test Accuracy: 0.7727
# ============================================================
# OVERALL ACCURACY: 0.7727 (77.27%)
# ============================================================
#
#                      Class TP FP FN TN  Precision  Recall  F1-Score  Support
# Acral Lentiginous Melanoma 12  3  3 70     0.8000  0.8000    0.8000       15
#                Blue Finger 20  0  0 68     1.0000  1.0000    1.0000       20
#                   Clubbing  5  2  7 74     0.7143  0.4167    0.5263       12
#               Healthy Nail  4  1  5 78     0.8000  0.4444    0.5714        9
#            Onychogryphosis 11  4  5 68     0.7333  0.6875    0.7097       16
#                    Pitting 16 10  0 62     0.6154  1.0000    0.7619       16
#                  Macro Avg                 0.7772  0.7248    0.7282       88
#               Weighted Avg                 0.7881  0.7727    0.7614       88
